# %%
tf.VERSION
# Out:
# '1.0.0'

# %%
#!pip install tensorflow==1.0.0

# %%
import tensorflow as tf
import numpy as np
import re
import time

# %%
lines=open("movie_lines.txt",encoding="utf-8",errors="ignore").read().split("\n")

# %%
conversations=open("movie_conversations.txt",encoding="utf-8",errors="ignore").read().split("\n")

# %%
id2line={}

# %%
for line in lines:
    _line=line.split(" +++$+++ ")
    if len(_line)==5:
        id2line[_line[0]]=_line[4]

# %%
id2line
# Out:
# {'L515149': "A Texas Bear in Arkansas.  Something's up and at this point in my life, I don't want to know what it is.",
#  'L120054': "I'm forty-three years old. I don't want to wait. I know you well enough to know that I really love you very much.  And I can't think of anybody better to be with. And I don't feel like waiting anymore.",
#  'L359657': 'You do see me standing here, right?',
#  'L373766': 'Anybody wanna have a game?',
#  'L343779': 'Go, Sera.  Go. Stay at home. I will call you tomorrow.',
#  'L254106': 'No -- no -- wait -- the man was a burglar -- he was going to steal my money.',
#  'L495797': 'Oh, damnit!',
#  'L526240': 'You said it would be unethical to help me. You call dwarf bowling ethical!',
#  'L400293': "This doesn't seem a little... perverse?",
#  'L440835': 'As in, the vegetable?',
#  'L433605': "It's Richard Ripley.",
#  'L656872': 'Those kids, they took my wagon. Never got it back.',
#  'L416879': "He must've been working late and some fruitcake came in and sliced him up like a kielbasa.  In the shower!  Left bloody footprints all over the...",
#  'L609798': "They can't shoot us in here.",
#  'L269926': 'Who is Ratan?',
#  'L117637': "Thank you for showing it to me first. I'll... I'll take care of it. Can I have the picture?",
#  'L616798': "I'm your man...  You win again.  Well played, sir. You are on fire.",
#  'L192157': "Good.  Soon as we're clear, we'll kick this baby into hyperdrive.",
#  'L112277': 'Turn it off.',
#  'L458561': 'But, Jake, I was just...',
#  'L627416': "You've reached a new low with this one.  I can't believe you're crazy enough to use the room at the Marquis.",
#  'L246732': 'No.  The girl.',
#  'L378424': "We got a guy who's probably on drugs. He's got a record of 459's and he was busted on possession. But he's never been busted on a major felony. What's his demeanor?",
#  'L543432': 'I just retired.',
#  'L109035': "<u>No you're not</u>.  You're not going anywhere.  I'm shutting this down.",
#  'L352335': '. . . What?',
#  'L225937': 'No time to explain.  Just listen. When I yell "stop," you jam on the brakes as hard as you can.  Okay?',
#  'L229214': "No, Jason, that's a wrap!  There's nothing to think about!",
#  'L357167': 'Look at me. Look at what they gave me to wear.',
#  'L307448': 'What did he talk to you about?',
#  'L324604': "You're silly....",
#  'L292756': "Still do the puzzles, still know the running times of songs, and I'll bet you're still the best damn cat burg--",
#  'L123530': 'Hey, speaking of Wrong Place, Wrong Time.  Lewis Lane to the rescue!',
#  'L86408': 'Two days?',
#  'L478247': 'Two hundred cops?  Was Mario Sanchez there?  He owes me money.',
#  'L359417': "There's so many I just can't keep track.",
#  'L97599': "Hey come here, you stole my girl, you bastard. I'm gonna kick your ass, right in front of your stupid house.",
#  'L322105': "Well, then I'm going to film it.",
#  'L209095': "That's a fine combination. You can't lose.",
#  'L124525': "I told you ... sooner or later you'd have to trust me ...",
#  'L142515': "I'll do it.  On one condition.  I want to make sure she's okay.",
#  'L124637': "No. It's the truth.",
#  'L396653': 'I see.',
#  'L218006': "<u>You're surprised</u>!... But I guess I just never met the right guy.  Whatta gonna do?",
#  'L63222': 'We should go out on a double date.',
#  'L428745': 'Jesus God...',
#  'L59311': "I don't know... I just feel scared.",
#  'L454412': "Can see you do. Sorry I couldn't make you feel better. You want to come to my office this afternoon and report a missing person... And the theft, is what you want to do!  Sooner you drop this thing in the lap of the law, that's the sooner you'll stand a chance of your sister bein' picked up. How about that?",
#  'L234694': "Whatever happens it's over.",
#  'L516291': "-- Brought against Sparazza by Israel's mother Laverne who was nineteen at the time. They had a brief affair which Israel was the by- product of.",
#  'L665798': "It wasn't me.",
#  'L488347': "Listen to me. We've got to get help. The Killer's here.",
#  'L287765': 'Keeps to himself, more like.',
#  'L612745': "It's about this.",
#  'L294476': 'One night stand?',
#  'L409537': 'Your mother used to lay for her boss, boy. Did you know that?',
#  'L627221': "Hey, slow down you're gonna miss the turn!",
#  'L6221': "Who gives a shit! I didn't come here to listen to music! Listen up instead of running off at the mouth! The batteries on my phone are almost gone.",
#  'L383077': "What's in your socks?",
#  'L260265': "Mom, I'm on a diet. You want an oinker for a daughter?",
#  'L32054': "Right. Now listen carefully. I want you to bring David here. I want him in my care. I'll notify the police that we've found him. It is imperative that you bring him straight to the hospital. Do you understand?",
#  'L477669': "You don't know what a shortcut is?",
#  'L288761': "I'll try.",
#  'L12816': "Okay. So we'll get what you want. What do you want?",
#  'L470327': "I'm sure you are.",
#  'L461493': 'If possible -- both.',
#  'L292124': 'Yes it is. Will and Seamus look at each other -',
#  'L243991': 'All of, they got you on this "board..."',
#  'L85977': "Fifteen. You don't know him. He was very kind and strong.",
#  'L384941': "There are thirty five listed in the reverend Wong's roster...",
#  'L622792': 'What do you think she wants?',
#  'L580274': 'Brought on by what?',
#  'L604347': "Oh, you won't be running for long...",
#  'L558701': "Sure. Especially if you'd be a really terrific guy and bring me a cheeseburger to go --",
#  'L409733': "Well, I haven't come around.",
#  'L133789': "I'm all right, Mr. Leland.  Only there was some fellows out front that thought they ought to take things up with me.  I learned 'em! Didn't I, officer?",
#  'L455296': "Alright: And I have to go and buy some more pudding for this trip to Hawaii and as I just said that out loud I'm realizing it sounds a little strange but it's not. So can you come and help me out?",
#  'L346846': 'Why do you want to know?',
#  'L270620': 'She took my head.',
#  'L120255': 'All right.',
#  'L467979': "Well.    I don't like men with...er, with too many, muscles.",
#  'L47913': "Maybe he'll get tubed.",
#  'L258182': "You don't.",
#  'L141183': 'Still time.',
#  'L126663': 'When you come on, you really come on.',
#  'L414683': "Me?  Wait a minute, you can't bring someone out of a dream!",
#  'L284151': "I'm Sheriff Hartman. You want me?",
#  'L505071': "So what's happening with your book?",
#  'L53533': "No.....But I think Honza at the office has. You keep shifting this crap and I'll take care of the locks, shouldn't take long. Take a break for lunch and I'll catch you up later.",
#  'L553847': 'Alright, get in the car before I have to embarrass you in front of your friend.',
#  'L347234': 'My pocket.  Check my pocket, will ya, honey?',
#  'L60138': 'Hook us up to a stand-pipe.',
#  'L59799': "I don't know.",
#  'L482271': "Oh they're all that and the proverbial bag of chips.",
#  'L587599': "I don't know who fingered me, but I'm not a communist!",
#  'L134297': 'Are you sure?',
#  'L134620': 'Five years.',
#  'L221605': "I never saw him. Why didn't he show up?",
#  'L434889': 'Come on, come on...',
#  'L412613': 'Young love.',
#  'L657140': 'Easy?  Easy?  On just what grounds should I take it easy!?',
#  'L199344': 'He had a mind that escalated things.',
#  'L597573': 'You bastard...',
#  'L274881': "What's going on?",
#  'L573430': "I don't know.",
#  'L112762': "Yeah. Great, isn't it?",
#  'L169993': 'You listening to me?',
#  'L659076': "I don't know where he is.",
#  'L648258': 'Tonight?',
#  'L164191': "Too bad it didn't happen to Miser Stevens.",
#  'L348622': "I'm too old for you. Besides, I'm not much in the mood.",
#  'L651554': 'But you invited is aboard.',
#  'L218627': "I 'magine it's me then, id'n it?",
#  'L648797': "But he acted like he'd never heard of it.",
#  'L421810': "...I believe they've done lit a shuck.",
#  'L23652': 'Look at that.',
#  'L618519': "I'd rather die alone.",
#  'L345089': 'Huh?',
#  'L259652': 'What?',
#  'L333079': '... Just a perception.',
#  'L458731': "We did what we had to do. Tommy don't forget. Sooner or later you'll get your shot -- if Tommy don't die.",
#  'L609701': 'You want to crawl, crawl.',
#  'L233531': 'Hello, Doris.',
#  'L114294': 'Well...',
#  'L244579': "Jim, Jim, you saw my book...I can't, you saw my book...",
#  'L507086': 'Hi, Dad.',
#  'L159919': 'The thieves.',
#  'L167424': 'Sonny!  Could you come out, please? Could you come out, please?',
#  'L656549': 'Right.',
#  'L556706': 'I mean him.',
#  'L548027': 'How was your flight?',
#  'L591157': 'Dream on.',
#  'L149602': "That's beautiful.",
#  'L627057': 'Well I pull out the manual on their setup, which is the new 680 server...',
#  'L660254': "Whew! That wasn't my plan - but something happened, didn't it?",
#  'L596487': "They're gonna book us.",
#  'L638856': 'If I could find the key... find the beginning put it together...',
#  'L59922': 'Cole, what the hell are you doing?',
#  'L121775': "Don't you threaten me!",
#  'L356944': 'I beg your pardon, brother. What did you say you were hunting?',
#  'L442281': 'That signal is over a thousand feet high, which means it can be seen for two hundred leagues in every direction.  The entire Royal Navy is out to sea looking for me -- do you think there is even a chance they could miss it?',
#  'L623332': "But you're looking better, it has to be said. Healthier. Radiant even.",
#  'L86642': 'What happened?',
#  'L199040': "What'd she sing?",
#  'L376960': 'You know him?',
#  'L82526': "I just wanted to say hi.  Did you know I still don't know your name or where you work?",
#  'L389571': "No. I'm here with you.",
#  'L3145': "Yeah.  I'll do that.  As long as you're not patronizing me.",
#  'L96779': 'Well. Okay.',
#  'L547997': "I'm very sorry I...",
#  'L461576': "Don't rush me. We have all night.",
#  'L291903': "We're usually successful in detecting the source of most problems.  Unfortunately.",
#  'L107005': "I don't know.  We may never know, but I'm going to guess it was a job, maybe the Karpoli family.",
#  'L625963': "Don't tell me where to work. I moved to New York to work for Edward Dowd. But I can't believe that Edward Dowd has nothing better to do these days than invoke exalted legal issues to get off guilty little --",
#  'L602758': "I couldn't go near that woman.",
#  'L554386': "Ah!  I almost forgot gas for the baby machine.  I'll grab your Snickers and get a place in line.",
#  'L293561': 'Get out of my sight.',
#  'L106517': "You're helping Rajeev?",
#  'L137398': "You dumb bastard, you waited too long.  If he made it back, this place would have been covered with police in a few hours.  The way we're moving, it's going to be anyway.",
#  'L337166': '"Carefully".  "Carefully". "Carefully".',
#  'L418957': 'No, madame, something of the utmost importance... it concerns your jewels.',
#  'L540816': '',
#  'L267114': "No. Fuck no. If you met yourself as a child, would you hug her and say everything's going to be okay...",
#  'L227195': "She's...she's dropping the anchors. I thought the Coast Guard could find us easier if...",
#  'L360464': 'Seat belt.',
#  'L325952': "We're going.",
#  'L118557': 'Is that a serious offer?',
#  'L588690': "It's Alice.",
#  'L617009': 'What about her?',
#  'L428326': 'Now, what would I be trying to say?',
#  'L485920': "That's great.",
#  'L409933': "Hell, if they don't blow up his place, they'll get him some other way. Don't make no difference no-how.",
#  'L251729': 'Could I make one phone call first?',
#  'L131025': 'So many children. Are they all orphans?',
#  'L172750': 'Just a guy I hang out with.',
#  'L328666': 'Your Honor, I would ask you to direct the witness to answer my question. Why did Colonel Finck not dissect the track of the bullet wound in the neck?',
#  'L30232': 'No.',
#  'L426644': 'Are you laughing at me, dick-brain?',
#  'L293802': 'Confused?',
#  'L590063': "Is it a great man whom Gray can order to his bidding? Is it a great man who for very shame dare not acknowledge his own wife so that I must play maidservant for the world's sake and his success?",
#  'L141630': 'What?',
#  'L143530': 'Well, you know. Small town, not much to do in the evenings. Mostly it was settling up old scores.',
#  'L285658': "You're much more convincing when you're making it up.",
#  'L501807': 'Nothing.',
#  'L505970': 'I understand.',
#  'L44904': 'His Snapples were in alphabetical order.',
#  'L381716': 'Come again?',
#  'L484239': "Well, if we're friends, why can't we see each other?",
#  'L142704': "It was a worthy experiment -- worthy of you; I was wrong about that part. But it's over now.",
#  'L569666': 'Where are you going?',
#  'L637266': 'Are we going to win?  We have, you know, other tactics, though...',
#  'L231265': "I don't believe it -- even the British can't be that stupid!",
#  'L472398': 'Am I like Such a fellow?',
#  'L437823': "Our doctor's gone too.",
#  'L311312': 'Well, I got it, Joe.',
#  'L375955': "I'm sorry.  Do you live here?",
#  'L413357': "Out shopping -- you're bleeding, Dad --",
#  'L510591': 'Shotgun. Suicide. Next?',
#  'L125556': 'Okay.',
#  'L118628': 'Are you one of those people who cannot imagine the Germans in their beloved Paris?',
#  'L269626': 'In other words, you want to get laid?',
#  'L645102': 'Upper West Side.',
#  'L472397': 'Keep away the cats! Thou art like one of these fellows that, when he enters the confines of a tavern claps me his sword upon the table and says, &quot;God send me no need of thee.&quot; and by the operation of the second cup draws him on the drawer, when indeed there is no need.',
#  'L474747': "He can wait. Let's stay here until morning.",
#  'L454115': "I don't know where. In your store, somewhere in your town... anywhere.",
#  'L427176': 'Talk to me in the morning. I feel like shit.',
#  'L134514': "Because I did only sleep with three guys! That doesn't mean I didn't just go with people.",
#  'L316093': "And no more demons. I told you they'd be gone.",
#  'L481266': "But you had to have it, didn't you? It was so nice to listen",
#  'L41578': 'Oh, yes, Grandmama - I wait until I hear...',
#  'L520952': 'Boy, would I like to borrow a cup of that Sugar.',
#  'L306714': 'Marylin? When did I say...?',
#  'L305949': 'Ah! You have questions?',
#  'L123552': 'Yes, you do. You have to go rescue all those people...',
#  'L329359': "I'm supposed to be running.",
#  'L59021': 'She did. But hardly anyone does anything truly alone.',
#  'L270327': 'No more revolts.',
#  'L131449': 'Did you come here with Wally--to *not* watch movies?',
#  'L64802': 'Your Grace, if I am so tame as to take this, then I must give up an honorable and lucrative occupation.',
#  'L511420': 'We are farmers here, not lawyers or bankers, or even constables.  Every penny we earn comes from what we send down the Hudson.',
#  'L428183': 'Will you come with me, please.',
#  'L243881': 'Fuck him.  Fuck Murray.  John?  You know?  You tell him I said so. What does he fucking know?  He\'s going to have a "sales" contest...you know what our sales contest used to be? ',
#  'L113829': 'No!!!!!',
#  'L303065': 'You did.',
#  'L218924': "But I'd like to say, so that I don't dampen the spirit of your adventure...",
#  'L46811': "Oh, I'm very grateful.",
#  'L163301': 'Nah. Once I get my own wheels, I could come up all the time.',
#  'L536232': 'Spock... Did braking thrusters fire?',
#  'L56270': "That's very clever. Do you know any other poems?",
#  'L126823': "The best for the last -- le chef- d'oeuvre de la collection. The masterpiece. It is the most valuable stamp in the world. It is called 'The Gazette Guyanne.' It was printed by hand on colored paper in 1852 and marked with the initials of the printer.  Today it has a value of $100,000.  Eh, bien -- I am not a thief. I knew there was some mistake. Take them.",
#  'L635647': "Ned, don't pay no mind to what the Kid said about the money. I'll bring your share along, hear? The Kid's full of shit, hear?",
#  'L14747': 'Yes.',
#  'L337551': 'How many onions does it say to use?',
#  'L84044': "Sorry, kid. I don't do charity.",
#  'L406005': 'Show him in.',
#  'L142337': 'Did you kill him?',
#  'L125016': 'They all get the wrong idea.',
#  'L26562': "Because you'll be gone soon, like the others.  Like everybody.  You'll be dead and you'll leave me alone.",
#  'L438770': "I don't know.",
#  'L452689': 'Congratulations.',
#  'L621422': 'Just one?',
#  'L424046': "She's gonna have to 'cause I'm out of ideas.",
#  'L247900': 'How ya doing?',
#  'L265599': "Waal, because your <u>selling</u>'em... Two years ago, his annotated Dictionary of Cuisine, by Alexander Dumas, went for sixteen thousand dollars. Seller's affidavit of ownership, signed Cary Panz.  P.A.N.Z.  Sounds to me like an Orderly.  Whadja clear on the book? Ten, twelve grand?",
#  'L666127': 'MMMmm!',
#  'L245548': "I know it wasn't me...so that leaves you.",
#  'L133779': "There are the people of the United States, and they are blaming you - Oh, I know it doesn't make any sense, but at least you can learn a lesson from it.",
#  'L630468': "You can tell J. Edgar that I was at a party and I got fifteen fuckin' witnesses.",
#  'L251322': 'Could you do it?',
#  'L339528': 'No.',
#  'L110722': 'I mean it fixed itself.',
#  'L93968': '...Ray?',
#  'L189815': "Well, I'm sure as hell not what I thought I was gonna be.  I was supposed to have one of those great lives, with everything all laid- out and perfect.  I mean, hell -- I was Miss Wichita, for God's sakes.  Did I tell you that?  You live next door to a real live beauty queen.  I still got the tiara.  I kept it cause I thought it meant something.  I thought it meant I was gonna do something great with my life.  I thought it proved I was gonna grow up to be someone.",
#  'L125351': "A bit heavy on the powder, isn't she, Jimmy?",
#  'L78352': "You don't have a key?",
#  'L62455': "I could've held off an army if I could've gotten behind a rock in the mountains.",
#  'L465413': 'Then one day she meets a John Holmes motherfucker, and it\'s like, whoa baby. This mother fucker\'s like Charles Bronson in "The Great Escape." He\'s diggin\' tunnels. Now she\'s gettin\' this serious dick action, she\'s feelin\' something she ain\'t felt since forever. Pain.',
#  'L302287': 'Thanks.',
#  'L617767': "Perfect way to tie up a... 'Knotty' problem?",
#  'L400894': 'That "thing" gets me excited.',
#  'L218850': "As a matter of fact, he's the one who introduced me to Carl...  How are you?",
#  'L548306': 'I hurt you?',
#  'L628031': 'That dazzling imagination.',
#  'L12696': "What's the difference? Take my truck, take a rest -- stop worrying about Mel Gordon. Have you decided what to do with your old man's place -- he going to stay there?",
#  'L643336': "When do we bring'em back?",
#  'L81153': 'What is that?',
#  'L435665': "Unh... Unh Man... I don't take no money from friends that need help. Fuck no. What do you think I am a bum?",
#  'L630883': "Come on, Laura. I'm your best friend.",
#  'L433463': 'You have to be kidding.',
#  'L628193': "What's this acting class guy's name?",
#  'L480024': "But one of those guys -- not one of them -- knew her at all.  Each one was convinced that she was perfect for them, but they didn't see her.  And she never showed up so they couldn't see her. It's a very symbolic thing happening. She becomes what she thinks they wanted to be.",
#  'L67756': 'No Lisa Anderson, detective.',
#  'L127505': "I'm making you feel like meat?",
#  'L364128': "Malcolm, you can be anything you want. You got class and you're smart.",
#  'L53381': 'This place is getting expensive too, used to be twelve.',
#  'L537981': "I'm not sure how to take that.",
#  'L295278': "That wouldn't give us much time, would it?",
#  'L332566': "You're about to be a media darling -- you might want to dress the part.",
#  'L233206': "Yeah, that's what we need. More agents.",
#  'L457734': "Yes, sure, that's fine. While I'm proving my innocence, you people are going to uncover every petty kid trick I ever did ... you're going to write editorials about every cocktail I ever drank. Anything that any sane, normal person might have done will have a sinister meaning, if I did it.  Go on! Get out! I don't want to talk to you! ",
#  'L521870': 'First thing we got to do is get out of these clothes.',
#  'L324698': "I've struck the mother-lode.  I'm counting... spade work....",
#  'L345958': 'This is not the time for squabbling.',
#  'L95920': "You're looking at him.  We provide the plane, transportation cost, U.S. landing spot, and take it to wherever you want it to go.  You provide the pick up point in South America, and are responsible for payment.  You assume all the bust risks.  We take sixty-five percent of all transportation fees, ten percent of the gross, plus our expenses. This is not a negotiation, so if this is okay with you, we can talk further.  If not, we can forget we had this conversation.",
#  'L86172': "Don't you lay a CURSE ON ME!",
#  'L325890': "No you don't. That's how you <u>think</u> you feel about him. That's how you feel about <u>yourself</u>. You won't give yourself one-fucking-minute for <u>you</u>.",
#  'L236648': "My acting workshop is across the street from here. I'm just on my break.",
#  'L57998': 'What is it?',
#  'L356121': "I want you to ride with me. Somethin' doesn't sound right.",
#  'L350101': "Don't worry about coming up with anything. It's cool.",
#  'L14180': 'Somebody told her.',
#  'L645311': "If you mean what you say, I think we're in the ball park. I'll take it to my people.",
#  'L375143': 'Oh, somebody else sitting there?',
#  'L308249': "Okay, I'll try. But, listen...  If I don't make it up, then you go ahead and have a great time.",
#  'L169366': 'Pino, relax, will ya.',
#  'L154263': "Any idea when she'll be back?",
#  'L279656': "I'm not experimenting.  Why don't you go experiment.",
#  'L661842': 'How about in the morning.',
#  'L487459': "You'll never get away with this.",
#  'L643841': "... they're checking the ratings...uh...",
#  'L113151': "Norman Rockwell's enduring portrait of a <u>Homecoming</u>  The return of a fighting man has always been one of the more moving ceremonies of war... Tearful women, proud men, excited children.  But J.D. Singer was right -- his homecoming was no big deal.",
#  'L588545': 'I understand completely, sir.',
#  'L570853': "That's none of your business.",
#  'L122792': 'Need some help?',
#  'L629635': 'They hurt you!',
#  'L387130': 'Somewhere.',
#  'L258116': 'Yeah.',
#  'L637882': 'Me, too.',
#  'L601899': 'Magnesium of some type... or some kind of strange alloy.  And those poor dumb bastards had to go and blow the hell out of it.',
#  'L152308': 'You must have it, you idiot, we can stop the bomb!',
#  'L578708': "They're going to stop me talking to you.",
#  'L366371': 'There were 24 kidnappings in Mexico City in the last six days. Four a day. What do you think about that, Mr. Creasy?',
#  'L366291': 'Is it loaded?',
#  'L822': 'How?',
#  'L160293': "What do you think, Sal? Jesus, you think we'd miss this?",
#  'L534759': 'We are going to this "planet." Even as our emissaries negotiate for "peace" with the Federation, we will <U>act</U> for the preservation of our race! We will seize the secret of this weapon. The secret of ultimate power!',
#  'L361815': 'I paid you back.',
#  'L248036': "We can learn something from our Asian friends. They smoke a thousand cigarettes a day; they're completely stressed and overworked; they drink like, well ...",
#  'L219172': 'Positive.',
#  'L180204': '...everyone has been very kind.',
#  'L191596': "He's checking out a meteorite that hit near him. He'll be in soon.",
#  'L287860': "The cops are comin'!",
#  'L206228': "Well, Ecklund & Swedlin's, that's closer ta Moose Lake, so I made that assumption.",
#  'L150179': "Cecile, I think you're going to have a hard time crying rape if that's all he did.",
#  'L150023': 'What about her?',
#  'L431909': "Are you sure they're your friends?",
#  'L612919': 'Just how easy is it to build a... device?',
#  'L268151': 'So long, you guys.',
#  'L223980': "I should'a been a fucking mailman.",
#  'L506373': 'Maybe you could run it without Stella.',
#  'L288716': "I don't have it here. At the Mille Collines. I can get it for you.",
#  'L491077': 'Is there a killer loose?',
#  'L600558': "Didn't they tell you? That hitcher was just about to cut your throat when you stopped to take a leak. You got a fucking horseshoe up your ass, man.",
#  'L194163': 'Well, anyway... Sorry.',
#  'L182509': "Trashcan Jack.  The Big V.  I can tell you he's on the Night Train to the big adios.",
#  'L474783': "I didn't know anything about her except she wanted a job because some man had left her stranded. I couldn't leave her in the street. Let's go.",
#  'L593922': "I'm gonna pay a visit to the K.L.F. See if they've got the 411 on Santa's location. I'll check in with you when I know more.",
#  'L512730': 'About a half a mile I think it is.',
#  'L15111': "Eh ... don't call him sir, he's got enough delusions of power as it is.",
#  'L622785': 'That triple the amount of stuff is going through.',
#  'L57548': 'A kipper. Or a red herring? What were they investigating?',
#  'L210887': 'Really?',
#  'L267900': 'Scrambled eggs, kippered herring, fried potatoes--and a whole onion. I want to eat the onion like an apple.  Do you understand?',
#  'L501583': 'Television or movies?',
#  'L637930': "No, actually, she was referred to me.  She was Dr. Hagman's patient...",
#  'L220605': "It's red, Ford.",
#  'L122677': "I never thought it would end.  Then it did.  It was so great to be saved, I couldn't stop laughing.",
#  'L403999': 'Please come, please.',
#  'L240174': 'No!  Nobody ever built them like this!  The architect was either an authentic whacko or a certified genius.  The whole building is like a huge antenna for pulling in and concentrating psychokinetic energy.',
#  'L284753': "Come on, Sheriff. We've got to get bail.",
#  'L369023': 'Library of Congress.',
#  'L471328': 'Forget it.',
#  'L168958': "I don't want to talk about it.  So what happened to your neck?",
#  'L101906': 'Then what the fuck?',
#  'L446821': 'Dance? Here?',
#  'L137335': 'What about you?',
#  'L399870': "Fill in the blank. I don't mind the office. The point is, you only go 'round once. Like the Zens say -- Be here now.",
#  'L87901': 'True.',
#  'L619068': "I don't enjoy watching things suffer.",
#  'L310635': "What's the matter? Wouldn't the old meanies wait for you?  Say, how old are you anyway? Don't you know these busses work on a schedule? You need a guardian.",
#  'L325173': 'You sure you know how to do this.',
#  'L336027': "I don't believe Tom's alive.",
#  'L341982': 'Big through the hips. Roomy.',
#  'L172146': "He's working very hard - I got him a job driving Firefly's car - He's-a driving him crazy and I'm driving him nuts - P-E-A-N-U-T-S",
#  'L340025': "I'm completing the walk.  I'm almost there.",
#  'L624157': 'Their equipment is primitive but effective. I recommend we land at Coordinate 8563.',
#  'L116953': "I think Thomas Pynchon's a genius.",
#  'L281315': 'Someone broke into the cavern last night.',
#  'L459721': "It's Dave Wilkie! I'm Dave Wilkie, don't you remember me?",
#  'L551555': 'Uh-oh!  Do you know if the demands are being taken seriously at this point, or does Washington think these people are just a bunch of crazy fuckers playing games?',
#  'L451090': "But don't they have it in English?",
#  'L337761': "Disappointing.  It only pulled a fourteen share and they were hoping for a twenty-five minimum, and...ah...they're not very happy and...Well, the guys have decided they want to...ah, re-think the entire concept and...Look, I don't like having to do this, okay?... But...I mean, what I mean is...ah, I'm going to have to...ah, let you go--",
#  'L78778': "I don't like Charles Deetz particularly, but you could have <u>killed</u> him.",
#  'L590031': 'Crony indeed!',
#  'L424069': "I'm not going back on our arrangement. My word is good, and my family owes you. But I think it's best for both of us if you get your own place as soon as you can.",
#  'L276423': "I hear everything. And soon you will know everything. More than you ever wanted I can guarantee that. But I want you to think for a minute first. Think about all you've seen. All the clues you've been given.",
#  'L464039': "Here and there. Restaurant, uh, that's the main expansion. Tables've been moved around; the big man's office, I dunno, might be upstairs now.",
#  'L424010': 'It may not have been an accident. They never did find her head...',
#  'L575131': "That don't mean nothin'.",
#  'L575487': "...I didn't recognize you without the smock. Did I--damn--did I leave something at the shop?",
#  'L59912': "Your attention, please. May I be the first to say, It's a raid!",
#  'L334530': 'It was... it was.',
#  'L552118': "General Ripper, if I shut down the communi- cations center, there'll be no radio or teleprinter contact with Air Command head- quarters or anyone, for that matter.",
#  'L88295': 'What about E.M.S. recombination?',
#  'L307410': "She said the frog came from around the Copper Ridge.  She must've been behind the hill.",
#  'L97624': 'My secret lover.',
#  'L434840': 'Small space?',
#  'L164346': "That isn't it. It's ... the loneliness, Mr. Scratch ... the loneliness!",
#  'L535660': 'Everyone remember where we parked.',
#  'L409991': 'Where was your father born?',
#  'L6390': 'My condolences.',
#  'L402988': 'No, no.',
#  'L118561': 'Done. No matter how clever he is, he still needs an exit visa, or I should say, two.',
#  'L369546': 'Oh!',
#  'L5118': 'Five bills.',
#  'L310500': "I won't thank you! I'll never thank you!",
#  'L14977': "Don't move, any of you. They've gone potty out there. The whole place is surging with girls.",
#  'L662930': 'Its heading for the oil terminal.',
#  'L239936': 'Hittites,  the Mesopotamians and the Sumerians.  "Zuul was the Minion of Gozer."',
#  'L342152': "We don't reckon time the same way, Clarice. This is all the time you'll ever have.",
#  'L332748': "_It's a second REM pattern_.",
#  'L260264': "Hang on Mrs. Pierce.  Not that tie, on the other side.  That's not the only thing your eating Rachel.",
#  'L582499': 'You sure about this?',
#  'L617008': "Of course, I'm always happy. Unless I'm bored.  That blonde Woman, is that your wife?",
#  'L636790': "That's for sure, Frank.",
#  'L304052': 'Alright.',
#  'L349539': 'Tell him how you made me fall in love with you.',
#  'L649759': "That's GREAT!",
#  'L482655': 'Cool it. We got business.',
#  'L30810': 'What you think, Mozart, is scarcely the point. It is what His Majesty thinks that counts.',
#  'L629838': 'I told you what I want.  Lock the door!',
#  'L459859': "Hope for the best? I don't understand all this skepticism. I thought you liked Rose.",
#  'L207168': "Doesn't sound free to me.  So you want me to pay for it?",
#  'L55900': 'Hungry.',
#  'L543001': 'Yes. I have a long ride ahead of me...  Goodbye.',
#  'L128001': '...you answer mine.',
#  'L277973': 'Bill, I...',
#  'L453848': "When you're married you can do a lot of things deliberately.",
#  'L349075': "You've been saying that for twenty years. While we were dating, you said it.",
#  'L576444': "I'm not sure.  We should split up. You take that hall and I'll take this one.",
#  'L312817': "It's Beaumont.",
#  'L375212': 'No, I never read the speeches before I make them. I get more of a kick out of it that way.',
#  'L141359': "Right. The guys who started that did what a lot of companies in the Valley do. They get a good idea, shop it around, raise some capital, then sell it off to a bigger company. Microsoft, Intel, Oracle, whatever. The beauty of it is, they've pretty much sold the company before they're even real. The bigger company is already set to buy it, all they want to do is make sure that the idea actually works. So they get some start up capital, make it work, then sell it for like five times the initial loan.",
#  'L505583': 'Stop crying!',
#  'L613652': 'Do you realize I have light eyes?',
#  'L29239': 'I met a Presidential aide once at a social occasion.',
#  'L456616': 'Shut down?',
#  'L332052': 'Tim!  Lex!',
#  'L199066': 'You leaving that on?',
#  'L173350': "HARRY's treasure chest? Sure. I know where that is.",
#  'L354821': "She'll figure it out sooner or later. I don't have to ask permission anymore, if that's what you mean.",
#  'L419459': 'Will you smile?',
#  'L8637': 'Maybe it was her mother who killed her, with all that Polly Perfect shit.',
#  'L367697': 'I am King, Mother!  And I do not wish to discuss this with you.',
#  'L624898': "There's nothing like them in the fossil record, I'm sure...Okay, so they predate the fossil record...  That'd make them a couple of billion years old...and we've just never seen one till now.  Right.",
#  'L447224': 'I know.  Killaine has a warrant.',
#  'L333933': 'Sure.',
#  'L598849': "I've been worried sick.",
#  'L167440': "For God's sake don't start in on Heidi again ...",
#  'L359367': 'So that means I have to ride with you.',
#  'L443137': 'Yo!',
#  'L568516': "Look around you. See the country you served. Look at people who had real courage, who took risks, who risked their lives. Like Emmi's father.",
#  'L610218': "Then I'm a rich man.",
#  'L251701': "Ben, I think we're two civilized human beings. Do you think it's necessary to threaten each other?",
#  'L520875': "Hi, Mary Lou - Rosella - Okay, Dolores, get a move on - How's your back, Olga?",
#  'L575018': "Why, because you're my security consultant?  This cocksucker nearly burnt my house down.",
#  'L256780': 'Like a club. Work less, make more.',
#  'L557245': "That wasn't me. That guy's gone.  And you're next Webster.",
#  'L125345': 'Yeah. Just checking. He being nice to you, Dil?',
#  'L280066': 'Is there a difference?',
#  'L326941': "Everything's on the fucking run! Everything --",
#  'L12826': "That's illegal, you know.",
#  'L496158': 'Hammer?',
#  'L232112': "It's over.",
#  'L345658': "The Baron is a frightful man.  They say he's an ogre.  He wears a mask so none may see his face.",
#  'L650940': 'Yes, Sir.',
#  'L66916': "I guess Nunez wasn't dead after all. He came after us with a vengeance.  You know the rest.",
#  'L596512': "-- I'm not talking about Max!  To hell with Max!",
#  'L460536': 'Of course.',
#  'L395507': "Fine, fine. Swell, You just showed me a sight lovely to behold, and I'd like to reciprocate. Listen, you hop aboard my magic carpet  thanks - and I'll show you sights that you've never seen before.",
#  'L626589': "Eddie... A guilty client's not the end of the world...",
#  'L278615': 'Okay!  We have TV!  We can all get stupid again!',
#  'L440826': "But he's got lots of other people's lives to ruin...",
#  'L407930': 'Tim studied several styles, but his favorite was Jeet Kune Do.',
#  'L168918': 'It\'s called "The Philosophy of Time Travel".',
#  'L560440': "Easy now, miss, I've got you???",
#  'L462139': 'A new disease.',
#  'L524154': "How would you like to go to the principal's office?",
#  'L295524': "Maybe by that time you'll die of old age. How much do you think you'll, uh, need?",
#  'L149889': 'Need a lift?',
#  'L558018': 'There will be no attack? No attempt to overpower the terrorists?',
#  'L122719': 'Not just that.  Take your time.  Use it. Live it.',
#  'L95393': 'Ah, yes.  The murder.',
#  'L325239': 'It needs more time to charge.',
#  'L166980': "I don't want to be paid.  I'm here with Sal and eight other people ... and we're dyin'!  They're gonna blow our guts out, man!  You're gonna see our brains onna sidewalk! How's that for all you shut-ins and housewives to look at!  You gonna help, or you just put it on instead of AS THE WORLD TURNS?  We're dyin' here!  What have you got for me?",
#  'L294526': 'Yes, darling.',
#  'L138245': 'Who are they, sir?',
#  'L437850': 'I taught him to drink beer.  He taught me how to fly.',
#  'L485982': 'He is.',
#  'L419531': 'No, sir.',
#  'L536093': 'Fundoscopic examination --',
#  'L332571': "No. When you put me on the stand, I'll say your client is catatonic and exhibits classic symptoms of a schizophrenic, sociopathic personality.  And he doesn't sleep.",
#  'L663334': "My God.  Murdered?  -- What's this have to do with Rorschach?",
#  'L305496': "The sun will destroy the blood I've given you. Every tissue, every vein. The fire in this lantern could do that too.",
#  'L522053': "I don't know how you did it, but whatever it was, keep doing it.",
#  'L368169': "Tubbs, it's me.",
#  'L642409': 'You have decided to leave, Moncho.',
#  'L157977': 'Knox, you are so infuriating!',
#  'L458396': 'What was that for? I know you can take punches. I can hit you from now to doomsday. What the fuck does that prove?',
#  'L124158': 'Stop the crying.',
#  'L588022': "You think he's drunk somewhere?",
#  'L348684': "Come on, man, I'm starting to cramp up here.  We have the chance right here, right now, I say we go!",
#  'L263132': "Well, yes, I would if, uh, if it would mean anything to you.  I don't know why it would.",
#  'L296295': 'Wesley!',
#  'L262197': 'Ah! HOLLY  Now.',
#  'L373395': 'You killed them.',
#  'L480565': 'Whatever it is.',
#  'L198351': "What d'you say, Willie?  Tighten her up?",
#  'L650314': "Don't worry about it -",
#  'L373297': "Morpheus believes in you, Neo and no one, not you or even me can convince him otherwise.  He believes it so blindly that he's going to sacrifice his life to save yours.",
#  'L663649': "Christ yes, I went in for a cancer scan first thing.  Gave me a couple of rough nights, I'll tell you . . .  How about you, Laurie?",
#  'L373103': "I know what you're trying to do --",
#  'L637801': "My client can't walk, your Honor.",
#  'L238841': 'Some crank.  Looking for goat hooves.  Come up with anything?',
#  'L338714': 'Yes. It is today.',
#  'L23302': "I've got it.  It's coming from ascension 6 minutes 32 seconds, declination -39 degrees 2 seconds.",
#  'L459930': "Oh-h, I'm sorry. I'm sorry, Mr. Hillyer... I just... couldn't help myself. I'm sorry...",
#  'L646161': 'Anybody want another drink?',
#  'L348700': "We'd be in the hole by now. Hey, man, you're peeing on my shoe.",
#  'L192098': 'But, if he could be turned, he would be a powerful ally.',
#  'L406216': 'Were any of them married?',
#  'L636019': 'Immunity.',
#  'L330467': "That little black line means death for this infant.  The fibula won't heal straight, so the ankle joint can't pivot when he stands on his hind feet.  The baby won't be able to run, and probably can't even walk. It'll be crippled, and a predator will pick it off before it gets more than a few weeks old.",
#  'L324422': 'Did you hear what I said?  Come inside....',
#  'L328823': 'You think they could talk to each other?',
#  'L346655': 'Ow!  Whatever it is, it hurts.',
#  'L225832': "I'm sorry.  I just wanted to surprise you.  What can I say?",
#  'L419323': "Ninotchka, you can't walk out like this... I'm crazy about you, and I thought I'd made an impression on you. You liked the white of my eye.",
#  'L408245': 'I want two men stationed in that tier, and I want men with rifles all along the walkway.',
#  'L236322': 'So you killed them?',
#  'L463601': 'There are monsters...  ...in the gelatin...',
#  'L180468': 'Yes, John?',
#  'L576039': '...You are ze fahzer?',
#  'L611543': 'Medicine. As in medicine man?',
#  'L128446': 'Pappas, that other guy was unloading ice cream into a freezer.  Now, what could he have to do with a military scientist, huh?',
#  'L23791': 'Are you in pain?',
#  'L143678': "Ana paira ninas. Koko's the brains.",
#  'L380365': 'What are you talking about?',
#  'L337964': "I...I don't know...",
#  'L275227': 'Finished?',
#  'L371078': 'You have a certain modest charm yourself.',
#  'L128328': 'Billings?  No, no, no, no, no.  We need to go to McGruder.',
#  'L155241': 'Dave, these things get awfully complicated sometimes...',
#  'L34153': 'Because I want to.',
#  'L392955': 'Chick--turn the ballyhoo boys loose on this right away. Greatest appointment ever made. A banquet-- declare a holiday.',
#  'L313570': 'Make the delivery somewhere in the mall.',
#  'L566177': 'Wait.',
#  'L661451': 'He cribbed that from Borges.',
#  'L202142': "Oh man, I'm gonna enjoy this one... Just remember, Jack, you did this.  You brought this on yourself...",
#  'L258981': 'Mm-hmm.',
#  'L182574': "For Jack, for Stensland, for anybody else who got in the way. I've been trying to be smart.  A detective.  But killing those two fuckers, that would be justice.",
#  'L336627': "I think it's interesting.",
#  'L500395': 'How much?',
#  'L131655': "If you're trying to be funny, Homer...",
#  'L617650': 'Remind me.',
#  'L175938': "You don't wanna be noticed?",
#  'L615555': "Oh, Shortie!--  --there's a girl on this ship--",
#  'L612518': "I don't care.",
#  'L635978': "How many times have you been in a line- up? It's always you and four dummies. The P.D. pays homeless guys ten bucks a head half the time. No way they'd line five felons in the same row. No way. And what the hell is a voice line-.up? A public defender could get you off of that.",
#  'L246589': "You've done a helluva lot more than most people.",
#  'L108098': "You don't know what you're getting into here.",
#  'L144598': 'Not yet.',
#  'L300394': 'He was afraid of you. He knows a tough guy when he sees one.',
#  'L154935': 'Oh my God...',
#  'L310681': 'Hey, you!',
#  'L329478': "I just hope you don't consider her a close friend.",
#  'L327923': "Fuck, yes.  Hell, I'm already in jail.  I got no reason to lie to you.  I ain't no nigger.",
#  'L231931': 'Of course.  He\'s a "de-gene-erate".  He works at Gattaca.  Why else would we find the eyelash near the washroom?  Nobody stops to take a leak during a murder.',
#  'L43921': 'Well, probably.',
#  'L267247': 'Doing what?',
#  'L248286': 'Hey -',
#  'L548925': "Maybe you're upset that Rachel moved in.",
#  'L465553': "You're right, this is bad.  How did you get out?",
#  'L458373': 'Nothing...',
#  'L35355': "You know Dickson as well as we do. He'll shut the doors before he gives up control.",
#  'L242507': "I would say there's nothing more dangerous than a man who knows what 'right' is.",
#  'L340156': "I don't know.",
#  'L644841': "So you say. Nice to meet you; hope you're intelligent. Like these, how'd you get these? ",
#  'L43237': "Whatta-whatta yuh joining a minstrel show? Geez.  Don't worry!  I did it! I killed them both. What- what's the matter? Whatta you-  whatta you sad about? You- What'd you want me to do? Capture 'em and rehabilitate 'em?",
#  'L235613': "It just occurred to me I don't know your first name. All this time and I don't know it.",
#  'L315954': "That's a lie. My family was here.",
#  'L400752': 'Proceed!',
#  'L30115': "Very small pay, I imagine. I'm sure he could be tempted with the right offer. Say, an opera in German for our National Theatre.",
#  'L460487': "No, you're not.",
#  'L627450': "Juno.  I wish I could say it's a pleasure to see you again.",
#  'L433665': "Sounds to me like he liked having you around.  I'll see you, Karen.  Mr. Sisco.",
#  'L27400': "Cassie, thank Christ!  We're under attack.",
#  'L83162': 'Why are you being like this?',
#  'L439038': "Because nothing else matters. That's the great thing about love. Every time we argue, every time something goes wrong, and I know that I'm not perfect either, things just work out better in the end. Cause you're my baby and I love you.",
#  'L137064': 'Did I miss something?',
#  'L664525': 'Treat you like a mutant?  We are not what you think.  Not all of us.',
#  'L526446': "I may not be a pro bowler, but I'm no amateur man. Sheila moves closer to Theo.",
#  'L456152': "I'm detective Jones. Just dropped in to tell you a bit of news.",
#  'L315460': "They weren't human!",
#  'L350172': "I've never been to Earth. I've never even slept over at some other dude's house!",
#  'L68419': "They're just words.",
#  'L428634': 'What?',
#  'L255292': 'Take two, three days. Call when you get there.',
#  'L63904': 'Any time.',
#  'L411185': 'Why do they listen to Guy?',
#  'L552632': "We'll have to leave that up to the C.I.D. boys, won't we, Major?",
#  'L529874': 'Your dog ate it.',
#  'L10831': 'And how do you explain that?',
#  'L326635': '... this is... uh... too funny...',
#  'L602696': 'She usually is.  Trying one way or another to get money out of Wynant. I wanted to find out if you were er - er -  --sleuthing for her.',
#  'L29258': "John Mitchell resigned as head of CREEP to spend more time with his family. That doesn't exactly have the ring of truth.  Howard Hunt's been found--there was talk that his lawyer had 25 thousand in cash in a paper bag.",
#  'L586357': "Hebrew's very difficult. It would take years.",
#  'L169040': 'The old crazy woman who lives off Old Gun Road.',
#  'L222640': 'Soon?',
#  'L369267': 'Can you give me an idea of the conditions...',
#  'L461449': 'You think I made all this up?',
#  'L346': "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  'L254420': "Easy. After all, they ain't but about *twelve* of us, is they?",
#  'L471503': 'Yeah?',
#  'L219662': 'Hey, what are you doing?',
#  'L5546': 'I had the worst goddamn nightmare.',
#  'L380285': "Where's that?",
#  'L36731': "I'm thinking Dorsia.",
#  'L535740': 'The hell you were, buster. Your friend was messing up my tank and messing up my whales...',
#  'L412655': 'Hey, would you look at this crazy car? Everybody has their own radio. What do you think of that?',
#  'L162915': 'Sure.',
#  'L124280': 'Lose the hardware now.',
#  'L564585': 'It should be said that my task is to represent the Walkers only in their anger.  Not their grief.',
#  'L392973': 'Yeah, Dad always used to say the only causes worth fighting for were lost causes.',
#  'L424101': 'Umm...',
#  'L141060': "I'm getting clear of this. If you're not going to do it for the fucking principle, do it for the money. Gordo?",
#  'L302279': 'Remember what?',
#  'L282527': "Well, as long as we're stuck here.",
#  'L99271': 'Did you use it the night Marsh died?',
#  'L161767': 'Just got the call.  Took him from school.  Bastard nailed the Vice- Principal and a teacher.',
#  'L304565': 'Lowell?',
#  'L63211': "Too bad.  How 'bout a dress?",
#  'L393612': 'Thanks a lot.',
#  'L233811': "What, the setup didn't work so you want the key back?",
#  'L627758': "I didn't get any chicken.",
#  'L386571': 'Why should I trust you?',
#  'L354146': 'We should just do it.',
#  'L42604': 'Oh, come on-I mean, I was still younger.',
#  'L329832': 'Is that normal?',
#  'L544242': 'Yes, sir...',
#  'L417344': "I could've saved them.",
#  'L629693': 'Well?',
#  'L349038': "I'd build a house.",
#  'L57542': "Let me guess -- 'Father'?",
#  'L437799': 'Learn English, then!',
#  'L446565': "You don't throw guests out, Brandon.",
#  'L653253': "He's just a regular guy't needs help, honey. Look at him.",
#  'L423850': "Oh, for Chrissakes. It just means the kind of person who can eat shit for a long time without complaining, then cut their momma's throat and go dancing the same night.",
#  'L295719': "I don't know. Never saw him play. They say he's one of the best.",
#  'L221064': "That's a thought, Lil. That sure is a thought.",
#  'L331851': 'Dinosaur eats man.  Woman inherits the Earth.',
#  'L291583': 'Steven --',
#  'L244059': "...you're absolutely right.",
#  'L388289': "I don't know, but Nekhorvich was not a manic.  Get me a twenty on Nyah.",
#  'L64535': 'And so I am.',
#  'L553547': "Come on. I'm not gonna go if you don't come.",
#  'L409297': "How 'bout the key?",
#  'L367548': 'Switch?!  That is your plan?  It is ludicrous!',
#  'L405447': 'Roy --',
#  'L332199': 'Come on, try some.  Take a bite.',
#  'L507334': 'Who\'s the hostage, Sayer, her or you?  You look kind of "captive" yourself.  While you\'re spending every waking hour obsessing over Simone, guess what, I guarantee she doesn\'t even know you exist.  Get off my property or I\'ll call the cops.',
#  'L327623': 'If I were investigatin\', I\'d round up the 100 best riflemen in the world and find out which ones were in Dallas that day.  You been duck hunting?  I think Oswald was a good old-fashioned decoy.  What\'d he say?  "I\'m just a patsy."  Out of the mouth of babes y\'ask me.',
#  'L154630': 'Yeah?',
#  'L490918': 'Fight fair, son...Use your fists!',
#  'L329342': 'When did you decide you were going to do Bleeker?',
#  'L73011': 'Trust me.  Vegetable magnetism.',
#  'L81018': "Yes, Ben told me to be in his room at ten o'clock.",
#  'L584615': "I have no evidence. I saw nothing. I said nothing. It's not my business.",
#  'L522585': 'Koontz!  I need you guys!',
#  'L527131': "Meaning we're never gonna get to the surface alive... to tell anyone.",
#  'L396146': 'Yes, but I',
#  'L636973': "He's not in, Sir.",
#  'L375016': 'Oh, yeah. We made Sourpuss chairman and decided to call ourselves The John Doe Club. And, say, incidentally, this is my wife. Come here, honey.',
#  'L284144': "Well, there's a lot of Communistic sympathizers around --",
#  'L576430': 'A legendary monster called Mbwun.',
# ...
#  'L513400': "He wanted to go off and play, I reckon.  You go in there and you and that Doyle eat ye dinner. You don't have to worry yourself none.",
#  'L278878': "He wasn't there.",
#  'L500347': 'After you drink to love and happiness forever.',
#  'L141561': 'Jake? Customs?',
#  'L448157': "How come I'm still in black and white?",
#  'L134359': "We're not moving! We have a right, a constitutional right, to assemble and be heard!",
#  'L12129': "Got here just in time. Go ahead. Jump in line. Maybe you'll win a prize.",
#  'L226246': "I've seen it.",
#  'L643532': "Have him say, 'I know we're all concerned for the President, there will he an update at 5:45.'",
#  'L572454': 'You pull me up.',
#  'L475887': 'How badly do you want that money?! How bad do you want to stay out of jail?',
#  'L346402': "Don't loose heart... Assemble the archers.  Have everyone not holding a shield man a bow.  Shoot the damned things as they fly.",
#  'L564401': 'How old is she?',
#  'L28409': 'I will not calm down!',
#  'L294728': 'I love you so much, Gabrielle.',
#  'L538663': 'Someone said the difference between comic and cosmic is the letter "S." You haven\'t outlived your usefulness - to me. And you are not responsible just because she is also Vulcan -',
#  'L432263': 'He wants us.',
#  'L489868': 'What the fuck is wrong with you?  What burnt you out?',
#  'L389955': 'Tell me, Charlie. Please.',
#  'L536129': 'Mr. Spock, where the hell is the power you promised me?',
#  'L120456': 'How many of these you gonna eat, huh?',
#  'L231586': "I'll tell you at the end of the week.",
#  'L409527': "What's the matter?! It's a celebration!",
#  'L67861': '.38 revolver.  Never recovered.',
#  'L341798': "Jack Crawford is helping your career, isn't he? Apparently he likes you. And you like him, too.",
#  'L134034': "Hey, you should be more careful. That's my ma and pa.",
#  'L527383': 'Captain, I personally feel we should ask much more substantive questions --',
#  'L62233': "Put that down. It's dirty.",
#  'L477766': 'I worked with Ambassador Han and his family for ten years.  He wanted me to come with them to America.  If I had, this might not have happened.',
#  'L203455': 'Back it down, Johnny!',
#  'L514905': 'Yes, I suppose I do.',
#  'L253252': 'Money -- Ever heard of it?',
#  'L351760': "You're not funny Tom; you're fat and look as though you should be funny, but you're not.",
#  'L433770': "Her phone's probably tapped.",
#  'L24035': "I've got an idea, but you're not going to like it.",
#  'L245734': 'Kay had a miscarriage; she lost the baby.',
#  'L665784': "Don't try to cheer me up that way.",
#  'L82582': "No thanks. I'm going to turn in.",
#  'L642007': 'A black bull!',
#  'L407622': "So can we. So the solution to our little problem is we had them deemed crazy. And we're shippin' 'em to Nystrom Asylum for the criminally insane.",
#  'L565033': "As I'm talking, I'm remembering more about it.",
#  'L341880': "Well, she's not local. Her ears are pierced three times each, and she's wearing green glitter nail polish. Looks like town to me...",
#  'L446864': 'No use waiting, then.',
#  'L10313': "You don't need to know the details of this mission... you're better off if you don't.",
#  'L146561': 'What do you mean not taking your meds?',
#  'L187647': "Bjorn's not. He could have Bjorn's place.",
#  'L448310': "I'm gonna go now.",
#  'L93471': 'Oh, my God!',
#  'L275224': "It's all right, sweetheart. Julia's told me everything; and it's all right...",
#  'L408114': "There's a chocolate cream filled in there?",
#  'L603516': 'Why not?',
#  'L227285': "This is Jason's fault!",
#  'L623760': "I want the money, Mark, that's all.",
#  'L510992': 'No shit.',
#  'L456257': 'So--friendly or otherwise--?',
#  'L192045': 'Stop that.',
#  'L654912': 'Yes.  Mainly to turn her toward the door.  I told her we would talk on Monday, in the office.',
#  'L318025': "No...  That's the sound of the men working on the chain gang.",
#  'L5064': 'You got a very depressing view of life, man... you gotta smile once in awhile...',
#  'L194059': 'Order me a pastrami for after?',
#  'L141164': 'In over your head?',
#  'L315690': "Why the hell we drivin' here?",
#  'L287873': "It's over now, Dennis!  Don't hurt anyone.",
#  'L391487': 'Can you wake up Loretta? I need to talk to her.',
#  'L15407': 'Is he?',
#  'L444623': "Yeah, I'm going to finish what you started --",
#  'L95460': 'You need to come down here, everybody meets everybody.  Ho ho ho.  Ha ha ha. We do one for good faith and then we talk about airplanes.',
#  'L524241': 'I sure did, Phillip!!',
#  'L125633': 'Not if you go.',
#  'L499403': 'It was. What sadness lengthens Romeo\'s hours?"',
#  'L282598': "You won't.",
#  'L27483': 'Oh, man...',
#  'L48359': 'The other one --',
#  'L579146': "He doesn't care.",
#  'L544415': "Rodger Young, prepare to receice outgoing fire...!  I'll take the first group.",
#  'L345873': "You'll visit again?",
#  'L39121': 'Andy? Andy is that you?',
#  'L574676': 'These are not guys you can just go run a number on, man.',
#  'L295874': "I know when to quit. You don't. Win or lose, you don't know when to quit.",
#  'L396428': "I was just telling the woman how I feel, for God's sake.",
#  'L430141': '"Gritty"?  Is this gonna be one of those youth hostel dives jammed with backpackers who don\'t believe in deodorant?',
#  'L538359': 'I believe I am.',
#  'L204109': 'I don\'t know if "we\'ve" noticed, but the sickest runs this side of the Alps are <i>right outside that window</i> --',
#  'L358908': "You're right, but it's funny.  All my life I thought I was simply a man who didn't believe in any of it.",
#  'L391419': 'You mean the whole house?',
#  'L267932': "I--I was wondering--is there anything you shouldn't eat--because of jungle fever?",
#  'L614624': 'Uh, yes. Of course. After you.',
#  'L169801': "I'm down, but for a worthwhile cause.",
#  'L55495': 'Suppose our theorizing is correct? Then this <u>could</u> be the next danger point!',
#  'L548870': "You've got a fruit loop in your hair.",
#  'L249382': 'It was easy money. I did it in the can.  Shit! I learned the junk business in the can, Paulie.',
#  'L253309': 'What is this that you have cancelled your car? Who am I that I should wait like a fool at the door? And here on a whim, you cancel your car. Have you forgotten there is a performance? Do you know the time? Or, are we all mad? Am I your manager?... Have we a contract? Have we obligations? Am I blind?  ...Or is that the time?',
#  'L350817': 'Now will you get in the flask?',
#  'L172661': "You know honey, I've finally figured out a way of bilking enough money from the school to get us that condo in Waikiki.",
#  'L435457': 'You fit the profile, Brother. You look exactly like the kind of nigger they think they can trust...',
#  'L444226': 'I was hoping you were over that. Remember to keep drinking fluids.',
#  'L590017': 'We could do that. But when he had them there, then what?',
#  'L614802': "I don't understand you. It is a fine match with Hockley, and it will insure our survival.",
#  'L368717': "What's one way?",
#  'L357188': "I'm sorry, but we have no doctors here.",
#  'L542014': "You might say I'm part of the landscape here.  They call me Ben Kenobi.",
#  'L219616': 'I love the outfits.',
#  'L315879': "War games? Thailand? That's not true! How can you believe that? Can't you see what they're doing? It's all a lie. We were in Da Nang, for God's sake. You've got to believe me.",
#  'L306504': "I don't need it.",
#  'L229014': 'You... You mean Earth?',
#  'L462781': 'Plato?',
#  'L127570': 'Yes.',
#  'L209077': 'Yeah... Explaining my Position. Some asshole wrote a poem about that once...',
#  'L391038': 'Yes.',
#  'L600936': "But but you're married. You have kids a great wife.",
#  'L283457': 'You -- you --',
#  'L558237': "Because of what I'm betting.  My life.",
#  'L48100': "You'll see soon enough -- get going, sailor --",
#  'L500252': 'Exactly what I was --',
#  'L373394': 'You are a beautiful woman.  Too bad things had to work out like this.',
#  'L270278': 'Well...',
#  'L13906': 'Well, who in particular?',
#  'L409875': "Why don't you come over for a beer when you get through?",
#  'L295036': 'Mother?',
#  'L449580': 'You tell me the fucking truth Johnny... did your parents really die in a car crash?  DID THEY?!',
#  'L41190': "It's no use, Dmitri - we'll never find the right girl!",
#  'L296198': "You didn't drive her mad.",
#  'L403377': 'WHAT??',
#  'L244232': "Don't fuck with me, fella.  I'm talking about a fuckin' Cadillac car that you owe me...",
#  'L439543': "It's a place where the dead speak, Missy.",
#  'L67454': 'Nilsen.',
#  'L115782': "Okay, let's go.",
#  'L461689': 'Did Mr. Doyle think I stole this case.',
#  'L405711': "I'll be down in a jiffy.",
#  'L594002': "Well, then I've got good news for you. We just got word that he'll be making an appearance at the Mall Of America today. I'm sending Esther to meet you there at once.",
#  'L120379': 'I actually turned my bedroom into a bank vault where I kept the choice stuff.',
#  'L7013': "I'm gonna kill you.",
#  'L164428': "Well -- I'll be -- if it isn't little Mary Sampson from Franklin.",
#  'L367623': 'I am so sorry!  Forgive me, I --',
#  'L475006': "Just a thing I was workin' on.",
#  'L611784': 'Ray. X22.',
#  'L545661': 'Ever since I was a little boy, I remember hearing about the family line. The Picards that fought at Trafalgar, the Picards that settled the first Martian colony. When my brother married and had a son...',
#  'L369219': 'Are you queer, Mr. Lounds?',
#  'L332417': 'Really? How much?',
#  'L556192': 'That makes it worse.',
#  'L279375': 'They always seemed...',
#  'L552342': 'He said war was too important a matter to be left to Generals.',
#  'L250991': '-- of bring -- inadequate -- I mean just because you happen to be inadequate in one way --',
#  'L594908': "Well, now that you've had your history lesson, I think I'll get on to the museum.",
#  'L93426': "And I think better than the ocean. I'm serious!",
#  'L329560': "The tough part's almost over for you. I mean, my girlfriends always tell me the first couple months are the hardest.",
#  'L664775': 'Been to any good diners lately?',
#  'L254889': 'We gonna live here?',
#  'L346095': "Or was it the time you and Jimmy Squarefoot stole the golden apples I'd forged.",
#  'L219514': "Thanks, Doc. Maybe I'll come back with a date. Or an elephant.",
#  'L622369': 'One question.  How did you find about this?',
#  'L480588': 'Not.',
#  'L661834': "Don't tell me I'm not a fucking asshole when I know I'm a fucking asshole!",
#  'L238843': 'You might want to check those Duke University mean averaging studies on controlled psychokinesis.',
#  'L292296': 'Jesus Christ ...',
#  'L325901': 'You find something curious in that?',
#  'L645406': "Are you mad! Why are you doing this! We're so close, the town is going to be ours. Don't throw away your future Bud!",
#  'L76919': 'Who sent ya?',
#  'L630866': 'Lay off the bennies, Leo.',
#  'L461293': 'You mean "goodnight."',
#  'L303657': "We're not moving fast enough for him.",
#  'L2601': 'Maybe you could just put in a shot of Martell?',
#  'L434714': 'What?',
#  'L645330': "Your responsibility, Dad, is to present the facts, not your opinions, to the men... you're gonna destroy their lives, Dad! Don't do it to 'em. Give it a chance. Let the membership decide for themselves, Dad. Please.",
#  'L84060': "Didn't kill anything, did I?",
#  'L244297': "They stole the phones.  They stole the leads.  They're...Christ.  What am I going to do this month? Oh, shit... ",
#  'L14906': "Oh, not at all, I let them have twenty-five; sure aren't there four of them?",
#  'L308843': "I don't really know where Thea comes from. The ViceConsul at Adrianople brought her to me..",
#  'L10330': "Well, yeah, but the tether off it ain't gonna be fancy.  When he gets down there he'll just sit, like a dumb-shit.  Unless something wanders through view of the camera, you'll get nada.",
#  'L480133': 'Me, either.',
#  'L227628': "This is not me! I am a professional fucking thief. I steal money. You try to stop me, god help you. But I don't kill people I don't have to, and I don't rape women. What you doin' ain't how it's done. Do you understand?",
#  'L318157': 'Damnit to hell, you left me back there to die!',
#  'L583682': "That wasn't a fucking restraint.",
#  'L326461': "You ain't talking to no one, till you calm down.",
#  'L110978': 'What?  Look, let me use the console for a few minutes.',
#  'L229532': "It doesn't have eyes.",
#  'L244241': 'The...',
#  'L662635': 'Who?',
#  'L566168': "We're going to Vegas.",
#  'L436503': 'Unless you would like to claim aggrieved status.',
#  'L262929': 'Thanks.  But guess who was there auditioning?',
#  'L270247': 'What do you think?',
#  'L437630': "Danny's not coming?",
#  'L168787': 'I met a girl.',
#  'L609854': 'What the hell are you doing!?',
#  'L559103': "Where's Clark?",
#  'L157867': 'We thought it would be good to break old habits, sir.',
#  'L10799': "But Anna wouldn't be staying with the kind of people who live here.",
#  'L230873': 'Who is that young man?',
#  'L123041': "Oh Frank, I'm not anti-male, I'm anti- you. Believe me, there's a difference.  Kelly is designing new uniforms for next week. Pay her and thank her. And is it a rule that the hottest places on the planet have the coldest air conditioning.  There's something out there called 73 degrees, look into it.",
#  'L463554': 'For twenty-five, she sounds pretty mature.',
#  'L403647': 'Well, even without anesthesia I always tell my patients to...eh... to relax.',
#  'L42550': "We've been through this.",
#  'L400800': 'I only gamble with my life, never my money.',
#  'L229931': 'You mean the World Series? I thought the Red Sox were winning.',
#  'L536326': 'You either need a new uniform or a new neck.',
#  'L648204': 'Seance.',
#  'L170929': "Go on home, Loretta. Come on. Go on, the party's over.",
#  'L78883': "I'm so sorry we frightened you. What were you doing?",
#  'L611884': "I took him out before he got the chance. He didn't say nothin' about Tashka Sha. And now his spirit is in the dirt. Forever.",
#  'L414981': 'Taste it.',
#  'L661837': 'Do you?',
#  'L450125': "I don't think that was any ordinary army taxi...",
#  'L400553': 'Not me... all my other my patients. I smelled tar and feathers on the way over here.',
#  'L5221': 'Fuck you.',
#  'L315874': "I'll tell you what's gotten into me. I don't know you from Adam, right? You come to my office with this bizarro story and demand I look into it. Okay. I said I'd check it out and I did. Now I don't know what kind of fool you take me for, but you have used and abused me, and I don't like it.",
#  'L376750': "He had no choice.  You're a formidable adversary.",
#  'L470390': 'It did.',
#  'L10785': 'Take it easy, Raimondo. Why are you getting so impatient?',
#  'L255254': "It's not your fault.",
#  'L382007': "As far as I can tell, the guy's what he says he is - alone, and unarmed.  All he wants is five minutes to introduce himself to the public.",
#  'L463777': 'So you could get with my sister.',
#  'L644569': 'You got a dime....?',
#  'L325967': "It's not your friend. It keeps you sucking. Remem- ber the old Bum's lungs?",
#  'L23985': 'Nothing.',
#  'L601285': "C'mon, you can do better than that. We ain't no heel grifters.",
#  'L232329': 'What can he do?  The British have massive superiority.',
#  'L255777': "If you come out to the track, don't know me.",
#  'L66776': "It's over. Time of death was 4:42. JAG's been notified and I called the Senator myself. My report will reflect that his medical condition made this unavoidable... you two had no culpability in the matter.",
#  'L601546': 'Had a little fight with a raggle down on 13th.  She got me with her ring.',
#  'L14665': "I didn't guess until it was too late.",
#  'L648368': 'The planchette?',
#  'L270641': 'Oh, no. But I should have liked to have been an astronaut. A private astronaut able to just go out and explore. Like the men who sailed with Magellan, I want to see if we really can fall off the edge of the world.  What a joke it will be if like them I -',
#  'L30976': 'Behold!',
#  'L260018': 'You locked yourself in.',
#  'L599850': 'Uh-huh.',
#  'L595932': "Can we go now, huh? LUCY Maybe later.  Grandpa's expecting us.",
#  'L160780': 'Well... you remember Cynthia?',
#  ...}

# %%
conversations[0].split(" +++$+++ ")[-1][1:-1].replace("'","").replace(" ","")
# Out:
# 'L194,L195,L196,L197'

# %%
conversations_ids=[]
for conversation in conversations[:-1]:
    _conversation=conversation.split(" +++$+++ ")[-1][1:-1].replace("'","").replace(" ","")
    conversations_ids.append(_conversation.split(","))

# %%
conversations_ids
# Out:
# [['L194', 'L195', 'L196', 'L197'],
#  ['L198', 'L199'],
#  ['L200', 'L201', 'L202', 'L203'],
#  ['L204', 'L205', 'L206'],
#  ['L207', 'L208'],
#  ['L271', 'L272', 'L273', 'L274', 'L275'],
#  ['L276', 'L277'],
#  ['L280', 'L281'],
#  ['L363', 'L364'],
#  ['L365', 'L366'],
#  ['L367', 'L368'],
#  ['L401', 'L402', 'L403'],
#  ['L404', 'L405', 'L406', 'L407'],
#  ['L575', 'L576'],
#  ['L577', 'L578'],
#  ['L662', 'L663'],
#  ['L693', 'L694', 'L695'],
#  ['L696', 'L697', 'L698', 'L699'],
#  ['L860', 'L861'],
#  ['L862', 'L863', 'L864', 'L865'],
#  ['L866', 'L867', 'L868', 'L869'],
#  ['L870', 'L871', 'L872'],
#  ['L924', 'L925'],
#  ['L984', 'L985'],
#  ['L1044', 'L1045'],
#  ['L49', 'L50', 'L51'],
#  ['L571', 'L572', 'L573'],
#  ['L579', 'L580'],
#  ['L595', 'L596', 'L597'],
#  ['L598', 'L599', 'L600'],
#  ['L659', 'L660'],
#  ['L952', 'L953'],
#  ['L394', 'L395'],
#  ['L396', 'L397'],
#  ['L589', 'L590', 'L591'],
#  ['L592', 'L593'],
#  ['L756', 'L757', 'L758'],
#  ['L759', 'L760'],
#  ['L164', 'L165'],
#  ['L319', 'L320'],
#  ['L441', 'L442', 'L443', 'L444', 'L445'],
#  ['L525', 'L526', 'L527'],
#  ['L529', 'L530'],
#  ['L531', 'L532', 'L533'],
#  ['L542', 'L543'],
#  ['L601', 'L602'],
#  ['L655', 'L656'],
#  ['L889', 'L890', 'L891', 'L892'],
#  ['L893', 'L894', 'L895', 'L896', 'L897', 'L898', 'L899', 'L900'],
#  ['L901', 'L902', 'L903'],
#  ['L904', 'L905', 'L906', 'L907', 'L908'],
#  ['L909', 'L910', 'L911', 'L912', 'L913', 'L914'],
#  ['L982', 'L983'],
#  ['L1007', 'L1008', 'L1009', 'L1010', 'L1011'],
#  ['L1021', 'L1022'],
#  ['L1051', 'L1052'],
#  ['L179', 'L180', 'L181', 'L182', 'L183'],
#  ['L189', 'L190'],
#  ['L517', 'L518', 'L519', 'L520', 'L521'],
#  ['L523', 'L524'],
#  ['L536', 'L537'],
#  ['L538', 'L539', 'L540'],
#  ['L544', 'L545', 'L546'],
#  ['L878', 'L879', 'L880', 'L881', 'L882', 'L883', 'L884'],
#  ['L922', 'L923'],
#  ['L458', 'L459', 'L460', 'L461', 'L462', 'L463'],
#  ['L63', 'L64', 'L65'],
#  ['L66', 'L67', 'L68', 'L69', 'L70', 'L71', 'L72', 'L73', 'L74'],
#  ['L77', 'L78'],
#  ['L87', 'L88', 'L89', 'L90', 'L91', 'L92'],
#  ['L139', 'L140', 'L141', 'L142'],
#  ['L143', 'L144', 'L145', 'L146', 'L147'],
#  ['L157', 'L158', 'L159'],
#  ['L210', 'L211'],
#  ['L212', 'L213'],
#  ['L215', 'L216', 'L217', 'L218', 'L219', 'L220', 'L221', 'L222'],
#  ['L223', 'L224', 'L225'],
#  ['L244', 'L245'],
#  ['L388', 'L389', 'L390', 'L391'],
#  ['L416', 'L417', 'L418', 'L419'],
#  ['L424', 'L425'],
#  ['L432', 'L433'],
#  ['L499', 'L500'],
#  ['L583', 'L584', 'L585', 'L586'],
#  ['L778', 'L779'],
#  ['L385', 'L386'],
#  ['L411', 'L412'],
#  ['L426', 'L427'],
#  ['L430', 'L431'],
#  ['L619', 'L620'],
#  ['L621', 'L622'],
#  ['L623', 'L624', 'L625'],
#  ['L725', 'L726'],
#  ['L740', 'L741'],
#  ['L743', 'L744', 'L745'],
#  ['L780', 'L781'],
#  ['L148', 'L149', 'L150'],
#  ['L335', 'L336'],
#  ['L554', 'L555', 'L556'],
#  ['L557', 'L558'],
#  ['L285', 'L286'],
#  ['L287', 'L288', 'L289', 'L290', 'L291', 'L292'],
#  ['L294', 'L295', 'L296', 'L297'],
#  ['L298', 'L299'],
#  ['L300', 'L301'],
#  ['L349', 'L350', 'L351', 'L352'],
#  ['L354', 'L355', 'L356', 'L357', 'L358'],
#  ['L605', 'L606'],
#  ['L607', 'L608', 'L609'],
#  ['L747', 'L748'],
#  ['L231', 'L232', 'L233', 'L234', 'L235', 'L236'],
#  ['L238', 'L239', 'L240'],
#  ['L502', 'L503', 'L504', 'L505'],
#  ['L508', 'L509'],
#  ['L123', 'L124', 'L125', 'L126', 'L127', 'L128'],
#  ['L129', 'L130'],
#  ['L131', 'L132'],
#  ['L133', 'L134'],
#  ['L151', 'L152'],
#  ['L247', 'L248', 'L249', 'L250', 'L251'],
#  ['L252', 'L253', 'L254'],
#  ['L447', 'L448'],
#  ['L490', 'L491'],
#  ['L716', 'L717', 'L718', 'L719', 'L720', 'L721'],
#  ['L750', 'L751', 'L752', 'L753', 'L754', 'L755'],
#  ['L946', 'L947', 'L948', 'L949'],
#  ['L304', 'L305', 'L306', 'L307'],
#  ['L309', 'L310'],
#  ['L311', 'L312', 'L313'],
#  ['L322', 'L323', 'L324', 'L325', 'L326', 'L327', 'L328'],
#  ['L330', 'L331', 'L332'],
#  ['L333', 'L334'],
#  ['L473', 'L474'],
#  ['L475', 'L476', 'L477'],
#  ['L481', 'L482', 'L483'],
#  ['L564', 'L565', 'L566', 'L567'],
#  ['L610', 'L611'],
#  ['L612', 'L613', 'L614', 'L615', 'L616'],
#  ['L626',
#   'L627',
#   'L628',
#   'L629',
#   'L630',
#   'L631',
#   'L632',
#   'L633',
#   'L634',
#   'L635',
#   'L636'],
#  ['L639', 'L640', 'L641', 'L642', 'L643', 'L644', 'L645', 'L646'],
#  ['L650', 'L651'],
#  ['L668', 'L669'],
#  ['L670', 'L671', 'L672', 'L673', 'L674', 'L675', 'L676'],
#  ['L677', 'L678', 'L679'],
#  ['L680', 'L681', 'L682'],
#  ['L683', 'L684'],
#  ['L686', 'L687', 'L688', 'L689', 'L690'],
#  ['L764', 'L765', 'L766', 'L767', 'L768'],
#  ['L769', 'L770', 'L771', 'L772', 'L773', 'L774'],
#  ['L798', 'L799'],
#  ['L800', 'L801', 'L802'],
#  ['L803', 'L804', 'L805', 'L806'],
#  ['L808', 'L809', 'L810', 'L811', 'L812'],
#  ['L813',
#   'L814',
#   'L815',
#   'L816',
#   'L817',
#   'L818',
#   'L819',
#   'L820',
#   'L821',
#   'L822',
#   'L823'],
#  ['L824', 'L825'],
#  ['L828', 'L829', 'L830', 'L831', 'L832'],
#  ['L834', 'L835', 'L836', 'L837', 'L838', 'L839', 'L840', 'L841'],
#  ['L842', 'L843', 'L844', 'L845', 'L846', 'L847', 'L848'],
#  ['L852', 'L853', 'L854', 'L855', 'L856', 'L857'],
#  ['L936', 'L937', 'L938', 'L939', 'L940'],
#  ['L957', 'L958', 'L959'],
#  ['L960', 'L961'],
#  ['L973', 'L974', 'L975', 'L976', 'L977'],
#  ['L1031', 'L1032'],
#  ['L1033', 'L1034', 'L1035'],
#  ['L1040', 'L1041', 'L1042', 'L1043'],
#  ['L172', 'L173', 'L174'],
#  ['L184', 'L185'],
#  ['L338',
#   'L339',
#   'L340',
#   'L341',
#   'L342',
#   'L343',
#   'L344',
#   'L345',
#   'L346',
#   'L347'],
#  ['L986', 'L987', 'L988'],
#  ['L989', 'L990', 'L991', 'L992', 'L993', 'L994', 'L995', 'L996', 'L997'],
#  ['L998', 'L999', 'L1000'],
#  ['L103', 'L104', 'L105', 'L106', 'L107'],
#  ['L108', 'L109'],
#  ['L1017', 'L1018'],
#  ['L728', 'L729', 'L730', 'L731'],
#  ['L732', 'L733'],
#  ['L735', 'L736', 'L737', 'L738'],
#  ['L371', 'L372', 'L373'],
#  ['L375', 'L376', 'L377'],
#  ['L378', 'L379'],
#  ['L380', 'L381', 'L382'],
#  ['L383', 'L384'],
#  ['L414', 'L415'],
#  ['L420', 'L421'],
#  ['L428', 'L429'],
#  ['L436', 'L437'],
#  ['L723', 'L724'],
#  ['L775', 'L776', 'L777'],
#  ['L59', 'L60', 'L61', 'L62'],
#  ['L257', 'L258', 'L259'],
#  ['L261', 'L262', 'L263', 'L264'],
#  ['L511', 'L512'],
#  ['L161', 'L162'],
#  ['L170', 'L171'],
#  ['L191', 'L192', 'L193'],
#  ['L876', 'L877'],
#  ['L886', 'L887'],
#  ['L917', 'L918'],
#  ['L926', 'L927'],
#  ['L929', 'L930', 'L931', 'L932', 'L933'],
#  ['L2170', 'L2171', 'L2172'],
#  ['L2173', 'L2174', 'L2175'],
#  ['L2176', 'L2177'],
#  ['L2179', 'L2180', 'L2181'],
#  ['L1989', 'L1990', 'L1991', 'L1992', 'L1993'],
#  ['L2005', 'L2006'],
#  ['L2010', 'L2011', 'L2012'],
#  ['L2014', 'L2015', 'L2016'],
#  ['L2019', 'L2020'],
#  ['L2022', 'L2023'],
#  ['L2024', 'L2025'],
#  ['L2027', 'L2028', 'L2029'],
#  ['L2030', 'L2031'],
#  ['L2274', 'L2275'],
#  ['L2522', 'L2523', 'L2524'],
#  ['L1979', 'L1980', 'L1981', 'L1982', 'L1983', 'L1984'],
#  ['L1985', 'L1986'],
#  ['L2118', 'L2119'],
#  ['L2121', 'L2122', 'L2123'],
#  ['L2318', 'L2319', 'L2320'],
#  ['L2471', 'L2472'],
#  ['L2473', 'L2474'],
#  ['L2537', 'L2538'],
#  ['L2539', 'L2540'],
#  ['L2290', 'L2291', 'L2292', 'L2293'],
#  ['L2421', 'L2422'],
#  ['L2423', 'L2424', 'L2425', 'L2426'],
#  ['L2429', 'L2430', 'L2431', 'L2432'],
#  ['L2127', 'L2128', 'L2129'],
#  ['L2130', 'L2131'],
#  ['L2439', 'L2440'],
#  ['L2484', 'L2485'],
#  ['L2500', 'L2501'],
#  ['L2541', 'L2542'],
#  ['L2547', 'L2548', 'L2549'],
#  ['L2550', 'L2551', 'L2552'],
#  ['L2103', 'L2104', 'L2105'],
#  ['L2106', 'L2107', 'L2108'],
#  ['L2109', 'L2110'],
#  ['L2281', 'L2282'],
#  ['L2286', 'L2287'],
#  ['L2295', 'L2296', 'L2297'],
#  ['L2299', 'L2300', 'L2301'],
#  ['L2463', 'L2464'],
#  ['L2465', 'L2466'],
#  ['L2467', 'L2468', 'L2469'],
#  ['L2237', 'L2238', 'L2239'],
#  ['L2248', 'L2249', 'L2250', 'L2251'],
#  ['L2253', 'L2254', 'L2255'],
#  ['L2256', 'L2257', 'L2258', 'L2259', 'L2260'],
#  ['L2341', 'L2342', 'L2343'],
#  ['L2393', 'L2394'],
#  ['L2409', 'L2410'],
#  ['L1942', 'L1943'],
#  ['L1947', 'L1948', 'L1949', 'L1950'],
#  ['L1951', 'L1952'],
#  ['L1957', 'L1958', 'L1959', 'L1960', 'L1961', 'L1962'],
#  ['L1963', 'L1964', 'L1965', 'L1966', 'L1967', 'L1968', 'L1969'],
#  ['L2037', 'L2038', 'L2039', 'L2040'],
#  ['L2041', 'L2042'],
#  ['L2045', 'L2046'],
#  ['L2132', 'L2133'],
#  ['L2134', 'L2135', 'L2136', 'L2137', 'L2138', 'L2139'],
#  ['L2140', 'L2141', 'L2142', 'L2143'],
#  ['L2144', 'L2145'],
#  ['L2525', 'L2526'],
#  ['L2531', 'L2532', 'L2533', 'L2534', 'L2535'],
#  ['L2071', 'L2072'],
#  ['L2073', 'L2074', 'L2075'],
#  ['L2076', 'L2077'],
#  ['L2079', 'L2080', 'L2081', 'L2082'],
#  ['L2085', 'L2086'],
#  ['L2279', 'L2280'],
#  ['L2456', 'L2457', 'L2458', 'L2459'],
#  ['L2277', 'L2278'],
#  ['L2328', 'L2329'],
#  ['L2331', 'L2332', 'L2333'],
#  ['L2345', 'L2346'],
#  ['L2347', 'L2348'],
#  ['L2386', 'L2387', 'L2388', 'L2389'],
#  ['L2154', 'L2155'],
#  ['L2157', 'L2158', 'L2159', 'L2160'],
#  ['L2164', 'L2165'],
#  ['L2490', 'L2491', 'L2492'],
#  ['L2064', 'L2065'],
#  ['L2196',
#   'L2197',
#   'L2198',
#   'L2199',
#   'L2200',
#   'L2201',
#   'L2202',
#   'L2203',
#   'L2204',
#   'L2205',
#   'L2206',
#   'L2207',
#   'L2208',
#   'L2209',
#   'L2210',
#   'L2211'],
#  ['L1930', 'L1931'],
#  ['L2112', 'L2113'],
#  ['L2115', 'L2116'],
#  ['L2376', 'L2377'],
#  ['L2414', 'L2415'],
#  ['L2417', 'L2418', 'L2419'],
#  ['L2460', 'L2461', 'L2462'],
#  ['L3380', 'L3381', 'L3382'],
#  ['L3383', 'L3384', 'L3385'],
#  ['L3392', 'L3393', 'L3394', 'L3395', 'L3396'],
#  ['L3459', 'L3460', 'L3461'],
#  ['L3464',
#   'L3465',
#   'L3466',
#   'L3467',
#   'L3468',
#   'L3469',
#   'L3470',
#   'L3471',
#   'L3472',
#   'L3473',
#   'L3474',
#   'L3475',
#   'L3476',
#   'L3477',
#   'L3478',
#   'L3479',
#   'L3480',
#   'L3481'],
#  ['L3482', 'L3483', 'L3484', 'L3485', 'L3486', 'L3487', 'L3488', 'L3489'],
#  ['L3490', 'L3491', 'L3492', 'L3493'],
#  ['L3496', 'L3497'],
#  ['L3545', 'L3546'],
#  ['L3059', 'L3060', 'L3061'],
#  ['L3089', 'L3090', 'L3091', 'L3092'],
#  ['L3093', 'L3094', 'L3095'],
#  ['L3096', 'L3097'],
#  ['L3158', 'L3159', 'L3160'],
#  ['L3161', 'L3162', 'L3163', 'L3164', 'L3165', 'L3166'],
#  ['L3167', 'L3168', 'L3169', 'L3170'],
#  ['L3177', 'L3178', 'L3179', 'L3180', 'L3181'],
#  ['L3300', 'L3301', 'L3302'],
#  ['L3305', 'L3306', 'L3307', 'L3308'],
#  ['L3309', 'L3310', 'L3311'],
#  ['L3313', 'L3314'],
#  ['L3315', 'L3316', 'L3317', 'L3318'],
#  ['L3329', 'L3330'],
#  ['L3514', 'L3515', 'L3516', 'L3517'],
#  ['L3045', 'L3046', 'L3047', 'L3048'],
#  ['L3049', 'L3050', 'L3051'],
#  ['L3055', 'L3056'],
#  ['L3062', 'L3063', 'L3064', 'L3065'],
#  ['L3208', 'L3209', 'L3210', 'L3211', 'L3212', 'L3213', 'L3214'],
#  ['L2797', 'L2798', 'L2799', 'L2800'],
#  ['L3196', 'L3197'],
#  ['L3198', 'L3199', 'L3200', 'L3201', 'L3202', 'L3203'],
#  ['L3293', 'L3294'],
#  ['L3498',
#   'L3499',
#   'L3500',
#   'L3501',
#   'L3502',
#   'L3503',
#   'L3504',
#   'L3505',
#   'L3506'],
#  ['L2801', 'L2802', 'L2803', 'L2804', 'L2805'],
#  ['L3289', 'L3290', 'L3291', 'L3292'],
#  ['L2599', 'L2600', 'L2601'],
#  ['L2602', 'L2603'],
#  ['L2630', 'L2631', 'L2632', 'L2633'],
#  ['L2751', 'L2752'],
#  ['L2920', 'L2921', 'L2922', 'L2923'],
#  ['L2924', 'L2925'],
#  ['L2936', 'L2937', 'L2938'],
#  ['L3016', 'L3017'],
#  ['L3022', 'L3023'],
#  ['L3027', 'L3028'],
#  ['L2964', 'L2965', 'L2966', 'L2967'],
#  ['L2971', 'L2972', 'L2973'],
#  ['L2975', 'L2976', 'L2977', 'L2978'],
#  ['L2979', 'L2980', 'L2981'],
#  ['L2986', 'L2987', 'L2988', 'L2989', 'L2990'],
#  ['L2730', 'L2731'],
#  ['L2746', 'L2747', 'L2748'],
#  ['L2875', 'L2876', 'L2877', 'L2878', 'L2879', 'L2880', 'L2881', 'L2882'],
#  ['L2883', 'L2884', 'L2885', 'L2886'],
#  ['L2887', 'L2888', 'L2889', 'L2890', 'L2891'],
#  ['L2892', 'L2893'],
#  ['L2895', 'L2896', 'L2897'],
#  ['L2899', 'L2900', 'L2901', 'L2902', 'L2903', 'L2904', 'L2905', 'L2906'],
#  ['L2949', 'L2950', 'L2951', 'L2952', 'L2953'],
#  ['L2955', 'L2956', 'L2957', 'L2958'],
#  ['L2962', 'L2963'],
#  ['L2991', 'L2992'],
#  ['L2993', 'L2994', 'L2995', 'L2996', 'L2997', 'L2998', 'L2999'],
#  ['L3052', 'L3053', 'L3054'],
#  ['L3057', 'L3058'],
#  ['L3067', 'L3068'],
#  ['L3069',
#   'L3070',
#   'L3071',
#   'L3072',
#   'L3073',
#   'L3074',
#   'L3075',
#   'L3076',
#   'L3077',
#   'L3078',
#   'L3079'],
#  ['L3080', 'L3081', 'L3082'],
#  ['L3219', 'L3220', 'L3221', 'L3222'],
#  ['L3223', 'L3224', 'L3225', 'L3226', 'L3227', 'L3228'],
#  ['L3229', 'L3230'],
#  ['L3236', 'L3237', 'L3238', 'L3239', 'L3240', 'L3241', 'L3242'],
#  ['L3243', 'L3244'],
#  ['L3248', 'L3249'],
#  ['L2758', 'L2759', 'L2760', 'L2761', 'L2762', 'L2763', 'L2764', 'L2765'],
#  ['L3029', 'L3030'],
#  ['L3031', 'L3032', 'L3033', 'L3034', 'L3035', 'L3036', 'L3037'],
#  ['L3038', 'L3039', 'L3040', 'L3041', 'L3042', 'L3043', 'L3044'],
#  ['L3101', 'L3102'],
#  ['L3103',
#   'L3104',
#   'L3105',
#   'L3106',
#   'L3107',
#   'L3108',
#   'L3109',
#   'L3110',
#   'L3111',
#   'L3112',
#   'L3113',
#   'L3114',
#   'L3115',
#   'L3116',
#   'L3117'],
#  ['L3119', 'L3120', 'L3121'],
#  ['L3126', 'L3127', 'L3128', 'L3129', 'L3130'],
#  ['L3135',
#   'L3136',
#   'L3137',
#   'L3138',
#   'L3139',
#   'L3140',
#   'L3141',
#   'L3142',
#   'L3143',
#   'L3144',
#   'L3145',
#   'L3146',
#   'L3147'],
#  ['L3148',
#   'L3149',
#   'L3150',
#   'L3151',
#   'L3152',
#   'L3153',
#   'L3154',
#   'L3155',
#   'L3156',
#   'L3157'],
#  ['L2595', 'L2596'],
#  ['L2604', 'L2605', 'L2606', 'L2607'],
#  ['L2611', 'L2612'],
#  ['L2644', 'L2645'],
#  ['L2646', 'L2647', 'L2648'],
#  ['L2651', 'L2652'],
#  ['L2653', 'L2654', 'L2655', 'L2656'],
#  ['L2664', 'L2665'],
#  ['L2621', 'L2622', 'L2623', 'L2624', 'L2625', 'L2626'],
#  ['L2627', 'L2628'],
#  ['L3278',
#   'L3279',
#   'L3280',
#   'L3281',
#   'L3282',
#   'L3283',
#   'L3284',
#   'L3285',
#   'L3286'],
#  ['L3419', 'L3420', 'L3421'],
#  ['L3431', 'L3432'],
#  ['L3433', 'L3434'],
#  ['L3435', 'L3436'],
#  ['L3554', 'L3555', 'L3556'],
#  ['L2845', 'L2846', 'L2847'],
#  ['L2848', 'L2849'],
#  ['L2850', 'L2851', 'L2852', 'L2853', 'L2854'],
#  ['L2855', 'L2856'],
#  ['L2857', 'L2858'],
#  ['L2563', 'L2564'],
#  ['L2565', 'L2566', 'L2567', 'L2568', 'L2569'],
#  ['L2570', 'L2571', 'L2572', 'L2573', 'L2574'],
#  ['L2577', 'L2578', 'L2579', 'L2580', 'L2581'],
#  ['L2908', 'L2909'],
#  ['L2910', 'L2911', 'L2912', 'L2913', 'L2914', 'L2915'],
#  ['L2557', 'L2558'],
#  ['L2559', 'L2560'],
#  ['L2561', 'L2562'],
#  ['L2635', 'L2636', 'L2637', 'L2638'],
#  ['L2639', 'L2640'],
#  ['L2666', 'L2667', 'L2668'],
#  ['L2670', 'L2671'],
#  ['L2778', 'L2779'],
#  ['L2780', 'L2781', 'L2782', 'L2783'],
#  ['L2789', 'L2790'],
#  ['L2842', 'L2843', 'L2844'],
#  ['L3083', 'L3084', 'L3085'],
#  ['L3087', 'L3088'],
#  ['L3183', 'L3184', 'L3185', 'L3186', 'L3187', 'L3188'],
#  ['L3189', 'L3190'],
#  ['L3191', 'L3192', 'L3193'],
#  ['L3246', 'L3247'],
#  ['L3250', 'L3251'],
#  ['L3356', 'L3357'],
#  ['L3359', 'L3360'],
#  ['L3361', 'L3362'],
#  ['L3363', 'L3364'],
#  ['L3365', 'L3366'],
#  ['L3368', 'L3369', 'L3370'],
#  ['L3372', 'L3373', 'L3374', 'L3375'],
#  ['L3376', 'L3377', 'L3378'],
#  ['L3547', 'L3548'],
#  ['L2672', 'L2673'],
#  ['L2674', 'L2675', 'L2676'],
#  ['L2678', 'L2679'],
#  ['L2680', 'L2681', 'L2682'],
#  ['L2685', 'L2686', 'L2687', 'L2688', 'L2689', 'L2690', 'L2691', 'L2692'],
#  ['L3271', 'L3272', 'L3273', 'L3274', 'L3275'],
#  ['L3352', 'L3353'],
#  ['L2608', 'L2609', 'L2610'],
#  ['L2614', 'L2615'],
#  ['L3409', 'L3410'],
#  ['L3411', 'L3412', 'L3413'],
#  ['L3262', 'L3263', 'L3264', 'L3265', 'L3266', 'L3267', 'L3268', 'L3269'],
#  ['L2575', 'L2576'],
#  ['L2582',
#   'L2583',
#   'L2584',
#   'L2585',
#   'L2586',
#   'L2587',
#   'L2588',
#   'L2589',
#   'L2590',
#   'L2591'],
#  ['L2732', 'L2733'],
#  ['L2740', 'L2741', 'L2742', 'L2743'],
#  ['L2744', 'L2745'],
#  ['L3398', 'L3399', 'L3400', 'L3401', 'L3402', 'L3403'],
#  ['L2698', 'L2699', 'L2700'],
#  ['L2701', 'L2702', 'L2703'],
#  ['L2706', 'L2707'],
#  ['L2771', 'L2772', 'L2773'],
#  ['L2808', 'L2809', 'L2810', 'L2811', 'L2812', 'L2813'],
#  ['L2715', 'L2716', 'L2717', 'L2718', 'L2719', 'L2720', 'L2721'],
#  ['L2724', 'L2725'],
#  ['L2735', 'L2736', 'L2737'],
#  ['L2738', 'L2739'],
#  ['L2754', 'L2755', 'L2756', 'L2757'],
#  ['L2767', 'L2768'],
#  ['L2793', 'L2794', 'L2795'],
#  ['L2863', 'L2864', 'L2865'],
#  ['L2870', 'L2871', 'L2872'],
#  ['L3024', 'L3025', 'L3026'],
#  ['L3287', 'L3288'],
#  ['L3342', 'L3343', 'L3344'],
#  ['L2928', 'L2929', 'L2930'],
#  ['L3422', 'L3423', 'L3424'],
#  ['L3425', 'L3426', 'L3427'],
#  ['L2828',
#   'L2829',
#   'L2830',
#   'L2831',
#   'L2832',
#   'L2833',
#   'L2834',
#   'L2835',
#   'L2836',
#   'L2837',
#   'L2838',
#   'L2839',
#   'L2840'],
#  ['L3712', 'L3713'],
#  ['L3720', 'L3721'],
#  ['L3728', 'L3729'],
#  ['L3749', 'L3750'],
#  ['L3756', 'L3757'],
#  ['L3770', 'L3771'],
#  ['L3777', 'L3778'],
#  ['L3942', 'L3943', 'L3944', 'L3945'],
#  ['L3963', 'L3964', 'L3965', 'L3966', 'L3967', 'L3968', 'L3969'],
#  ['L3972', 'L3973', 'L3974', 'L3975', 'L3976'],
#  ['L3979', 'L3980', 'L3981', 'L3982', 'L3983', 'L3984'],
#  ['L3987', 'L3988', 'L3989', 'L3990', 'L3991', 'L3992'],
#  ['L3995', 'L3996', 'L3997', 'L3998', 'L3999', 'L4000', 'L4001'],
#  ['L4011', 'L4012', 'L4013', 'L4014', 'L4015', 'L4016', 'L4017'],
#  ['L4159', 'L4160', 'L4161', 'L4162', 'L4163'],
#  ['L4188', 'L4189', 'L4190', 'L4191', 'L4192', 'L4193'],
#  ['L4196', 'L4197', 'L4198', 'L4199'],
#  ['L4208', 'L4209'],
#  ['L4282', 'L4283'],
#  ['L4296', 'L4297', 'L4298', 'L4299', 'L4300'],
#  ['L4006', 'L4007'],
#  ['L4068', 'L4069', 'L4070'],
#  ['L4079', 'L4080'],
#  ['L4219', 'L4220', 'L4221', 'L4222', 'L4223', 'L4224'],
#  ['L4227', 'L4228', 'L4229', 'L4230'],
#  ['L4265', 'L4266', 'L4267', 'L4268', 'L4269', 'L4270', 'L4271'],
#  ['L4333', 'L4334', 'L4335'],
#  ['L4346', 'L4347', 'L4348', 'L4349', 'L4350'],
#  ['L4353', 'L4354', 'L4355', 'L4356', 'L4357'],
#  ['L4360', 'L4361', 'L4362', 'L4363'],
#  ['L4366', 'L4367', 'L4368'],
#  ['L3970', 'L3971'],
#  ['L3977', 'L3978'],
#  ['L3993', 'L3994'],
#  ['L4002', 'L4003'],
#  ['L4009', 'L4010'],
#  ['L4018', 'L4019'],
#  ['L3668', 'L3669'],
#  ['L3672', 'L3673', 'L3674', 'L3675', 'L3676', 'L3677'],
#  ['L3679', 'L3680', 'L3681', 'L3682', 'L3683', 'L3684', 'L3685'],
#  ['L3688', 'L3689', 'L3690', 'L3691', 'L3692', 'L3693'],
#  ['L3797', 'L3798', 'L3799'],
#  ['L3805', 'L3806', 'L3807', 'L3808', 'L3809', 'L3810'],
#  ['L3730', 'L3731', 'L3732', 'L3733', 'L3734', 'L3735'],
#  ['L3758', 'L3759'],
#  ['L3774', 'L3775', 'L3776'],
#  ['L3779', 'L3780'],
#  ['L3622', 'L3623'],
#  ['L3626', 'L3627', 'L3628', 'L3629', 'L3630', 'L3631'],
#  ['L3651', 'L3652', 'L3653'],
#  ['L3724', 'L3725', 'L3726'],
#  ['L3738', 'L3739', 'L3740'],
#  ['L3745', 'L3746', 'L3747', 'L3748'],
#  ['L3751', 'L3752', 'L3753', 'L3754'],
#  ['L3760', 'L3761', 'L3762', 'L3763'],
#  ['L3766', 'L3767', 'L3768'],
#  ['L3772', 'L3773'],
#  ['L3868', 'L3869'],
#  ['L3889', 'L3890', 'L3891', 'L3892', 'L3893'],
#  ['L3896', 'L3897'],
#  ['L3904', 'L3905', 'L3906', 'L3907'],
#  ['L3817', 'L3818', 'L3819', 'L3820', 'L3821'],
#  ['L3824', 'L3825', 'L3826', 'L3827', 'L3828', 'L3829'],
#  ['L3832', 'L3833', 'L3834'],
#  ['L3837', 'L3838', 'L3839'],
#  ['L4020', 'L4021', 'L4022', 'L4023', 'L4024', 'L4025'],
#  ['L4028', 'L4029', 'L4030', 'L4031', 'L4032', 'L4033'],
#  ['L4096', 'L4097'],
#  ['L4108', 'L4109', 'L4110', 'L4111', 'L4112', 'L4113'],
#  ['L4118', 'L4119'],
#  ['L4169', 'L4170'],
#  ['L4174', 'L4175'],
#  ['L4181', 'L4182', 'L4183'],
#  ['L5039', 'L5040'],
#  ['L5041', 'L5042'],
#  ['L5043', 'L5044'],
#  ['L5045', 'L5046', 'L5047', 'L5048'],
#  ['L4897', 'L4898', 'L4899', 'L4900'],
#  ['L4903', 'L4904', 'L4905', 'L4906'],
#  ['L4922', 'L4923'],
#  ['L4924', 'L4925'],
#  ['L4453', 'L4454'],
#  ['L4501', 'L4502', 'L4503', 'L4504', 'L4505'],
#  ['L4506', 'L4507', 'L4508', 'L4509', 'L4510', 'L4511'],
#  ['L4562', 'L4563'],
#  ['L4567', 'L4568'],
#  ['L5175', 'L5176', 'L5177', 'L5178', 'L5179', 'L5180'],
#  ['L5181', 'L5182'],
#  ['L5183', 'L5184', 'L5185', 'L5186', 'L5187', 'L5188'],
#  ['L5193', 'L5194'],
#  ['L5215', 'L5216'],
#  ['L5366', 'L5367', 'L5368'],
#  ['L5370', 'L5371'],
#  ['L4944', 'L4945'],
#  ['L4959', 'L4960'],
#  ['L5316', 'L5317', 'L5318'],
#  ['L5321', 'L5322', 'L5323', 'L5324', 'L5325'],
#  ['L5328', 'L5329'],
#  ['L4628', 'L4629'],
#  ['L5338', 'L5339', 'L5340'],
#  ['L5346', 'L5347', 'L5348'],
#  ['L4727', 'L4728', 'L4729'],
#  ['L4731', 'L4732'],
#  ['L4739', 'L4740', 'L4741'],
#  ['L4743',
#   'L4744',
#   'L4745',
#   'L4746',
#   'L4747',
#   'L4748',
#   'L4749',
#   'L4750',
#   'L4751'],
#  ['L4763', 'L4764'],
#  ['L4765', 'L4766'],
#  ['L4769', 'L4770'],
#  ['L4771', 'L4772', 'L4773', 'L4774', 'L4775'],
#  ['L4778', 'L4779'],
#  ['L4780', 'L4781', 'L4782', 'L4783', 'L4784', 'L4785'],
#  ['L4786', 'L4787', 'L4788'],
#  ['L4789', 'L4790', 'L4791', 'L4792'],
#  ['L4800', 'L4801', 'L4802', 'L4803'],
#  ['L4814', 'L4815', 'L4816'],
#  ['L4825', 'L4826', 'L4827', 'L4828'],
#  ['L4848', 'L4849', 'L4850', 'L4851', 'L4852', 'L4853', 'L4854', 'L4855'],
#  ['L4857', 'L4858'],
#  ['L4860', 'L4861'],
#  ['L4863', 'L4864'],
#  ['L4866', 'L4867'],
#  ['L4868', 'L4869'],
#  ['L4870', 'L4871'],
#  ['L4873', 'L4874', 'L4875', 'L4876', 'L4877', 'L4878', 'L4879'],
#  ['L4880', 'L4881'],
#  ['L4882', 'L4883', 'L4884', 'L4885', 'L4886'],
#  ['L4887', 'L4888', 'L4889', 'L4890', 'L4891'],
#  ['L4893', 'L4894'],
#  ['L4895', 'L4896'],
#  ['L4911', 'L4912'],
#  ['L4929', 'L4930'],
#  ['L4937', 'L4938', 'L4939'],
#  ['L4964', 'L4965'],
#  ['L4969', 'L4970', 'L4971', 'L4972', 'L4973'],
#  ['L4974', 'L4975'],
#  ['L4994', 'L4995', 'L4996', 'L4997'],
#  ['L5002', 'L5003', 'L5004', 'L5005'],
#  ['L5007', 'L5008', 'L5009', 'L5010'],
#  ['L5011', 'L5012', 'L5013', 'L5014'],
#  ['L5016', 'L5017'],
#  ['L5018', 'L5019', 'L5020'],
#  ['L5021', 'L5022'],
#  ['L5023', 'L5024', 'L5025'],
#  ['L5028', 'L5029', 'L5030'],
#  ['L5033', 'L5034', 'L5035'],
#  ['L5036', 'L5037', 'L5038'],
#  ['L5049', 'L5050', 'L5051'],
#  ['L5052', 'L5053', 'L5054', 'L5055', 'L5056'],
#  ['L5057', 'L5058', 'L5059'],
#  ['L5060', 'L5061', 'L5062', 'L5063', 'L5064'],
#  ['L5065', 'L5066'],
#  ['L5067', 'L5068'],
#  ['L5069', 'L5070', 'L5071', 'L5072'],
#  ['L5073', 'L5074'],
#  ['L5076', 'L5077'],
#  ['L5083', 'L5084', 'L5085'],
#  ['L5171', 'L5172'],
#  ['L5190', 'L5191', 'L5192'],
#  ['L5195', 'L5196'],
#  ['L5197', 'L5198', 'L5199', 'L5200'],
#  ['L5201', 'L5202'],
#  ['L5204', 'L5205'],
#  ['L5206', 'L5207'],
#  ['L5208', 'L5209', 'L5210'],
#  ['L5212', 'L5213'],
#  ['L5224', 'L5225', 'L5226', 'L5227'],
#  ['L5236', 'L5237'],
#  ['L5249', 'L5250', 'L5251', 'L5252'],
#  ['L5253', 'L5254', 'L5255'],
#  ['L5256', 'L5257'],
#  ['L5290', 'L5291'],
#  ['L5304', 'L5305'],
#  ['L5306', 'L5307'],
#  ['L5308', 'L5309', 'L5310', 'L5311', 'L5312', 'L5313', 'L5314'],
#  ['L5351', 'L5352', 'L5353'],
#  ['L5372', 'L5373'],
#  ['L5375', 'L5376'],
#  ['L5377', 'L5378', 'L5379', 'L5380', 'L5381', 'L5382'],
#  ['L5383', 'L5384'],
#  ['L4689', 'L4690'],
#  ['L4691', 'L4692'],
#  ['L4693',
#   'L4694',
#   'L4695',
#   'L4696',
#   'L4697',
#   'L4698',
#   'L4699',
#   'L4700',
#   'L4701',
#   'L4702',
#   'L4703'],
#  ['L5093', 'L5094', 'L5095', 'L5096'],
#  ['L5097', 'L5098', 'L5099'],
#  ['L5100', 'L5101'],
#  ['L5102', 'L5103', 'L5104'],
#  ['L5242', 'L5243'],
#  ['L5244', 'L5245'],
#  ['L4636', 'L4637', 'L4638', 'L4639'],
#  ['L4642', 'L4643', 'L4644'],
#  ['L4669', 'L4670', 'L4671'],
#  ['L4672', 'L4673'],
#  ['L4675', 'L4676'],
#  ['L4677', 'L4678', 'L4679', 'L4680'],
#  ['L4681', 'L4682'],
#  ['L4685', 'L4686', 'L4687'],
#  ['L5132', 'L5133', 'L5134', 'L5135', 'L5136', 'L5137', 'L5138'],
#  ['L5142', 'L5143'],
#  ['L5144', 'L5145'],
#  ['L5158', 'L5159'],
#  ['L5162', 'L5163'],
#  ['L4809', 'L4810', 'L4811', 'L4812', 'L4813'],
#  ['L4817', 'L4818', 'L4819'],
#  ['L4821', 'L4822', 'L4823'],
#  ['L4467', 'L4468'],
#  ['L4469', 'L4470', 'L4471'],
#  ['L4472', 'L4473', 'L4474'],
#  ['L4475', 'L4476'],
#  ['L4477',
#   'L4478',
#   'L4479',
#   'L4480',
#   'L4481',
#   'L4482',
#   'L4483',
#   'L4484',
#   'L4485',
#   'L4486',
#   'L4487',
#   'L4488'],
#  ['L4513', 'L4514'],
#  ['L4516', 'L4517'],
#  ['L4519', 'L4520', 'L4521', 'L4522'],
#  ['L4523', 'L4524', 'L4525'],
#  ['L4528', 'L4529', 'L4530', 'L4531', 'L4532'],
#  ['L4533', 'L4534', 'L4535'],
#  ['L4704', 'L4705', 'L4706'],
#  ['L4707', 'L4708', 'L4709'],
#  ['L4712', 'L4713', 'L4714', 'L4715', 'L4716', 'L4717', 'L4718'],
#  ['L4836', 'L4837'],
#  ['L4839', 'L4840'],
#  ['L5149', 'L5150', 'L5151', 'L5152', 'L5153'],
#  ['L5164', 'L5165'],
#  ['L5167', 'L5168', 'L5169'],
#  ['L5219', 'L5220', 'L5221'],
#  ['L5258', 'L5259', 'L5260', 'L5261', 'L5262', 'L5263'],
#  ['L5275', 'L5276'],
#  ['L5284', 'L5285', 'L5286', 'L5287'],
#  ['L5292', 'L5293', 'L5294', 'L5295', 'L5296', 'L5297', 'L5298'],
#  ['L5301', 'L5302', 'L5303'],
#  ['L5355', 'L5356', 'L5357', 'L5358'],
#  ['L5359', 'L5360', 'L5361', 'L5362', 'L5363'],
#  ['L5364', 'L5365'],
#  ['L5264', 'L5265'],
#  ['L5266', 'L5267', 'L5268'],
#  ['L5279', 'L5280', 'L5281', 'L5282'],
#  ['L5288', 'L5289'],
#  ['L4600', 'L4601', 'L4602'],
#  ['L4603', 'L4604'],
#  ['L4609', 'L4610'],
#  ['L4612', 'L4613'],
#  ['L4493', 'L4494'],
#  ['L4495', 'L4496', 'L4497', 'L4498', 'L4499', 'L4500'],
#  ['L4543', 'L4544', 'L4545', 'L4546', 'L4547'],
#  ['L4548', 'L4549', 'L4550', 'L4551', 'L4552', 'L4553', 'L4554', 'L4555'],
#  ['L4558', 'L4559'],
#  ['L5230', 'L5231'],
#  ['L5233', 'L5234'],
#  ['L5105', 'L5106'],
#  ['L5107', 'L5108'],
#  ['L5109', 'L5110'],
#  ['L5113', 'L5114'],
#  ['L5115', 'L5116', 'L5117', 'L5118', 'L5119', 'L5120'],
#  ['L5121', 'L5122', 'L5123'],
#  ['L5124', 'L5125'],
#  ['L5643', 'L5644', 'L5645'],
#  ['L5673', 'L5674'],
#  ['L5678', 'L5679', 'L5680'],
#  ['L5692', 'L5693'],
#  ['L5875', 'L5876'],
#  ['L5889', 'L5890'],
#  ['L5710', 'L5711'],
#  ['L5737',
#   'L5738',
#   'L5739',
#   'L5740',
#   'L5741',
#   'L5742',
#   'L5743',
#   'L5744',
#   'L5745'],
#  ['L5746', 'L5747', 'L5748'],
#  ['L5751', 'L5752'],
#  ['L5754', 'L5755', 'L5756'],
#  ['L5760', 'L5761'],
#  ['L5613', 'L5614'],
#  ['L5615', 'L5616', 'L5617'],
#  ['L5620', 'L5621', 'L5622'],
#  ['L5624', 'L5625', 'L5626', 'L5627', 'L5628'],
#  ['L5648', 'L5649', 'L5650', 'L5651'],
#  ['L5652', 'L5653', 'L5654', 'L5655'],
#  ['L5656', 'L5657', 'L5658'],
#  ['L5826', 'L5827', 'L5828', 'L5829', 'L5830', 'L5831', 'L5832', 'L5833'],
#  ['L5839', 'L5840'],
#  ['L6168', 'L6169', 'L6170', 'L6171', 'L6172'],
#  ['L6258', 'L6259'],
#  ['L6263', 'L6264', 'L6265', 'L6266'],
#  ['L5463', 'L5464'],
#  ['L5468', 'L5469', 'L5470'],
#  ['L5508', 'L5509', 'L5510'],
#  ['L5511', 'L5512'],
#  ['L5515', 'L5516'],
#  ['L5521', 'L5522'],
#  ['L5556', 'L5557'],
#  ['L5630', 'L5631', 'L5632'],
#  ['L5636', 'L5637'],
#  ['L5646', 'L5647'],
#  ['L5671', 'L5672'],
#  ['L5675', 'L5676'],
#  ['L5686', 'L5687'],
#  ['L5688', 'L5689'],
#  ['L5730', 'L5731'],
#  ['L5911', 'L5912', 'L5913'],
#  ['L6251', 'L6252'],
#  ['L6105', 'L6106', 'L6107'],
#  ['L6108', 'L6109', 'L6110'],
#  ['L6114', 'L6115', 'L6116', 'L6117', 'L6118', 'L6119', 'L6120'],
#  ['L6123', 'L6124'],
#  ['L5488', 'L5489'],
#  ['L5490', 'L5491', 'L5492'],
#  ['L5493', 'L5494', 'L5495', 'L5496'],
#  ['L5497', 'L5498', 'L5499'],
#  ['L5501', 'L5502', 'L5503', 'L5504', 'L5505', 'L5506'],
#  ['L5664', 'L5665', 'L5666', 'L5667', 'L5668'],
#  ['L5669', 'L5670'],
#  ['L5596', 'L5597'],
#  ['L5605', 'L5606'],
#  ['L5609', 'L5610'],
#  ['L5611', 'L5612'],
#  ['L5633', 'L5634'],
#  ['L5638', 'L5639', 'L5640', 'L5641'],
#  ['L5420', 'L5421'],
#  ['L5422', 'L5423', 'L5424', 'L5425'],
#  ['L5426', 'L5427'],
#  ['L5777', 'L5778', 'L5779', 'L5780'],
#  ['L5782', 'L5783'],
#  ['L5785', 'L5786'],
#  ['L5787', 'L5788', 'L5789'],
#  ['L5790', 'L5791', 'L5792'],
#  ['L5880', 'L5881', 'L5882'],
#  ['L6029', 'L6030', 'L6031', 'L6032'],
#  ['L5543', 'L5544'],
#  ['L5545', 'L5546', 'L5547', 'L5548'],
#  ['L5834', 'L5835'],
#  ['L6208', 'L6209'],
#  ['L6211', 'L6212'],
#  ['L5922', 'L5923'],
#  ['L5924', 'L5925'],
#  ['L5933', 'L5934'],
#  ['L6020', 'L6021', 'L6022', 'L6023', 'L6024', 'L6025', 'L6026'],
#  ['L6132', 'L6133'],
#  ['L6156', 'L6157', 'L6158'],
#  ['L6183', 'L6184'],
#  ['L6190', 'L6191'],
#  ['L6206', 'L6207'],
#  ['L6213', 'L6214'],
#  ['L6215', 'L6216'],
#  ['L6278', 'L6279', 'L6280'],
#  ['L6282', 'L6283'],
#  ['L5794', 'L5795', 'L5796', 'L5797', 'L5798', 'L5799', 'L5800'],
#  ['L5801', 'L5802', 'L5803'],
#  ['L5804', 'L5805', 'L5806'],
#  ['L5809', 'L5810', 'L5811', 'L5812', 'L5813'],
#  ['L5815', 'L5816'],
#  ['L5817', 'L5818', 'L5819'],
#  ['L5820', 'L5821', 'L5822'],
#  ['L5824', 'L5825'],
#  ['L5858', 'L5859'],
#  ['L5869', 'L5870', 'L5871'],
#  ['L5900', 'L5901'],
#  ['L5943', 'L5944'],
#  ['L5946', 'L5947'],
#  ['L5949', 'L5950'],
#  ['L5954', 'L5955', 'L5956', 'L5957'],
#  ['L5958', 'L5959', 'L5960', 'L5961', 'L5962', 'L5963', 'L5964', 'L5965'],
#  ['L6051', 'L6052', 'L6053', 'L6054', 'L6055', 'L6056'],
#  ['L6057', 'L6058', 'L6059'],
#  ['L6062', 'L6063', 'L6064'],
#  ['L6066', 'L6067'],
#  ['L6237', 'L6238', 'L6239', 'L6240', 'L6241'],
#  ['L6267', 'L6268', 'L6269', 'L6270'],
#  ['L6289', 'L6290', 'L6291', 'L6292', 'L6293'],
#  ['L6297', 'L6298', 'L6299', 'L6300', 'L6301'],
#  ['L6302', 'L6303', 'L6304', 'L6305'],
#  ['L6308', 'L6309'],
#  ['L5722', 'L5723', 'L5724', 'L5725', 'L5726'],
#  ['L5728', 'L5729'],
#  ['L5531', 'L5532', 'L5533'],
#  ['L5534', 'L5535', 'L5536'],
#  ['L5537', 'L5538'],
#  ['L5539', 'L5540'],
#  ['L5560', 'L5561', 'L5562', 'L5563', 'L5564', 'L5565', 'L5566', 'L5567'],
#  ['L5568', 'L5569', 'L5570'],
#  ['L5573', 'L5574'],
#  ['L5585', 'L5586'],
#  ['L6313', 'L6314'],
#  ['L5767', 'L5768', 'L5769', 'L5770'],
#  ['L5773', 'L5774'],
#  ['L6254', 'L6255'],
#  ['L5441', 'L5442'],
#  ['L5443', 'L5444', 'L5445', 'L5446', 'L5447'],
#  ['L5448', 'L5449', 'L5450', 'L5451', 'L5452', 'L5453'],
#  ['L5479', 'L5480'],
#  ['L5396', 'L5397', 'L5398'],
#  ['L5399', 'L5400'],
#  ['L5404', 'L5405'],
#  ['L5406', 'L5407'],
#  ['L6219', 'L6220', 'L6221', 'L6222', 'L6223', 'L6224', 'L6225'],
#  ['L6002', 'L6003'],
#  ['L6004', 'L6005'],
#  ['L6006', 'L6007', 'L6008', 'L6009'],
#  ['L6011', 'L6012'],
#  ['L6335', 'L6336'],
#  ['L6337', 'L6338', 'L6339', 'L6340', 'L6341', 'L6342', 'L6343', 'L6344'],
#  ['L6347', 'L6348', 'L6349', 'L6350'],
#  ['L6351', 'L6352'],
#  ['L6361', 'L6362', 'L6363', 'L6364', 'L6365'],
#  ['L6429', 'L6430', 'L6431', 'L6432', 'L6433', 'L6434', 'L6435'],
#  ['L6957', 'L6958', 'L6959'],
#  ['L6960', 'L6961', 'L6962', 'L6963', 'L6964'],
#  ['L6971', 'L6972', 'L6973', 'L6974', 'L6975', 'L6976'],
#  ['L6977', 'L6978', 'L6979'],
#  ['L6980', 'L6981', 'L6982', 'L6983', 'L6984', 'L6985'],
#  ['L6986', 'L6987', 'L6988', 'L6989', 'L6990', 'L6991', 'L6992', 'L6993'],
#  ['L6996', 'L6997', 'L6998', 'L6999', 'L7000'],
#  ['L7001', 'L7002'],
#  ['L6605', 'L6606'],
#  ['L6607', 'L6608', 'L6609', 'L6610', 'L6611', 'L6612'],
#  ['L6707',
#   'L6708',
#   'L6709',
#   'L6710',
#   'L6711',
#   'L6712',
#   'L6713',
#   'L6714',
#   'L6715',
#   'L6716',
#   'L6717'],
#  ['L6909', 'L6910'],
#  ['L6779', 'L6780'],
#  ['L6781', 'L6782', 'L6783', 'L6784'],
#  ['L6789', 'L6790'],
#  ['L6791',
#   'L6792',
#   'L6793',
#   'L6794',
#   'L6795',
#   'L6796',
#   'L6797',
#   'L6798',
#   'L6799'],
#  ['L6800', 'L6801', 'L6802'],
#  ['L6803', 'L6804', 'L6805', 'L6806', 'L6807', 'L6808'],
#  ['L6810', 'L6811', 'L6812'],
#  ['L6814', 'L6815'],
#  ['L6828', 'L6829'],
#  ['L6830', 'L6831', 'L6832'],
#  ['L6833', 'L6834', 'L6835'],
#  ['L6840', 'L6841', 'L6842'],
#  ['L6844', 'L6845', 'L6846'],
#  ['L6852', 'L6853'],
#  ['L6858', 'L6859', 'L6860', 'L6861', 'L6862'],
#  ['L6863', 'L6864'],
#  ['L6847', 'L6848'],
#  ['L6865', 'L6866'],
#  ['L6906', 'L6907', 'L6908'],
#  ['L6911', 'L6912'],
#  ['L6935', 'L6936'],
#  ['L6437', 'L6438', 'L6439', 'L6440', 'L6441', 'L6442'],
#  ['L6443',
#   'L6444',
#   'L6445',
#   'L6446',
#   'L6447',
#   'L6448',
#   'L6449',
#   'L6450',
#   'L6451',
#   'L6452'],
#  ['L6453', 'L6454'],
#  ['L6460', 'L6461', 'L6462', 'L6463', 'L6464'],
#  ['L6693',
#   'L6694',
#   'L6695',
#   'L6696',
#   'L6697',
#   'L6698',
#   'L6699',
#   'L6700',
#   'L6701',
#   'L6702'],
#  ['L6919', 'L6920'],
#  ['L7013', 'L7014', 'L7015'],
#  ['L7016', 'L7017'],
#  ['L7018', 'L7019', 'L7020', 'L7021', 'L7022', 'L7023', 'L7024', 'L7025'],
#  ['L7026', 'L7027', 'L7028', 'L7029', 'L7030', 'L7031', 'L7032', 'L7033'],
#  ['L7034', 'L7035', 'L7036', 'L7037', 'L7038', 'L7039'],
#  ['L7043', 'L7044', 'L7045'],
#  ['L7048',
#   'L7049',
#   'L7050',
#   'L7051',
#   'L7052',
#   'L7053',
#   'L7054',
#   'L7055',
#   'L7056',
#   'L7057'],
#  ['L7059', 'L7060'],
#  ['L7061', 'L7062', 'L7063', 'L7064', 'L7065', 'L7066', 'L7067'],
#  ['L7070', 'L7071', 'L7072', 'L7073', 'L7074', 'L7075', 'L7076'],
#  ['L6686', 'L6687', 'L6688', 'L6689', 'L6690', 'L6691', 'L6692'],
#  ['L6374', 'L6375', 'L6376', 'L6377', 'L6378', 'L6379', 'L6380'],
#  ['L6868',
#   'L6869',
#   'L6870',
#   'L6871',
#   'L6872',
#   'L6873',
#   'L6874',
#   'L6875',
#   'L6876',
#   'L6877',
#   'L6878',
#   'L6879',
#   'L6880'],
#  ['L6881', 'L6882', 'L6883', 'L6884', 'L6885'],
#  ['L6886', 'L6887', 'L6888', 'L6889'],
#  ['L6890', 'L6891', 'L6892', 'L6893', 'L6894'],
#  ['L6898', 'L6899'],
#  ['L6900', 'L6901'],
#  ['L6902', 'L6903'],
#  ['L6921', 'L6922'],
#  ['L6546', 'L6547', 'L6548', 'L6549', 'L6550', 'L6551', 'L6552', 'L6553'],
#  ['L6556', 'L6557'],
#  ['L6558', 'L6559', 'L6560', 'L6561'],
#  ['L6568', 'L6569'],
#  ['L6570', 'L6571'],
#  ['L6574', 'L6575'],
#  ['L6576',
#   'L6577',
#   'L6578',
#   'L6579',
#   'L6580',
#   'L6581',
#   'L6582',
#   'L6583',
#   'L6584',
#   'L6585',
#   'L6586',
#   'L6587',
#   'L6588',
#   'L6589',
#   'L6590',
#   'L6591',
#   'L6592',
#   'L6593',
#   'L6594',
#   'L6595',
#   'L6596'],
#  ['L6597', 'L6598'],
#  ['L6614',
#   'L6615',
#   'L6616',
#   'L6617',
#   'L6618',
#   'L6619',
#   'L6620',
#   'L6621',
#   'L6622'],
#  ['L6623',
#   'L6624',
#   'L6625',
#   'L6626',
#   'L6627',
#   'L6628',
#   'L6629',
#   'L6630',
#   'L6631',
#   'L6632',
#   'L6633',
#   'L6634',
#   'L6635',
#   'L6636',
#   'L6637'],
#  ['L6722',
#   'L6723',
#   'L6724',
#   'L6725',
#   'L6726',
#   'L6727',
#   'L6728',
#   'L6729',
#   'L6730',
#   'L6731',
#   'L6732',
#   'L6733',
#   'L6734',
#   'L6735',
#   'L6736',
#   'L6737'],
#  ['L6750', 'L6751', 'L6752'],
#  ['L6753', 'L6754'],
#  ['L6757', 'L6758'],
#  ['L6762', 'L6763', 'L6764', 'L6765'],
#  ['L6768', 'L6769'],
#  ['L6787', 'L6788'],
#  ['L6816', 'L6817', 'L6818', 'L6819'],
#  ['L6821', 'L6822'],
#  ['L6823', 'L6824'],
#  ['L6368', 'L6369'],
#  ['L6372', 'L6373'],
#  ['L6382', 'L6383'],
#  ['L6384', 'L6385'],
#  ['L6386', 'L6387', 'L6388'],
#  ['L6389', 'L6390', 'L6391', 'L6392'],
#  ['L6395', 'L6396', 'L6397', 'L6398'],
#  ['L6399', 'L6400', 'L6401'],
#  ['L6402', 'L6403', 'L6404', 'L6405', 'L6406'],
#  ['L6407', 'L6408', 'L6409'],
#  ['L6410', 'L6411'],
#  ['L6412', 'L6413', 'L6414', 'L6415', 'L6416', 'L6417', 'L6418'],
#  ['L6419', 'L6420', 'L6421', 'L6422', 'L6423', 'L6424'],
#  ['L6425', 'L6426', 'L6427', 'L6428'],
#  ['L6639', 'L6640', 'L6641', 'L6642'],
#  ['L6643', 'L6644', 'L6645', 'L6646', 'L6647'],
#  ['L6648', 'L6649', 'L6650', 'L6651', 'L6652', 'L6653', 'L6654', 'L6655'],
#  ['L6738',
#   'L6739',
#   'L6740',
#   'L6741',
#   'L6742',
#   'L6743',
#   'L6744',
#   'L6745',
#   'L6746'],
#  ['L6747', 'L6748', 'L6749'],
#  ['L6466', 'L6467'],
#  ['L6468', 'L6469', 'L6470', 'L6471', 'L6472'],
#  ['L6473', 'L6474', 'L6475', 'L6476', 'L6477'],
#  ['L6479', 'L6480', 'L6481'],
#  ['L6482', 'L6483'],
#  ['L6485',
#   'L6486',
#   'L6487',
#   'L6488',
#   'L6489',
#   'L6490',
#   'L6491',
#   'L6492',
#   'L6493',
#   'L6494',
#   'L6495',
#   'L6496',
#   'L6497',
#   'L6498',
#   'L6499',
#   'L6500',
#   'L6501',
#   'L6502'],
#  ['L6503', 'L6504'],
#  ['L6507', 'L6508'],
#  ['L6511', 'L6512', 'L6513', 'L6514', 'L6515'],
#  ['L6516',
#   'L6517',
#   'L6518',
#   'L6519',
#   'L6520',
#   'L6521',
#   'L6522',
#   'L6523',
#   'L6524'],
#  ['L6525', 'L6526', 'L6527', 'L6528'],
#  ['L6531', 'L6532'],
#  ['L6534', 'L6535', 'L6536'],
#  ['L7081', 'L7082', 'L7083', 'L7084'],
#  ['L7085', 'L7086', 'L7087'],
#  ['L7088',
#   'L7089',
#   'L7090',
#   'L7091',
#   'L7092',
#   'L7093',
#   'L7094',
#   'L7095',
#   'L7096',
#   'L7097',
#   'L7098'],
#  ['L6657', 'L6658', 'L6659'],
#  ['L6661', 'L6662'],
#  ['L6665', 'L6666', 'L6667', 'L6668'],
#  ['L6669', 'L6670', 'L6671'],
#  ['L6354', 'L6355', 'L6356', 'L6357'],
#  ['L6358', 'L6359', 'L6360'],
#  ['L6676', 'L6677', 'L6678'],
#  ['L6679', 'L6680', 'L6681'],
#  ['L6682', 'L6683', 'L6684'],
#  ['L8029', 'L8030', 'L8031', 'L8032'],
#  ['L8033', 'L8034', 'L8035'],
#  ['L8036', 'L8037'],
#  ['L8094', 'L8095', 'L8096', 'L8097'],
#  ['L8155', 'L8156'],
#  ['L8196', 'L8197', 'L8198', 'L8199'],
#  ...]

# %%
# Getting separately the questions and the answers
questions = []
answers = []
for conversation in conversations_ids:
    for i in range(len(conversation) - 1):
        questions.append(id2line[conversation[i]])
        answers.append(id2line[conversation[i+1]])

# %%
questions[4]
# Out:
# "No, no, it's my fault -- we didn't have a proper introduction ---"

# %%
# Doing a first cleaning of the texts
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"[-()\"#/@;:<>{}+=~|.?,]", "", text)
    return text

# %%
# Cleaning the questions
clean_questions = []
for question in questions:
    clean_questions.append(clean_text(question))
 
# Cleaning the answers
clean_answers = []
for answer in answers:
    clean_answers.append(clean_text(answer))

# %%
# Creating a dictionary that maps each word to its number of occurrences
word2count = {}
for question in clean_questions:
    for word in question.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1
for answer in clean_answers:
    for word in answer.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1

# %%
word2count
# Out:
# {"stravanavitch's": 1,
#  "scumbag's": 2,
#  'spotted': 47,
#  'bogucki': 1,
#  'peeked': 8,
#  'sumner': 1,
#  'statutory': 3,
#  'uhenchmenu': 2,
#  'monumentsif': 2,
#  'verificatesi': 1,
#  "truthc'mon": 1,
#  "coon's": 4,
#  'billy!': 18,
#  'siding': 5,
#  "ss'ai": 2,
#  'lord!': 21,
#  'claustrophobia': 1,
#  'jumped': 92,
#  'ucommanderu!': 1,
#  'guardian': 19,
#  'toil': 3,
#  'skin!': 7,
#  'comebut': 2,
#  'molecular': 29,
#  "jewboy's": 3,
#  'reward!': 3,
#  'detonate': 19,
#  'twiggy': 1,
#  'cosmetic': 6,
#  'depots': 1,
#  'useriousu': 1,
#  "fortune's": 1,
#  '`bout': 2,
#  'proceed': 73,
#  'dispair': 1,
#  'aaarrrgggaahh': 1,
#  'deliriously': 4,
#  'tsttst!': 1,
#  'fixation': 5,
#  'cabell': 7,
#  'puppies!': 3,
#  'wellversed': 1,
#  "'mornin'": 1,
#  'uhonoru': 1,
#  'moneyi': 2,
#  'yonder': 24,
#  'disappoints': 2,
#  'pilots': 36,
#  'carondolet': 2,
#  'g7': 1,
#  'swoop': 4,
#  'marchena': 2,
#  'freshmen': 3,
#  'examiner': 8,
#  'accounta': 5,
#  'thirteenth': 10,
#  'spokesperson': 1,
#  'panda': 7,
#  'britain': 22,
#  'behave': 49,
#  'festival!': 1,
#  'realestate': 1,
#  'fingerprinted': 3,
#  "d'you": 167,
#  "pussy's": 2,
#  'notoriously': 2,
#  "mustard's": 4,
#  'houton': 2,
#  'jiggy': 3,
#  'yeahyou': 10,
#  'outburst!': 1,
#  'bubbles!': 1,
#  'gliding': 2,
#  'sticking': 52,
#  'complicity': 3,
#  "bronfman's": 1,
#  'huge': 143,
#  'nakedfaced': 1,
#  'master!': 5,
#  'deadski': 1,
#  'jorgenson': 1,
#  'art': 341,
#  'emotionsi': 2,
#  'chemist': 6,
#  'odor': 7,
#  'greeni': 1,
#  "doin'!": 8,
#  'fashion': 62,
#  'vr': 6,
#  'amenities': 2,
#  "suit's": 3,
#  'aloud': 6,
#  'nonprostitute': 1,
#  'reassigned': 9,
#  'wings': 88,
#  'he!!!': 2,
#  'nnothing': 1,
#  'kinderman': 2,
#  'presidio!': 1,
#  'hostages': 53,
#  "reputation's": 2,
#  'vex': 2,
#  'happenedyes': 1,
#  "father's!": 1,
#  'fourchambered': 1,
#  'jailhouse': 4,
#  'appalled': 7,
#  'happen!!': 1,
#  "hornsby's": 1,
#  'galaxies': 7,
#  "nuthin'!": 3,
#  'refusing': 18,
#  '5551342': 1,
#  'thrash': 3,
#  'soothed': 1,
#  'fausto': 3,
#  'foxed': 2,
#  'pickaninnies': 1,
#  'yesif': 4,
#  'verdict': 17,
#  'schizophrenia': 5,
#  'z': 32,
#  'tokyo': 27,
#  'puppy!': 1,
#  "fixin'": 23,
#  'civilian': 46,
#  'almanac': 3,
#  'marshaling': 3,
#  'gimping': 1,
#  'kross!': 1,
#  'homeless': 34,
#  'wagonful': 2,
#  'work!': 36,
#  'kenny!': 8,
#  'collapsible': 1,
#  'fears': 31,
#  'dudeover': 1,
#  'unmysterious': 2,
#  'remiss': 2,
#  'irrigated': 2,
#  'fridaythe': 1,
#  'nineyearolds': 1,
#  'ce': 1,
#  'fals': 1,
#  'hackneys': 2,
#  'gratis': 1,
#  'uunuofficial': 1,
#  'peas': 7,
#  'coates': 3,
#  "ujoe'su": 2,
#  'ledgable]': 1,
#  'rob!': 4,
#  'awgive': 2,
#  'duckbill': 2,
#  'geologists': 10,
#  'patpong': 2,
#  'highball': 1,
#  'centre': 10,
#  "hand's": 12,
#  '1868': 2,
#  'chintz': 1,
#  'ants': 22,
#  'vous': 16,
#  'showings': 2,
#  'debts': 34,
#  'torment': 13,
#  "climbin'": 5,
#  'congressional': 13,
#  "'nads": 1,
#  'adonis': 11,
#  'finalist': 1,
#  'reclusive': 2,
#  'tigerstyle': 1,
#  'werehurt': 1,
#  "squirtin'": 2,
#  'hudley': 2,
#  'vegetarians': 3,
#  'wannabes': 10,
#  'eric!!!!': 2,
#  'sugarpie': 2,
#  'poliakoff': 3,
#  'acres': 32,
#  'hurley': 2,
#  "jak'tahla": 2,
#  "turnin'": 11,
#  'troika': 1,
#  'sweats': 6,
#  'almo': 1,
#  'transit': 27,
#  'tits': 121,
#  'mcdonald': 1,
#  'hotwire': 7,
#  'uinsectopiau!': 1,
#  'basket!': 2,
#  'lauryi': 1,
#  'saidmaybe': 2,
#  'sara': 37,
#  'halffive': 1,
#  'newberry': 4,
#  'personal]': 1,
#  'aim': 75,
#  'crm114': 18,
#  "brotherinlaw's": 2,
#  'ujewu': 1,
#  "gun's": 14,
#  'parmigiana': 1,
#  'developments': 12,
#  'overpriced!': 2,
#  'payoffs': 9,
#  "ma'm": 3,
#  'decentralized': 1,
#  "clerk'they": 2,
#  "knows'": 1,
#  'contruct': 1,
#  'papau': 1,
#  'himyou': 2,
#  'doucet': 15,
#  'ltriptophanea': 1,
#  'pencil!': 1,
#  'cyber': 8,
#  "craig's": 3,
#  'garde': 1,
#  'vacuumsealed': 1,
#  'plumbers': 11,
#  "picnic'": 1,
#  'schrooms': 2,
#  'blueprints!': 2,
#  'pelvic': 5,
#  'talleyrand': 2,
#  'wear!': 2,
#  'pupcik': 1,
#  'assassinations': 4,
#  'balenciaga': 2,
#  'ioh': 1,
#  'personification': 3,
#  'spf': 2,
#  'radiometric': 1,
#  'fuckfest': 2,
#  '*other*': 1,
#  'humanalien': 1,
#  'senseor': 2,
#  'hams': 8,
#  'associates': 37,
#  'trickass': 2,
#  'stageonly': 2,
#  'bothers': 63,
#  'courtiers': 1,
#  'fermented': 3,
#  'moneymaking': 2,
#  'inspections': 1,
#  'wounded': 75,
#  'some': 9340,
#  'hmpressure': 1,
#  "marlin's": 1,
#  'vitamins!': 2,
#  'norman': 184,
#  'saleslady': 1,
#  'vulgarity': 2,
#  'welchers': 1,
#  'uhyes': 4,
#  'overestimating': 4,
#  'kevinyou': 1,
#  'bestserved': 1,
#  'giulia': 10,
#  'ithisi': 6,
#  'chestcutter': 6,
#  'need!': 14,
#  'chulo': 6,
#  'hardwood': 1,
#  'eightyeight': 10,
#  'worlds': 60,
#  'nervousness': 5,
#  'paton': 1,
#  'givememy': 1,
#  "goldfinger's": 2,
#  'coffers': 1,
#  'oneirix': 1,
#  'pc': 4,
#  'expunged': 4,
#  'corrective': 6,
#  'goatguy': 1,
#  "kranepool's": 2,
#  'artfully': 1,
#  "brimmer's": 1,
#  'isreally': 4,
#  'ofwhat': 1,
#  'compromised': 18,
#  'bali': 3,
#  'udieu': 5,
#  "dryin'": 1,
#  'validate': 3,
#  'repatriate': 2,
#  'halfjoking': 2,
#  'dumbshit!': 1,
#  'casino': 109,
#  'reveal': 34,
#  'widdman': 1,
#  'profoundly': 6,
#  "hawthorne's": 2,
#  'usonly': 2,
#  'copperfield': 1,
#  'practising': 3,
#  'preview': 2,
#  'whities': 1,
#  'threeninefive': 2,
#  'loew': 8,
#  'duplicates': 1,
#  'uwayu': 5,
#  "bloomin'": 2,
#  'negotiate]': 1,
#  'sawbuck!': 2,
#  'verificarsi': 1,
#  "'edge'": 2,
#  'symptom': 13,
#  'gmen': 1,
#  'oldest': 47,
#  'shotyou': 3,
#  'antarctica': 7,
#  "pimm's": 2,
#  'bird!': 4,
#  'reraise': 1,
#  'franklin': 53,
#  'doesnit': 2,
#  'slush': 4,
#  'absorbing': 4,
#  'ahhthen': 2,
#  'dextra': 2,
#  "dick's": 5,
#  'schoolsit': 1,
#  'apone': 1,
#  'ballpark': 5,
#  'defile': 2,
#  'conk': 2,
#  'withshe': 2,
#  'spangler': 2,
#  'swallow]': 1,
#  'chartered': 4,
#  '*disintegrating*my': 2,
#  'barneys': 1,
#  'exploded': 15,
#  'respectable': 42,
#  'wadja': 1,
#  'shoulld': 1,
#  'gennaro': 1,
#  'made': 2736,
#  'enemies': 106,
#  "crowd's": 2,
#  'turndown': 1,
#  "d'wana": 3,
#  'horrific': 3,
#  'reform': 22,
#  'foreground': 6,
#  'aside!': 3,
#  '93': 2,
#  'shep': 30,
#  'gains': 7,
#  'deadwhat': 2,
#  "'copter'": 1,
#  'zephram': 6,
#  "tricks'n": 1,
#  'rapped': 2,
#  'jantzen': 2,
#  'bluebacks': 2,
#  'humidity': 3,
#  'nicksan': 1,
#  'spring': 133,
#  'authorizing': 5,
#  'totalk': 2,
#  'jolt': 8,
#  "stoppin'": 6,
#  'jarheads': 1,
#  '*dinner*!': 2,
#  'disregards': 2,
#  'issue': 156,
#  "lynchin'when": 2,
#  "believin'": 3,
#  'routing': 3,
#  'outtoo': 2,
#  'yohoho': 1,
#  'coming!': 31,
#  'p11': 1,
#  'incinerators': 2,
#  'tobetsy': 2,
#  "brain's": 7,
#  "toain't": 1,
#  'smoking': 156,
#  'dormer': 1,
#  'haltdrowned': 1,
#  'crudley': 1,
#  'pabo': 1,
#  'initials': 27,
#  "travelin'": 6,
#  'cliffhangers': 2,
#  "finder's": 18,
#  'likelihood': 5,
#  'hawaiian': 7,
#  'androgenous': 1,
#  'receptionuhfor': 1,
#  "'her": 1,
#  'inhave': 1,
#  'pearlman': 1,
#  'tissue': 31,
#  'dubes': 2,
#  "jethro's": 2,
#  'reallyshould': 1,
#  'twentyfour!': 2,
#  'zeroonefive': 1,
#  'poker': 64,
#  'burr': 1,
#  'umass': 2,
#  'wedlock': 1,
#  'fallthen': 1,
#  'malik': 1,
#  'virus': 152,
#  'larue': 1,
#  'poppa': 7,
#  'fully': 109,
#  '703': 2,
#  'altmont': 1,
#  'neighbors': 80,
#  '600000': 1,
#  'gewiss!': 1,
#  'ohmygod!': 3,
#  'domesticated': 3,
#  'disburse': 4,
#  'squirbs': 1,
#  'persona': 5,
#  'bimboo': 3,
#  'yuppies': 5,
#  'hooters': 2,
#  'hair': 593,
#  'togetherso': 2,
#  'victoriously': 1,
#  'sees': 199,
#  "areligion'": 2,
#  'unbecoming': 6,
#  'infallible': 4,
#  'heisman': 2,
#  'whichi': 2,
#  'monicker': 1,
#  "'stab'": 1,
#  "hen's": 1,
#  'headon': 2,
#  'ricochet': 4,
#  'ginting': 1,
#  'channing': 39,
#  "worstick's": 1,
#  'burnedout': 2,
#  'harassments': 1,
#  'wither': 4,
#  'discovered': 126,
#  'actual': 76,
#  'track!': 1,
#  'alllooklook': 2,
#  'teresa': 60,
#  'wholehearted': 1,
#  'practitioner': 1,
#  'ceo': 11,
#  'ascared': 1,
#  'mural': 1,
#  'brits': 7,
#  'umhow': 1,
#  'liebkind': 16,
#  'serveza': 2,
#  'freedoms': 2,
#  "eagle's": 2,
#  '*plays*': 1,
#  'windstorm': 1,
#  'newhart': 2,
#  'danang': 4,
#  'backtoback': 3,
#  'diavolo': 1,
#  'whenwhenwhen': 2,
#  'ubaxteru!': 1,
#  'incident': 79,
#  "terry's": 5,
#  'knees!': 2,
#  'zookeeper': 2,
#  'bernstien': 1,
#  'overrate': 2,
#  'northto': 2,
#  'jumpship': 2,
#  'viscera': 4,
#  'group': 268,
#  "don'tbring": 2,
#  'dinners': 11,
#  'harrier': 2,
#  'salina': 2,
#  'noise!': 3,
#  'dredge': 6,
#  'flushed': 9,
#  'musclebound': 2,
#  'firpo': 2,
#  'mookie': 35,
#  'ronda': 2,
#  'ravening': 2,
#  "lone's": 2,
#  "whistlin'": 2,
#  'ubornu': 2,
#  'distemper': 1,
#  'stipes': 1,
#  'mangano': 2,
#  "'aunt": 2,
#  'ayegor!': 3,
#  'prunes': 5,
#  'duty': 213,
#  'sender': 7,
#  'coordinate': 12,
#  'piecing': 3,
#  'wellesly': 2,
#  'inspire': 17,
#  'likei': 5,
#  'amontillado': 1,
#  'cloth': 19,
#  'darling!you': 1,
#  "house's": 4,
#  'lukes': 2,
#  'futures': 7,
#  'twentyish': 4,
#  'pacmanned': 1,
#  'cabled': 1,
#  'follicles': 2,
#  'fauntleroy': 3,
#  'halibut': 3,
#  'abhorrent': 2,
#  'troina': 4,
#  'dered': 1,
#  'crossed': 71,
#  'tazinari]': 2,
#  'spoiled': 53,
#  'cavaliers': 1,
#  'jokey': 2,
#  'stoplight': 1,
#  'singapore': 7,
#  'yu': 18,
#  'replicates': 3,
#  'am*': 5,
#  'ucalmu': 1,
#  'ubitu': 1,
#  "tenth's": 2,
#  'cess': 1,
#  "shooter's": 2,
#  'bitches!': 7,
#  'reproduces': 2,
#  'worshipped': 13,
#  'dollareighty': 1,
#  'ashamed': 121,
#  'begrudge': 3,
#  'mco': 1,
#  'buzzing': 37,
#  'elvis': 67,
#  "desmond's": 2,
#  'evidenced': 2,
#  'him]': 5,
#  "much'": 1,
#  'hiss': 15,
#  'denomination': 3,
#  'uassu!': 1,
#  'aced': 7,
#  'landlubber': 2,
#  'comment': 39,
#  'nuns!': 4,
#  'spaciousnontime': 2,
#  'stams': 1,
#  'copbad': 2,
#  'keyhole': 7,
#  "operatin'": 1,
#  'spinks': 2,
#  'metals': 5,
#  'postlife': 2,
#  'moldavia': 4,
#  'exactement!': 2,
#  'scrilla': 2,
#  'am!': 55,
#  'moods': 19,
#  'kristel': 1,
#  'necks': 18,
#  'getty': 6,
#  'julias': 1,
#  'uterroristsu': 1,
#  'worrying!': 1,
#  'nomak': 13,
#  'pagers': 4,
#  'undefeated': 3,
#  'outrigger': 1,
#  'embarrass': 35,
#  'cantwell': 1,
#  'hissing': 1,
#  'naughty': 32,
#  'blood!': 23,
#  'carrion': 5,
#  'laboratorystorage': 1,
#  'fahrenheit': 1,
#  'whwhwhere': 1,
#  'materials': 30,
#  'pygmy': 1,
#  'gula': 2,
#  'austriangerman': 1,
#  'ramonano': 2,
#  'funkadelic': 3,
#  'me!!': 42,
#  "thin'": 4,
#  'hhi': 1,
#  'ideal!': 2,
#  'hustler': 29,
#  'allcountry': 1,
#  'click': 20,
#  'tittie': 4,
#  'progressive': 8,
#  'defiantly': 2,
#  'stoodup!': 1,
#  'toothache': 10,
#  'ethanyoull': 2,
#  'kitteridge': 2,
#  'elevated!': 2,
#  'ledge!': 2,
#  'williamson': 35,
#  'swoon!': 2,
#  'heyheyheyheyhey': 2,
#  'community': 115,
#  'heroworshipped': 2,
#  'lines!': 6,
#  "prob'lm": 1,
#  'riverbank!': 2,
#  'waiting!!!': 1,
#  'ubabyu': 2,
#  'andw': 2,
#  'shrinking': 3,
#  "democrats'": 1,
#  'obscenity': 1,
#  'personor': 2,
#  '72nd': 2,
#  'consul': 3,
#  "he'uz": 1,
#  'cofounders': 2,
#  'carel': 2,
#  "ogg's": 3,
#  'monthly': 17,
#  'uplinks': 4,
#  'upwent': 1,
#  'hassler': 2,
#  'proofpositive': 2,
#  'unwind': 6,
#  'heyho': 1,
#  'froze': 14,
#  'hearingscall': 2,
#  'jericho![4]': 1,
#  "6'6": 2,
#  'shortend': 2,
#  'dryers': 2,
#  'flier': 2,
#  'wielding': 3,
#  'rums': 1,
#  'ufileu': 1,
#  'complications': 31,
#  'indescribable': 4,
#  'coaxed': 1,
#  'chairing': 3,
#  'apprenticed': 1,
#  'demons!': 2,
#  'smut!!': 1,
#  'straps': 15,
#  'deserved!': 2,
#  'ulrich': 2,
#  'frankness': 2,
#  'megabitch': 1,
#  'chords': 2,
#  'swifts': 2,
#  'raise': 234,
#  'endless': 26,
#  'boarded': 9,
#  'mythe': 2,
#  'cost!': 2,
#  'hurtful': 6,
#  'preted': 1,
#  "musta'": 3,
#  'socioeconomic': 2,
#  'marrying': 65,
#  'aron': 4,
#  "their's": 1,
#  'cates': 10,
#  'ubooksu': 2,
#  'opens': 70,
#  'auggie': 68,
#  "marshal's": 2,
#  'glasssound': 1,
#  'polaris': 1,
#  'dropsi': 2,
#  'ravenfodder': 1,
#  'revoir': 13,
#  'energetically': 1,
#  'avoiding': 35,
#  'planned!': 1,
#  'slaphappy': 1,
#  'inaccuracy': 1,
#  'dod': 3,
#  'loosely!': 2,
#  'sonnyhorses': 1,
#  'itget': 2,
#  'pessimistic': 7,
#  'mule': 20,
#  'harlequin': 3,
#  'asleepthen': 1,
#  'itbelieve': 1,
#  "midget'n": 2,
#  "c'mere!": 4,
#  'egg!': 1,
#  'counselors': 7,
#  'sowe': 3,
#  'collins': 33,
#  'upmost': 1,
#  'barnes': 89,
#  'all]': 2,
#  'childs!': 4,
#  'workwhat': 3,
#  'duke': 78,
#  'truckand': 2,
#  'teletype': 5,
#  'rads': 2,
#  'madman': 53,
#  'blueberries': 3,
#  'penelope': 30,
#  'okay!': 83,
#  'prematurelyi': 2,
#  'mallory': 51,
#  "nobody's": 269,
#  'gott!': 1,
#  '168': 1,
#  "herit's": 2,
#  'ohhhhbaby': 1,
#  'nonrefundable': 1,
#  'pagebreak': 2,
#  'dictator': 5,
#  'illdivining': 1,
#  'dissemblers!': 1,
#  'cetshwayo': 2,
#  "chomsky's": 2,
#  'overcome': 20,
#  'orchestrate': 1,
#  'quaalude': 2,
#  'therrian': 4,
#  'sitcom': 8,
#  'coshairm': 1,
#  'muster': 9,
#  'endeavored': 1,
#  'catch': 593,
#  'centuries!': 4,
#  'optimistic': 19,
#  'pharoah': 2,
#  "crook's": 1,
#  'eightythousand': 1,
#  'subliminal': 2,
#  'robb': 2,
#  'woodlot': 2,
#  'doingat': 1,
#  'barman': 8,
#  'tic': 5,
#  'underwearand': 2,
#  'reservation': 71,
#  'chatwick': 3,
#  'player': 157,
#  'swim!': 3,
#  'ratios': 2,
#  'ahh!': 7,
#  'sodium': 12,
#  'rok': 7,
#  'normalizing': 1,
#  'tp': 4,
#  'fixit': 2,
#  'pearson': 4,
#  'swords': 15,
#  'lookalike': 7,
#  'formidable!': 2,
#  'riband': 1,
#  'lila': 52,
#  'mallet!': 1,
#  'freedman': 1,
#  'typo': 3,
#  'naomi': 16,
#  'littlejust': 1,
#  'jell!': 2,
#  'offenders': 7,
#  'mann': 3,
#  'iced': 27,
#  'casablanca': 64,
#  'declines': 1,
#  'typesand': 2,
#  'dip': 28,
#  'minh': 4,
#  "mary's": 24,
#  '1899': 2,
#  'groupu': 2,
#  'maserati': 4,
#  'scarface': 3,
#  'locking': 14,
#  'dalai': 13,
#  'vats': 2,
#  'questionsi': 2,
#  'whyd': 5,
#  'ledgers!': 2,
#  "it'scatwoman": 2,
#  'superflous': 1,
#  'como': 25,
#  'piranhas': 3,
#  'sleepover': 2,
#  'whips': 21,
#  "toby's": 16,
#  'cay': 3,
#  'lursa': 1,
#  'nails!': 1,
#  'perking': 2,
#  "j'youandyourfriend": 1,
#  'adequately': 2,
#  "thatthere's": 2,
#  'mightiness': 1,
#  'ambercon': 1,
#  'calls': 435,
#  'tv': 507,
#  'cream!!': 2,
#  'ebby': 10,
#  'cad': 1,
#  'consolation': 8,
#  'sex!': 10,
#  'massacre': 12,
#  'klingons': 14,
#  'forest!': 1,
#  'meurice': 16,
#  'seawater': 1,
#  'injured!': 1,
#  'welch!': 1,
#  'fedaykin': 1,
#  'occur': 48,
#  'snotty': 9,
#  'kegan': 1,
#  'proudest': 4,
#  "peace'": 1,
#  'didiing': 1,
#  'blvd': 1,
#  "punishments'": 1,
#  'nobby': 1,
#  'fullpage': 1,
#  'coffeetable': 2,
#  'okthis': 1,
#  "deliverin'": 2,
#  'sillyass': 2,
#  'forrester': 7,
#  'condition': 221,
#  'variable': 15,
#  'bushido': 1,
#  'inured': 2,
#  'historical': 22,
#  'scrambled': 20,
#  'nicollet': 1,
#  'dimples': 1,
#  'punchier': 1,
#  'party': 885,
#  'longjust': 1,
#  'atchya': 1,
#  'lunch!': 14,
#  'eugenie': 3,
#  'peddling': 9,
#  "momma's": 8,
#  'poolchair': 1,
#  'flannels': 1,
#  'anal': 17,
#  'berlin': 76,
#  'produce': 60,
#  'onequarter': 1,
#  'bowmen!': 2,
#  'astirring': 2,
#  'cyborgif': 2,
#  'deeprooted': 1,
#  'timewelcome': 1,
#  "'ie'": 2,
#  'items': 17,
#  'toin': 1,
#  'flouncy': 1,
#  'emerged': 2,
#  'asset': 16,
#  "palmer's": 6,
#  'drive!!': 1,
#  'kimlo': 4,
#  'tate': 9,
#  'whatja': 6,
#  'cassius': 12,
#  'onepuppet': 1,
#  'megazord': 1,
#  'rejoicing': 1,
#  'shitthe': 1,
#  'nicklaus': 4,
#  "rosebud's": 2,
#  'iman': 4,
#  'vultures': 10,
#  'laughriot': 1,
#  'predatory': 1,
#  'dons': 2,
#  'judie': 1,
#  'fuckup': 10,
#  'prejudge': 1,
#  'personality': 95,
#  'aknocking': 2,
#  'constipated': 3,
#  'paran': 2,
#  'uomigodu!': 2,
#  'wounds': 49,
#  'negativefive': 1,
#  'crackling': 1,
#  'stepbrother': 1,
#  'peoplei': 1,
#  'meyers': 17,
#  "pancho's": 1,
#  'imbecile': 29,
#  'mastery': 2,
#  'bolivia': 1,
#  'rufferwell': 1,
#  'lyu': 1,
#  'idiot!': 42,
#  'notfuck': 2,
#  "l'unica": 1,
#  'sodajerk': 2,
#  'perimeter!': 1,
#  'zealand': 6,
#  'sellable': 1,
#  'uriah': 4,
#  "ben's": 23,
#  'harkonnen': 4,
#  'rentals': 3,
#  'fatassed': 7,
#  'thingsyes': 2,
#  'rejuvenating': 1,
#  'dewitt': 18,
#  "supr'tendantwith": 1,
#  'nuketell': 1,
#  'ohashi': 3,
#  "pack's": 2,
#  'offers': 39,
#  'lieutenant': 288,
#  "surf's": 4,
#  'clothe': 2,
#  'thoughtout': 3,
#  "whizzin'": 1,
#  'really!': 38,
#  'togetherwe': 1,
#  'nestful': 1,
#  'slightly': 49,
#  'showand': 4,
#  'stanzimanzibanziwanzi!': 2,
#  'prewarp': 1,
#  'straordinario!': 1,
#  'vigil': 1,
#  'alibis': 7,
#  'cosmetics': 6,
#  'fait': 5,
#  'sooooo': 1,
#  'kicker!': 1,
#  'utwentyfive': 2,
#  'boatwright': 20,
#  'twit': 8,
#  "kerouac's": 1,
#  'subsequent': 4,
#  'shalom': 10,
#  'ufingersu': 1,
#  'bodysuit': 2,
#  'al!!': 2,
#  'leeloo': 11,
#  'kentucky': 37,
#  'quien': 2,
#  'heremaybemilitary': 1,
#  'teen': 14,
#  'gilroy': 2,
#  'misfiled': 1,
#  "asmilin'": 1,
#  'musketeer!': 1,
#  'wnew': 1,
#  'buglet': 2,
#  'stormed': 6,
#  'sprickenzie': 1,
#  'coincidence': 90,
#  'stop!!!!': 2,
#  'heparin': 2,
#  'cardone': 1,
#  'revolutionizes': 1,
#  'bones!': 4,
#  'honky': 5,
#  'yes': 10897,
#  'cattleprodded': 2,
#  'lunatics': 8,
#  'utodayu': 1,
#  'barrett': 19,
#  'ooh!': 6,
#  'evolve': 12,
#  'overpowering': 8,
#  'fella': 198,
#  'crosscountry': 1,
#  'sedated': 14,
#  "bates'": 7,
#  'sojef': 1,
#  'alamo': 13,
#  'hollering': 8,
#  'nina': 7,
#  ...}

# %%
# Creating two dictionaries that map the questions words and the answers words to a unique integer
threshold_questions = 20
questionswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_questions:
        questionswords2int[word] = word_number
        word_number += 1
threshold_answers = 20
answerswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_answers:
        answerswords2int[word] = word_number
        word_number += 1

# %%
questionswords2int
# Out:
# {'lousy': 4362,
#  'areas': 6679,
#  'clubs': 4363,
#  'spotted': 0,
#  'teaching': 1134,
#  'billion': 6680,
#  'lainey': 5945,
#  'tahoe': 7772,
#  'silver': 2246,
#  'harvard': 3274,
#  'brenda': 5506,
#  'public': 2251,
#  'lord!': 1,
#  'homeless': 20,
#  'subject': 5507,
#  'jumped': 2,
#  'depends': 2255,
#  'yelled': 2245,
#  'sacrificed': 8386,
#  'goddam': 3277,
#  'helps': 1135,
#  'interview': 5461,
#  'molecular': 3,
#  'judgement': 5510,
#  'registered': 8176,
#  'dam': 1136,
#  'ouch': 3278,
#  'chad': 1601,
#  'scream': 8483,
#  'shows': 6683,
#  'uh': 6684,
#  'protein': 6685,
#  'proceed': 4,
#  'arlo': 5511,
#  'defeat': 3279,
#  'crusher': 2248,
#  'digital': 4365,
#  'votes': 1137,
#  'polish': 7946,
#  'dc': 7777,
#  'talking': 3280,
#  'tomorrow': 4255,
#  'tub': 4023,
#  'explained': 7580,
#  'yonder': 5,
#  'us!': 3281,
#  'figuring': 4389,
#  'pilots': 6,
#  'weight': 4391,
#  'ass!': 7780,
#  'fighter': 3283,
#  'enter': 1572,
#  'webster': 7653,
#  'neil': 6686,
#  'behave': 8,
#  'concentration': 5514,
#  'or': 1546,
#  'gig': 4399,
#  "d'you": 9,
#  'ballroom': 2250,
#  'cheeks': 5516,
#  "walkin'": 5517,
#  'appearance': 3284,
#  'goodbye': 6689,
#  'partial': 3275,
#  'sticking': 10,
#  'sink': 1138,
#  'containment': 2253,
#  'huge': 11,
#  'geneva': 2745,
#  'jasper': 6691,
#  'reed': 8646,
#  'hiding': 5518,
#  'rendezvous': 7607,
#  'fashion': 13,
#  'warriors': 3285,
#  'bela': 7783,
#  'fooling': 5519,
#  'legs': 3838,
#  'expense': 3286,
#  'flea': 6904,
#  'chang': 1139,
#  'streets': 3287,
#  'denied': 4364,
#  'wings': 14,
#  'hostages': 15,
#  'significant': 6140,
#  'attacking': 4370,
#  'grandma': 1140,
#  'supportive': 2304,
#  'seventh': 1141,
#  'detailed': 1142,
#  'indicates': 4371,
#  'stab': 6739,
#  'serial': 2073,
#  'ni!': 5520,
#  'rib': 6692,
#  'walter': 7785,
#  'cairo': 3290,
#  'angels': 3291,
#  'contribution': 7786,
#  'wheelchair': 4372,
#  'butt': 6693,
#  'adjust': 4439,
#  'confused': 2247,
#  'kept': 2256,
#  'z': 16,
#  'tokyo': 17,
#  "fixin'": 18,
#  'civilian': 19,
#  'oh': 7787,
#  'gain': 2257,
#  'knees': 1056,
#  'conduct': 5523,
#  'work!': 21,
#  'humperdinck': 1143,
#  'fears': 22,
#  'cop': 6697,
#  'current': 8014,
#  'bath': 4376,
#  'claims': 6346,
#  'myself!': 4074,
#  'can': 6004,
#  'runs': 3292,
#  'pick': 1144,
#  'commission': 3293,
#  '45': 1145,
#  'driver': 6765,
#  'shower': 7788,
#  'target': 7789,
#  'sooner': 7790,
#  'deal!': 1507,
#  'voices': 2260,
#  'dearest': 6698,
#  'robbed': 4377,
#  'ants': 23,
#  'windows': 5495,
#  'harmless': 6772,
#  'debts': 24,
#  'moscow': 5935,
#  "'a": 2339,
#  'whack': 4378,
#  "leavin'": 2261,
#  'fathers': 8405,
#  'sabotage': 8132,
#  'celebrate': 1147,
#  '13': 4379,
#  'acres': 25,
#  'banished': 2264,
#  'mace': 1148,
#  'away!': 3296,
#  'obligation': 6110,
#  'transit': 26,
#  'connect': 1149,
#  'mouths': 4380,
#  'nanobot': 4381,
#  'sends': 2359,
#  'transmission': 2266,
#  'town!': 2363,
#  'aim': 29,
#  'terry': 3924,
#  'estate': 6700,
#  'outfit': 1151,
#  'objection!': 5525,
#  'pool': 3298,
#  'drama': 5526,
#  'temper': 3299,
#  'written': 2368,
#  'crane': 8097,
#  'chairs': 7794,
#  'valiant': 4382,
#  'mattress': 7795,
#  'responding': 6701,
#  'classes': 4383,
#  'animal!': 2268,
#  'switch': 3300,
#  'general': 4384,
#  'generous': 1152,
#  'it!': 7796,
#  'discreet': 5528,
#  'dressed': 1829,
#  'destroying': 3301,
#  'explode': 7012,
#  'flaw': 7215,
#  'strangers': 5529,
#  'he!': 8133,
#  'ripper': 4385,
#  'filled': 8553,
#  'gamble': 6702,
#  'cigarettes': 4366,
#  'vice': 3302,
#  'joy': 7799,
#  'clyde': 7370,
#  'prenup': 3303,
#  'awkward': 3304,
#  'kelly': 5530,
#  'faithful': 7809,
#  "driver's": 8401,
#  'oregon': 8710,
#  'associates': 30,
#  'lose': 2269,
#  'causes': 2270,
#  'cigarette': 3839,
#  'surprises': 2271,
#  'd': 7801,
#  'greedy': 8033,
#  'ruin': 2272,
#  'shhhh': 7749,
#  'asia': 5531,
#  'wounded': 32,
#  'lifestyle': 6703,
#  'some': 33,
#  'weekends': 2397,
#  'norman': 34,
#  'false': 3305,
#  'disco': 7508,
#  'vienna': 7891,
#  'arriving': 4936,
#  'sophisticated': 5532,
#  'remarried': 2275,
#  'clarify': 6930,
#  'blamed': 1154,
#  'answering': 4386,
#  'here!!': 8650,
#  'loyal': 3308,
#  'fits': 8327,
#  'dad!': 5320,
#  'pain': 7778,
#  'worlds': 35,
#  "drivin'": 5533,
#  'wh': 6705,
#  'dwight': 2276,
#  'university': 7059,
#  "layin'": 7804,
#  'doyle': 6753,
#  'events': 5874,
#  'besides': 2277,
#  'boys': 2347,
#  'noir': 5947,
#  'assassination': 2414,
#  'jacqueline': 2278,
#  "hasn't": 5512,
#  'fences': 4367,
#  'cuban': 6707,
#  'ourselves': 5535,
#  'eventually': 4387,
#  'each': 5472,
#  'blind': 2279,
#  'goddamnit!': 6849,
#  'mean!': 7480,
#  'chat': 1155,
#  'uniforms': 1156,
#  'environment': 2280,
#  'admiral': 8723,
#  'voodoo': 3312,
#  'angeles': 5513,
#  'paid': 1157,
#  'casino': 36,
#  'bible': 7808,
#  'reveal': 37,
#  'tool': 4548,
#  'interrogation': 2281,
#  'double': 1158,
#  'multiple': 2282,
#  "givin'": 1159,
#  'experiences': 4554,
#  'unexpected': 6322,
#  'pole': 4556,
#  'in!': 6710,
#  'nearly': 1160,
#  'informant': 8125,
#  'late!': 2283,
#  'oldest': 38,
#  "y'know": 5538,
#  'graveyard': 4559,
#  'swedish': 4394,
#  'franklin': 39,
#  'wear': 6711,
#  'celebrity': 1162,
#  'knock': 8479,
#  'harold': 2284,
#  'un': 3867,
#  'dozen': 8307,
#  'types': 7515,
#  'mandrake': 2776,
#  'disposal': 3313,
#  'medium': 1163,
#  'en': 7084,
#  'advised': 1164,
#  'authorities': 6712,
#  'goal': 6713,
#  'open': 1165,
#  'married': 3314,
#  'simone': 1166,
#  'respectable': 40,
#  'caring': 6875,
#  'cameras': 6714,
#  'making': 4395,
#  'made': 41,
#  'nine': 5541,
#  'terminate': 4579,
#  'fact': 6837,
#  'cole': 2610,
#  'reform': 43,
#  'cross': 6715,
#  'unknown': 5542,
#  'shep': 44,
#  'improved': 2286,
#  'unothingu': 6287,
#  'andrew': 4396,
#  'vicki': 1168,
#  'degrees': 2287,
#  'eduard': 6716,
#  'eliminate': 5543,
#  'guy': 3687,
#  'traveled': 4397,
#  'much': 8402,
#  'spreading': 5545,
#  'phyllis': 2076,
#  'global': 7813,
#  'mph': 6688,
#  'stinks': 5546,
#  'yards': 1553,
#  'prayers': 2288,
#  'minutes!': 2289,
#  'clinic': 3316,
#  'closet': 5547,
#  'misunderstood': 3317,
#  'breach': 7814,
#  'hired': 3318,
#  'ought': 4401,
#  'issue': 46,
#  'fly': 7927,
#  'limo': 5550,
#  'ties': 5551,
#  'rocks': 3319,
#  'coming!': 47,
#  'dea': 6720,
#  'bear': 6721,
#  'paper': 1170,
#  'smoking': 48,
#  'curiosity': 4404,
#  'referring': 5659,
#  'scares': 4405,
#  'bay': 8221,
#  'gold': 4217,
#  'initials': 49,
#  'riot': 5552,
#  'wrist': 1171,
#  'wheel': 5553,
#  'results': 6723,
#  'brains': 3320,
#  'point': 2290,
#  'woody': 2291,
#  '100': 8635,
#  'prevent': 7818,
#  'tissue': 50,
#  'path': 4407,
#  'insignificant': 6724,
#  'radical': 5555,
#  'lips': 4635,
#  'conversations': 4408,
#  'poker': 51,
#  'treated': 4409,
#  'compassion': 1172,
#  'pulls': 6725,
#  'bend': 2292,
#  'virus': 52,
#  'committee': 6726,
#  'wallet': 1904,
#  'will!': 7820,
#  'cadillac': 7941,
#  'war': 7821,
#  'rational': 2294,
#  'sunk': 5556,
#  'holiday': 2295,
#  'hookers': 1173,
#  'offices': 2519,
#  'souls': 7822,
#  'images': 5558,
#  'successful': 1174,
#  'happiness': 4411,
#  "couldn't": 3321,
#  'sees': 56,
#  'barney': 4369,
#  'albert': 7824,
#  'secret': 6075,
#  'fade': 5559,
#  "name's": 7825,
#  'drum': 4412,
#  "majesty's": 4413,
#  'editor': 2690,
#  'channing': 57,
#  'gets': 7826,
#  '24': 3322,
#  'flood': 4414,
#  "carl's": 5560,
#  'discovered': 58,
#  'acts': 4415,
#  'owes': 4416,
#  "it'": 3842,
#  'similar': 2297,
#  'meetings': 2298,
#  'create': 7827,
#  'teresa': 60,
#  'unhappy': 2778,
#  'f': 7828,
#  'negotiation': 5562,
#  'gruner': 8673,
#  'attorney': 7502,
#  'egypt': 1177,
#  'complete': 7830,
#  'christ!': 6731,
#  'additional': 1178,
#  "worryin'": 3323,
#  'heller': 7831,
#  'benefits': 1179,
#  'cab': 3324,
#  'star': 6727,
#  'priority': 2080,
#  'incident': 61,
#  'concept': 7832,
#  'faith': 7016,
#  'daylight': 1181,
#  'vegas': 2547,
#  'assuming': 1182,
#  'group': 62,
#  'nicolet': 2301,
#  'hand': 1183,
#  'sandra': 6960,
#  'agent': 4418,
#  'returns': 3326,
#  'leaves': 5563,
#  'terrible!': 6812,
#  'sexy': 2553,
#  'planted': 1184,
#  'mookie': 63,
#  'masters': 1185,
#  'torrance': 4195,
#  'delicate': 8054,
#  'corridor': 3327,
#  'duty': 64,
#  'killing': 7408,
#  'mckenna': 3328,
#  'blue': 2565,
#  'mass': 3852,
#  'jane': 358,
#  'to!': 4421,
#  'opinions': 2302,
#  "month's": 1186,
#  'decided': 2569,
#  'bucket': 2254,
#  "whatever's": 1187,
#  'walter!': 5564,
#  'etc': 7835,
#  '99': 7999,
#  'hamilton': 5565,
#  'corny': 1188,
#  'crossed': 65,
#  'spoiled': 66,
#  'trusted': 4422,
#  'phone': 1189,
#  'requesting': 8135,
#  'continuing': 7836,
#  'vancouver': 4423,
#  'itself': 5567,
#  'minister': 1519,
#  'panthers': 4424,
#  'ouch!': 1190,
#  'bullets': 2303,
#  'models': 1191,
#  'forest': 3329,
#  'honeymoon': 5569,
#  'tune': 4425,
#  'loan': 7837,
#  'demon': 7838,
#  'stream': 390,
#  'theirs': 4426,
#  'buzzing': 68,
#  'elvis': 69,
#  'terminal': 6892,
#  'educated': 1193,
#  'police': 3332,
#  'despise': 8655,
#  'okay': 3333,
#  'chocolate': 3334,
#  'stealing': 2596,
#  'accessory': 5570,
#  'comment': 70,
#  'proposed': 5571,
#  'sleepy': 7839,
#  'puke': 4427,
#  'contrary': 1194,
#  'deeper': 3335,
#  'indians': 4428,
#  'syndrome': 6274,
#  'spends': 7908,
#  'pittsburgh': 7623,
#  'bud': 5724,
#  'kong': 4744,
#  'am!': 71,
#  'time': 3336,
#  'mixer': 2611,
#  'days': 6288,
#  'cuervo': 1195,
#  'looking': 2613,
#  'currently': 5925,
#  'sober': 6119,
#  'embarrass': 72,
#  'jumping': 8329,
#  'investigation': 2305,
#  'naughty': 73,
#  'systems': 6741,
#  'frances': 6197,
#  'blood!': 74,
#  'tasted': 8524,
#  'lies': 4430,
#  'tripp': 420,
#  'potential': 1197,
#  'adults': 4432,
#  'medicine': 1198,
#  "haven't": 1199,
#  'emergency': 5575,
#  'nevertheless': 6742,
#  'me!!': 76,
#  'proud': 7842,
#  'hustler': 77,
#  'tools': 2306,
#  'leg': 5576,
#  'flying': 5522,
#  'kat': 4775,
#  'click': 78,
#  'rolling': 8312,
#  'of': 5149,
#  'gestapo': 3338,
#  'marshall': 7036,
#  'rome': 4433,
#  'sad': 1200,
#  'waiter': 6744,
#  'confidentiality': 1201,
#  'grandson': 5720,
#  'habit': 2307,
#  'williamson': 79,
#  'korea': 2308,
#  "knowin'": 5577,
#  'community': 80,
#  'depending': 4434,
#  'rick': 8656,
#  'attempt': 1204,
#  'paying': 5578,
#  'nose': 3341,
#  'advantage': 1205,
#  'demand': 1206,
#  'brady': 4435,
#  'robert': 4436,
#  'shining': 6746,
#  'anthony': 2310,
#  'what': 4437,
#  'interfere': 2311,
#  'girl!': 5579,
#  'sauce': 2312,
#  'presented': 5580,
#  'leaders': 4438,
#  'favour': 2659,
#  'federal': 1208,
#  'russia': 1209,
#  'pleases': 1210,
#  'plants': 5581,
#  'sulu': 2074,
#  'for!': 6366,
#  'moral': 6747,
#  'paulie': 3344,
#  'grendel': 2313,
#  'complications': 81,
#  'flyer': 3345,
#  'tent': 5584,
#  'episode': 6885,
#  'other': 1910,
#  'pie': 2670,
#  'snoop': 2315,
#  'oldfashioned': 3346,
#  'raise': 82,
#  'relax': 2316,
#  'disgust': 7846,
#  'active': 6748,
#  'endless': 83,
#  'moron': 6749,
#  'cost': 6750,
#  'personally': 1213,
#  'gum': 5585,
#  'fifty': 3348,
#  'pooch': 6751,
#  'bottles': 4373,
#  'marrying': 84,
#  'chronic': 5586,
#  'pour': 1214,
#  'oklahoma': 3349,
#  'opens': 85,
#  'truck': 6537,
#  'gear': 1215,
#  'auggie': 86,
#  'interested': 3351,
#  'having': 1216,
#  'jewels': 1716,
#  'jews': 8254,
#  'marines': 1218,
#  'marie': 3353,
#  'apes': 3354,
#  'division': 4835,
#  'mankind': 4442,
#  'avoiding': 87,
#  'draw': 7869,
#  'count': 4443,
#  'instead': 5588,
#  'uthatu': 1219,
#  'mule': 88,
#  'gwen': 3355,
#  'echo': 3356,
#  'crap': 3357,
#  'brutal': 6695,
#  'stares': 2318,
#  'josephine': 5589,
#  'gump': 7018,
#  'videos': 1220,
#  'collins': 89,
#  'date': 6755,
#  'fergus': 2319,
#  'barnes': 90,
#  'mainland': 1221,
#  'rigged': 4445,
#  'duke': 91,
#  'apology': 5590,
#  'invasion': 3358,
#  'might': 3359,
#  'sample': 3360,
#  'el': 7850,
#  'madman': 92,
#  'penelope': 93,
#  'joanna': 1222,
#  'father!': 2320,
#  'okay!': 94,
#  'hostile': 1153,
#  'appeared': 6923,
#  "nobody's": 96,
#  'canada': 7853,
#  'whaddaya': 2321,
#  'electricity': 3362,
#  'listened': 5592,
#  'behavior': 5926,
#  'starks': 1223,
#  'overcome': 97,
#  'woulda': 2322,
#  'known': 5593,
#  'anybody!': 3363,
#  "'im": 2323,
#  'catch': 98,
#  'measures': 1224,
#  'chain': 6859,
#  'wheeler': 2325,
#  'planr': 4446,
#  'sucks': 2326,
#  'debbie': 2327,
#  'connection': 7507,
#  'copper': 3366,
#  'appropriate': 4683,
#  'quiet!': 1225,
#  'satellite': 2328,
#  'plates': 8255,
#  'major': 7856,
#  'rmph': 1226,
#  'reservation': 99,
#  'backs': 4447,
#  'player': 100,
#  'disappeared': 7164,
#  'marry': 6760,
#  '17': 5595,
#  'dumber': 2329,
#  'sucked': 1227,
#  'elected': 4448,
#  'dammit': 2330,
#  'metro': 2331,
#  'woke': 1228,
#  'ganz': 6762,
#  'jon': 6763,
#  'gone': 4449,
#  'counting': 3370,
#  'disgrace': 5598,
#  'lonesome': 2742,
#  'values': 5599,
#  'ellen': 2332,
#  'minor': 3113,
#  'everybody!': 5601,
#  "waitin'": 7859,
#  'adopted': 2333,
#  'iced': 102,
#  'casablanca': 103,
#  'length': 1373,
#  'dip': 104,
#  'edition': 3371,
#  "mary's": 105,
#  'released': 5604,
#  'der': 3372,
#  'grip': 5825,
#  'anyways': 7861,
#  'kings': 2334,
#  'bad': 4919,
#  'jerome': 1230,
#  'sie': 4450,
#  'como': 106,
#  'bluestar': 4451,
#  'whips': 107,
#  'hmm': 7192,
#  'specifically': 7863,
#  'mouth!': 8645,
#  'dust': 5155,
#  'politics': 5605,
#  'able': 8637,
#  'unowu': 6766,
#  'rejected': 2960,
#  'sting': 1231,
#  'real!': 3375,
#  'mug': 7411,
#  'calls': 108,
#  'tv': 109,
#  'flight': 4929,
#  'crawling': 7443,
#  'fairly': 1233,
#  'learning': 600,
#  'burgel': 6768,
#  'ancient': 4930,
#  'ferrie': 601,
#  'lying': 7865,
#  'brass': 8488,
#  'mayor': 6769,
#  'food': 2773,
#  'picking': 1235,
#  'slots': 5929,
#  'surrounded': 7866,
#  'thorwald': 7867,
#  'forgets': 1236,
#  'oughta': 1065,
#  'borrow': 6770,
#  'buy': 5606,
#  'karen': 1237,
#  'sounding': 4947,
#  "doin'": 2335,
#  'parry': 5607,
#  'senate': 3377,
#  'hi!': 4454,
#  'upper': 3378,
#  'sheep': 6771,
#  "startin'": 2336,
#  'kurtz': 2337,
#  'monster': 4952,
#  'particular': 788,
#  'historical': 112,
#  'risk': 7456,
#  'ken': 2338,
#  'camera': 4306,
#  'party': 114,
#  'returning': 7792,
#  'nights': 5608,
#  'shells': 4964,
#  'skipped': 4970,
#  'executive': 5708,
#  'crashed': 1239,
#  'legally': 4455,
#  'berlin': 115,
#  'produce': 116,
#  'four': 6125,
#  'fortunately': 4973,
#  'passport': 4456,
#  'requests': 3259,
#  'sold': 4457,
#  'plans': 4974,
#  'ground': 3381,
#  'gosh': 2340,
#  'supernatural': 2341,
#  'covered': 5610,
#  'wrists': 4459,
#  'kicks': 3853,
#  'tourists': 2342,
#  'zavitz': 2343,
#  'seventytwo': 7656,
#  'rats': 3382,
#  'gekko': 3383,
#  "'i": 6775,
#  'uandu': 3384,
#  'sits': 4460,
#  'luthor': 1241,
#  'chopper': 5612,
#  'married!': 7874,
#  'kingdom': 7020,
#  'captured': 4983,
#  'ready': 3854,
#  'specific': 6980,
#  'telephone': 6339,
#  'darkness': 4985,
#  'delivered': 5614,
#  'gentle': 2813,
#  'silent': 8558,
#  'customer': 1242,
#  'gibson': 4461,
#  'tour': 2345,
#  'sympathetic': 7256,
#  'salon': 3385,
#  'he': 4993,
#  'knowing': 1243,
#  'repeating': 2107,
#  'cheat': 5615,
#  'wounds': 118,
#  'anytime': 1244,
#  'instrument': 1245,
#  'vegetable': 7207,
#  'whacked': 4463,
#  'mcmurphy': 5616,
#  'imbecile': 119,
#  'suite': 3386,
#  'promise': 2599,
#  'myers': 6776,
#  'grade': 8493,
#  'idiot!': 120,
#  'flush': 4465,
#  'formal': 6778,
#  'how': 5617,
#  'growing': 1246,
#  'islands': 5010,
#  'review': 5618,
#  'human': 7877,
#  "ben's": 121,
#  'luca': 6779,
#  'selina': 4466,
#  "town's": 2833,
#  'arguing': 2348,
#  'whereabouts': 2349,
#  'category': 3387,
#  'rebels': 2835,
#  'simple': 4467,
#  'katrina': 6780,
#  'divine': 7592,
#  'lipstick': 4468,
#  'bites': 7879,
#  'considerate': 5620,
#  'day!': 3895,
#  'below': 3473,
#  'warden': 1247,
#  'off': 3388,
#  'microwave': 3389,
#  'transport': 3206,
#  'concerns': 2790,
#  'really!': 124,
#  'martini': 2350,
#  'obviously': 5622,
#  'phase': 1249,
#  'slightly': 125,
#  'dash': 1250,
#  'heroes': 8803,
#  'michaels': 7027,
#  'officially': 4471,
#  'duties': 4472,
#  'brace': 6782,
#  'understands': 2850,
#  'profits': 1251,
#  'reverend': 1252,
#  'boatwright': 126,
#  "mom's": 2856,
#  'painted': 5624,
#  'reach': 5625,
#  'office': 7793,
#  "thing's": 5160,
#  'charlie!': 4474,
#  'peggy': 1253,
#  'facing': 2353,
#  'and': 4475,
#  'kentucky': 127,
#  '22': 5628,
#  'treatment': 1254,
#  'alma': 534,
#  'german': 5629,
#  'kick': 4017,
#  'letty': 8665,
#  'tattoo': 2265,
#  'lucy': 6785,
#  'flies': 7962,
#  'balls': 1255,
#  'feelings': 7884,
#  'merrick': 7885,
#  'began': 1256,
#  'whose': 3177,
#  'neither': 6384,
#  'commercial': 5630,
#  'enormous': 3392,
#  'reckon': 7011,
#  'happens': 2356,
#  'grace': 3856,
#  'walking': 4479,
#  'slack': 5632,
#  'pennsylvania': 2357,
#  'merit': 3394,
#  'fella': 130,
#  'you!!': 296,
#  "wonderin'": 8820,
#  'polo': 1723,
#  'youth': 5064,
#  'dumper': 8662,
#  'vault': 3857,
#  "'the": 131,
#  'delightful': 4206,
#  'building': 1257,
#  'physical': 132,
#  'adrenaline': 4480,
#  'evidence': 7888,
#  'top': 5810,
#  'reliant': 5634,
#  'dollar': 5635,
#  'sh': 5072,
#  'barton': 4481,
#  'buddy': 5636,
#  'invention': 713,
#  'macleod': 2360,
#  'draft': 1259,
#  'universal': 5638,
#  'casper': 6598,
#  "let's": 7971,
#  'argument': 133,
#  'speech': 134,
#  'troops': 2362,
#  'possibilities': 135,
#  'matters': 3396,
#  'came': 4483,
#  'operation': 5087,
#  'buildings': 4207,
#  'already': 1261,
#  'eternal': 1262,
#  'homicidal': 136,
#  'setting': 2364,
#  'cars': 8246,
#  "takin'": 2964,
#  'devil': 5639,
#  'ink': 137,
#  'sweat': 3399,
#  'bundy': 1263,
#  'suckers': 138,
#  "one's": 6377,
#  'directors': 1724,
#  'kim': 6788,
#  'grasp': 8317,
#  'remind': 1264,
#  'laugh': 7889,
#  'reggie': 5582,
#  'screaming': 3400,
#  'richard': 2091,
#  'rehab': 4484,
#  'fields': 4485,
#  'tit': 4486,
#  'savage': 1265,
#  'sharing': 5875,
#  'protecting': 7890,
#  'determine': 139,
#  'spats': 5731,
#  'reads': 2921,
#  'ape': 6789,
#  'haul': 3403,
#  'crimes': 5641,
#  'pacific': 5267,
#  'firm': 5642,
#  'impress': 6790,
#  'pointing': 8698,
#  'quitting': 4487,
#  '30': 1266,
#  'swamp': 7892,
#  'tipping': 1267,
#  'patchett': 4488,
#  'assumed': 7893,
#  'rosa': 2367,
#  'flipped': 3405,
#  'destroyed': 7237,
#  'darryl': 1725,
#  'weaker': 5984,
#  'happier': 1355,
#  'inspiration': 140,
#  'carter': 6338,
#  'pg&e': 3406,
#  'fixed': 5120,
#  'cosmo': 8492,
#  'stroll': 8375,
#  'ya': 6046,
#  'les': 4489,
#  'colorful': 1269,
#  'may': 3407,
#  'dark': 7149,
#  'deaf': 5645,
#  'swimming': 4490,
#  'entertaining': 141,
#  'affected': 2203,
#  'foolish': 1270,
#  'marty': 2369,
#  'peaceful': 1271,
#  'taxes': 5647,
#  'implying': 3408,
#  ...}

# %%
# Adding the last tokens to these two dictionaries
tokens = ['<PAD>', '<EOS>', '<OUT>', '<SOS>']
for token in tokens:
    questionswords2int[token] = len(questionswords2int) + 1
for token in tokens:
    answerswords2int[token] = len(answerswords2int) + 1

# %%
# Creating the inverse dictionary of the answerswords2int dictionary
answersints2word = {w_i: w for w, w_i in answerswords2int.items()}
 
# Adding the End Of String token to the end of every answer
for i in range(len(clean_answers)):
    clean_answers[i] += ' <EOS>'

# %%
# Translating all the questions and the answers into integers
# and Replacing all the words that were filtered out by <OUT> 
questions_into_int = []
for question in clean_questions:
    ints = []
    for word in question.split():
        if word not in questionswords2int:
            ints.append(questionswords2int['<OUT>'])
        else:
            ints.append(questionswords2int[word])
    questions_into_int.append(ints)
answers_into_int = []
for answer in clean_answers:
    ints = []
    for word in answer.split():
        if word not in answerswords2int:
            ints.append(answerswords2int['<OUT>'])
        else:
            ints.append(answerswords2int[word])
    answers_into_int.append(ints)

# %%
#sorted_clean_questions[int(len(sorted_clean_questions) * 0.15):]
#sorted_clean_answers[20000:]

# %%
# Sorting questions and answers by the length of questions
sorted_clean_questions = []
sorted_clean_answers = []
for length in range(1, 25 + 1):
    for i in enumerate(questions_into_int):
        if len(i[1]) == length:
            sorted_clean_questions.append(questions_into_int[i[0]])
            sorted_clean_answers.append(answers_into_int[i[0]])

# %%
# Splitting the questions and answers into training and validation sets
training_validation_split = int(len(sorted_clean_questions) * 0.15)
training_questions = sorted_clean_questions[training_validation_split:]
training_answers = sorted_clean_answers[training_validation_split:]
validation_questions = sorted_clean_questions[:training_validation_split]
validation_answers = sorted_clean_answers[:training_validation_split]
training_answers[0]
# Out:
# [8647,
#  2543,
#  2890,
#  5383,
#  3170,
#  5134,
#  8824,
#  8824,
#  1802,
#  5149,
#  6448,
#  2189,
#  8824,
#  957,
#  6038,
#  5134,
#  8824,
#  8824,
#  3313,
#  8823]

# %%
########## PART 2 - BUILDING THE SEQ2SEQ MODEL ##########
 
 
 
# Creating placeholders for the inputs and the targets
def model_inputs():
    inputs = tf.placeholder(tf.int32, [None, None], name = 'input')
    targets = tf.placeholder(tf.int32, [None, None], name = 'target')
    lr = tf.placeholder(tf.float32, name = 'learning_rate')
    keep_prob = tf.placeholder(tf.float32, name = 'keep_prob')
    return inputs, targets, lr, keep_prob
 
# Preprocessing the targets
def preprocess_targets(targets, word2int, batch_size):
    left_side = tf.fill([batch_size, 1], word2int['<SOS>'])
    right_side = tf.strided_slice(targets, [0,0], [batch_size, -1], [1,1])
    preprocessed_targets = tf.concat([left_side, right_side], 1)
    return preprocessed_targets
 
# Creating the Encoder RNN
def encoder_rnn(rnn_inputs, rnn_size, num_layers, keep_prob, sequence_length):
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
    encoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
    encoder_output, encoder_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = encoder_cell,
                                                                    cell_bw = encoder_cell,
                                                                    sequence_length = sequence_length,
                                                                    inputs = rnn_inputs,
                                                                    dtype = tf.float32)
    return encoder_state

# %%
#batch_size = 64
#model_inputs()
#questionswords2int['<SOS>']
#tf.fill([64,1],answerswords2int['<SOS>'])
#tf.strided_slice(training_answers, [0,0], [64, -1], [1,1])

#preprocess_targets(training_answers, answerswords2int, 64)

# %%
def decode_training_set(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob, batch_size): 
    '''Decode the training data'''

    attention_states = tf.zeros([batch_size, 1, dec_cell.output_size])

    att_keys, att_vals, att_score_fn, att_construct_fn = tf.contrib.seq2seq.prepare_attention(attention_states,
                                                 attention_option="bahdanau",
                                                 num_units=dec_cell.output_size)

    train_decoder_fn = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state[0],
                                                                     att_keys,
                                                                     att_vals,
                                                                     att_score_fn,
                                                                     att_construct_fn,
                                                                     name = "attn_dec_train")
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell,
                                                              train_decoder_fn,
                                                              dec_embed_input,
                                                              sequence_length,
                                                              scope=decoding_scope)
    train_pred_drop = tf.nn.dropout(train_pred, keep_prob)
    return output_fn(train_pred_drop)

# %%
 
# Decoding the training set
def decode_training_set(encoder_state, decoder_cell, decoder_embedded_input, sequence_length, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    training_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              name = "attn_dec_train")
    decoder_output, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                              training_decoder_function,
                                                                                                              decoder_embedded_input,
                                                                                                              sequence_length,
                                                                                                              scope = decoding_scope)
    decoder_output_dropout = tf.nn.dropout(decoder_output, keep_prob)
    return output_function(decoder_output_dropout)

# %%
# Decoding the test/validation set
def decode_test_set(encoder_state, decoder_cell, decoder_embeddings_matrix, sos_id, eos_id, maximum_length, num_words, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    test_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_inference(output_function,
                                                                              encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              decoder_embeddings_matrix,
                                                                              sos_id,
                                                                              eos_id,
                                                                              maximum_length,
                                                                              num_words,
                                                                              name = "attn_dec_inf")
    test_predictions, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                                test_decoder_function,
                                                                                                                scope = decoding_scope)
    return test_predictions

# %%
 
# Creating the Decoder RNN
def decoder_rnn(decoder_embedded_input, decoder_embeddings_matrix, encoder_state, num_words, sequence_length, rnn_size, num_layers, word2int, keep_prob, batch_size):
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
        decoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
        weights = tf.truncated_normal_initializer(stddev = 0.1)
        biases = tf.zeros_initializer()
        output_function = lambda x: tf.contrib.layers.fully_connected(x,
                                                                      num_words,
                                                                      None,
                                                                      scope = decoding_scope,
                                                                      weights_initializer = weights,
                                                                      biases_initializer = biases)
        training_predictions = decode_training_set(encoder_state,
                                                   decoder_cell,
                                                   decoder_embedded_input,
                                                   sequence_length,
                                                   decoding_scope,
                                                   output_function,
                                                   keep_prob,
                                                   batch_size)
        decoding_scope.reuse_variables()
        test_predictions = decode_test_set(encoder_state,
                                           decoder_cell,
                                           decoder_embeddings_matrix,
                                           word2int['<SOS>'],
                                           word2int['<EOS>'],
                                           sequence_length - 1,
                                           num_words,
                                           decoding_scope,
                                           output_function,
                                           keep_prob,
                                           batch_size)
    return training_predictions, test_predictions
 
# Building the seq2seq model
def seq2seq_model(inputs, targets, keep_prob, batch_size, sequence_length, answers_num_words, questions_num_words, encoder_embedding_size, decoder_embedding_size, rnn_size, num_layers, questionswords2int):
    encoder_embedded_input = tf.contrib.layers.embed_sequence(inputs,
                                                              answers_num_words + 1,
                                                              encoder_embedding_size,
                                                              initializer = tf.random_uniform_initializer(0, 1))
    encoder_state = encoder_rnn(encoder_embedded_input, rnn_size, num_layers, keep_prob, sequence_length)
    preprocessed_targets = preprocess_targets(targets, questionswords2int, batch_size)
    decoder_embeddings_matrix = tf.Variable(tf.random_uniform([questions_num_words + 1, decoder_embedding_size], 0, 1))
    decoder_embedded_input = tf.nn.embedding_lookup(decoder_embeddings_matrix, preprocessed_targets)
    training_predictions, test_predictions = decoder_rnn(decoder_embedded_input,
                                                         decoder_embeddings_matrix,
                                                         encoder_state,
                                                         questions_num_words,
                                                         sequence_length,
                                                         rnn_size,
                                                         num_layers,
                                                         questionswords2int,
                                                         keep_prob,
                                                         batch_size)
    return training_predictions, test_predictions

# %%
########## PART 3 - TRAINING THE SEQ2SEQ MODEL ##########
 
 
 
# Setting the Hyperparameters
epochs = 100
batch_size = 64
rnn_size = 512
num_layers = 3
encoding_embedding_size = 512
decoding_embedding_size = 512
learning_rate = 0.01
learning_rate_decay = 0.9
min_learning_rate = 0.0001
keep_probability = 0.5
 
# Defining a session
tf.reset_default_graph()
session = tf.InteractiveSession()
 
# Loading the model inputs
inputs, targets, lr, keep_prob = model_inputs()
 
# Setting the sequence length
sequence_length = tf.placeholder_with_default(25, None, name = 'sequence_length')
 
# Getting the shape of the inputs tensor
input_shape = tf.shape(inputs)

# %%
# Getting the training and test predictions
training_predictions, test_predictions = seq2seq_model(tf.reverse(inputs, [-1]),
                                                       targets,
                                                       keep_prob,
                                                       batch_size,
                                                       sequence_length,
                                                       len(answerswords2int),
                                                       len(questionswords2int),
                                                       encoding_embedding_size,
                                                       decoding_embedding_size,
                                                       rnn_size,
                                                       num_layers,
                                                       questionswords2int)
 
# Setting up the Loss Error, the Optimizer and Gradient Clipping
with tf.name_scope("optimization"):
    loss_error = tf.contrib.seq2seq.sequence_loss(training_predictions,
                                                  targets,
                                                  tf.ones([input_shape[0], sequence_length]))
    optimizer = tf.train.AdamOptimizer(learning_rate)
    gradients = optimizer.compute_gradients(loss_error)
    clipped_gradients = [(tf.clip_by_value(grad_tensor, -5., 5.), grad_variable) for grad_tensor, grad_variable in gradients if grad_tensor is not None]
    optimizer_gradient_clipping = optimizer.apply_gradients(clipped_gradients)

# %%
# Padding the sequences with the <PAD> token
def apply_padding(batch_of_sequences, word2int):
    max_sequence_length = max([len(sequence) for sequence in batch_of_sequences])
    #print(max_sequence_length)
    return [sequence + [word2int['<PAD>']] * (max_sequence_length - len(sequence)) for sequence in batch_of_sequences]

# %%
#print(training_questions[65 : 129])
#print(max([len(sequence) for sequence in training_questions[0 : 64]]))
np.array(apply_padding(training_questions[0 : 64], questionswords2int))
#apply_padding(training_answers[0 : 64], answerswords2int)[0]
#[questionswords2int['<PAD>']]answ4
# Out:
# array([[7560, 4437],
#        [4823, 8359],
#        [ 593, 4047],
#        [4823, 4047],
#        [1875, 8824],
#        [4307, 4437],
#        [1897, 3297],
#        [3906, 2199],
#        [1875, 8640],
#        [ 593, 2859],
#        [4714, 5696],
#        [6036, 4806],
#        [5145,  651],
#        [4001, 3333],
#        [3156, 4049],
#        [8165, 3906],
#        [4823, 1133],
#        [4242, 2034],
#        [3937, 8824],
#        [5527,  406],
#        [6042, 3280],
#        [7482, 5196],
#        [6042, 7796],
#        [1915, 5933],
#        [8824, 5151],
#        [4307, 6052],
#        [1995,  157],
#        [6089, 4823],
#        [1376, 4823],
#        [5151, 3024],
#        [4172, 4875],
#        [3156, 4049],
#        [1075, 5134],
#        [7560, 2170],
#        [7039, 4823],
#        [7969, 5926],
#        [2723, 6879],
#        [8311, 5231],
#        [1394, 7208],
#        [2300, 2884],
#        [1940, 8388],
#        [1940, 2171],
#        [4875, 4695],
#        [5446,  323],
#        [6735, 1258],
#        [4437, 6545],
#        [1093,  258],
#        [2365,  472],
#        [3906,  279],
#        [8580, 4823],
#        [ 257,  708],
#        [8165, 3906],
#        [3906, 4919],
#        [4437, 2201],
#        [7352, 4823],
#        [8417, 1875],
#        [8824, 4437],
#        [6906, 8824],
#        [8824, 8824],
#        [4595, 6969],
#        [3924, 1775],
#        [ 707, 4993],
#        [2509, 1258],
#        [4101, 4081]])

# %%
# Splitting the data into batches of questions and answers
def split_into_batches(questions, answers, batch_size):
    for batch_index in range(0, len(questions) // batch_size):
        start_index = batch_index * batch_size
        questions_in_batch = questions[start_index : start_index + batch_size]
        answers_in_batch = answers[start_index : start_index + batch_size]
        padded_questions_in_batch = np.array(apply_padding(questions_in_batch, questionswords2int))
        padded_answers_in_batch = np.array(apply_padding(answers_in_batch, answerswords2int))
        yield padded_questions_in_batch, padded_answers_in_batch

# %%
split_into_batches(training_questions, training_answers, 64)
#padded_questions_in_batch
# Out:
# <generator object split_into_batches at 0x7f86da042ca8>

# %%
#padded_questions_in_batch, padded_answers_in_batch=split_into_batches(training_questions, training_answers, 64)
#padded_questions_in_batch
batch_size=64
for batch_index in range(0, len(training_questions) // batch_size):
    start_index = batch_index * batch_size
    questions_in_batch = training_questions[start_index : start_index + batch_size]
    answers_in_batch = training_answers[start_index : start_index + batch_size]
    padded_questions_in_batch = np.array(apply_padding(questions_in_batch, questionswords2int))
    padded_answers_in_batch = np.array(apply_padding(answers_in_batch, answerswords2int))

# %%
# Splitting the questions and answers into training and validation sets
training_validation_split = int(len(sorted_clean_questions) * 0.15)
training_questions = sorted_clean_questions[training_validation_split:]
training_answers = sorted_clean_answers[training_validation_split:]
validation_questions = sorted_clean_questions[:training_validation_split]
validation_answers = sorted_clean_answers[:training_validation_split]
 
# Training
batch_index_check_training_loss = 100
batch_index_check_validation_loss = ((len(training_questions)) // batch_size // 2) - 1
total_training_loss_error = 0
list_validation_loss_error = []
early_stopping_check = 0
early_stopping_stop = 1000
checkpoint = "chatbot_weights.ckpt" # For Windows users, replace this line of code by: checkpoint = "./chatbot_weights.ckpt"
session.run(tf.global_variables_initializer())
for epoch in range(1, epochs + 1):
    for batch_index, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(training_questions, training_answers, batch_size)):
        starting_time = time.time()
        _, batch_training_loss_error = session.run([optimizer_gradient_clipping, loss_error], {inputs: padded_questions_in_batch,
                                                                                               targets: padded_answers_in_batch,
                                                                                               lr: learning_rate,
                                                                                               sequence_length: padded_answers_in_batch.shape[1],
                                                                                               keep_prob: keep_probability})
        total_training_loss_error += batch_training_loss_error
        ending_time = time.time()
        batch_time = ending_time - starting_time
        if batch_index % batch_index_check_training_loss == 0:
            print('Epoch: {:>3}/{}, Batch: {:>4}/{}, Training Loss Error: {:>6.3f}, Training Time on 100 Batches: {:d} seconds'.format(epoch,
                                                                                                                                       epochs,
                                                                                                                                       batch_index,
                                                                                                                                       len(training_questions) // batch_size,
                                                                                                                                       total_training_loss_error / batch_index_check_training_loss,
                                                                                                                                       int(batch_time * batch_index_check_training_loss)))
            total_training_loss_error = 0
        if batch_index % batch_index_check_validation_loss == 0 and batch_index > 0:
            total_validation_loss_error = 0
            starting_time = time.time()
            for batch_index_validation, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(validation_questions, validation_answers, batch_size)):
                batch_validation_loss_error = session.run(loss_error, {inputs: padded_questions_in_batch,
                                                                       targets: padded_answers_in_batch,
                                                                       lr: learning_rate,
                                                                       sequence_length: padded_answers_in_batch.shape[1],
                                                                       keep_prob: 1})
                total_validation_loss_error += batch_validation_loss_error
            ending_time = time.time()
            batch_time = ending_time - starting_time
            average_validation_loss_error = total_validation_loss_error / (len(validation_questions) / batch_size)
            print('Validation Loss Error: {:>6.3f}, Batch Validation Time: {:d} seconds'.format(average_validation_loss_error, int(batch_time)))
            learning_rate *= learning_rate_decay
            if learning_rate < min_learning_rate:
                learning_rate = min_learning_rate
            list_validation_loss_error.append(average_validation_loss_error)
            if average_validation_loss_error <= min(list_validation_loss_error):
                print('I speak better now!!')
                early_stopping_check = 0
                saver = tf.train.Saver()
                saver.save(session, checkpoint)
            else:
                print("Sorry I do not speak better, I need to practice more.")
                early_stopping_check += 1
                if early_stopping_check == early_stopping_stop:
                    break
    if early_stopping_check == early_stopping_stop:
        print("My apologies, I cannot speak better anymore. This is the best I can do.")
        break
print("Game Over")
# Out:
# Epoch:   1/100, Batch:    0/2708, Training Loss Error:  0.091, Training Time on 100 Batches: 889 seconds
# Epoch:   1/100, Batch:  100/2708, Training Loss Error:  5.661, Training Time on 100 Batches: 825 seconds
# Epoch:   1/100, Batch:  200/2708, Training Loss Error:  2.245, Training Time on 100 Batches: 650 seconds
# Epoch:   1/100, Batch:  300/2708, Training Loss Error:  1.695, Training Time on 100 Batches: 643 seconds
# Epoch:   1/100, Batch:  400/2708, Training Loss Error:  1.624, Training Time on 100 Batches: 829 seconds
# Epoch:   1/100, Batch:  500/2708, Training Loss Error:  1.464, Training Time on 100 Batches: 894 seconds
# Epoch:   1/100, Batch:  600/2708, Training Loss Error:  1.384, Training Time on 100 Batches: 1764 seconds
# Epoch:   1/100, Batch:  700/2708, Training Loss Error:  1.307, Training Time on 100 Batches: 764 seconds
# Epoch:   1/100, Batch:  800/2708, Training Loss Error:  1.379, Training Time on 100 Batches: 769 seconds
# Epoch:   1/100, Batch:  900/2708, Training Loss Error:  1.276, Training Time on 100 Batches: 841 seconds
# Epoch:   1/100, Batch: 1000/2708, Training Loss Error:  1.280, Training Time on 100 Batches: 1195 seconds
# Epoch:   1/100, Batch: 1100/2708, Training Loss Error:  1.237, Training Time on 100 Batches: 962 seconds
# Epoch:   1/100, Batch: 1200/2708, Training Loss Error:  1.243, Training Time on 100 Batches: 992 seconds
# Epoch:   1/100, Batch: 1300/2708, Training Loss Error:  1.244, Training Time on 100 Batches: 1250 seconds
# Validation Loss Error:  8.155, Batch Validation Time: 1750 seconds
# I speak better now!!
# Epoch:   1/100, Batch: 1400/2708, Training Loss Error:  1.222, Training Time on 100 Batches: 1217 seconds
# Epoch:   1/100, Batch: 1500/2708, Training Loss Error:  1.205, Training Time on 100 Batches: 1228 seconds
# Epoch:   1/100, Batch: 1600/2708, Training Loss Error:  1.202, Training Time on 100 Batches: 932 seconds
# Epoch:   1/100, Batch: 1700/2708, Training Loss Error:  1.281, Training Time on 100 Batches: 1059 seconds
# Epoch:   1/100, Batch: 1800/2708, Training Loss Error:  1.270, Training Time on 100 Batches: 2981 seconds
# Epoch:   1/100, Batch: 1900/2708, Training Loss Error:  1.271, Training Time on 100 Batches: 1103 seconds
# Epoch:   1/100, Batch: 2000/2708, Training Loss Error:  1.264, Training Time on 100 Batches: 1441 seconds
# Epoch:   1/100, Batch: 2100/2708, Training Loss Error:  1.278, Training Time on 100 Batches: 1036 seconds
# Epoch:   1/100, Batch: 2200/2708, Training Loss Error:  1.222, Training Time on 100 Batches: 859 seconds
# Epoch:   1/100, Batch: 2300/2708, Training Loss Error:  1.159, Training Time on 100 Batches: 1494 seconds
# Epoch:   1/100, Batch: 2400/2708, Training Loss Error:  1.234, Training Time on 100 Batches: 935 seconds
# Epoch:   1/100, Batch: 2500/2708, Training Loss Error:  1.210, Training Time on 100 Batches: 1917 seconds
# Epoch:   1/100, Batch: 2600/2708, Training Loss Error:  1.312, Training Time on 100 Batches: 1266 seconds
# Epoch:   1/100, Batch: 2700/2708, Training Loss Error:  1.242, Training Time on 100 Batches: 1683 seconds
# Validation Loss Error: 10.974, Batch Validation Time: 1856 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:   2/100, Batch:    0/2708, Training Loss Error:  0.239, Training Time on 100 Batches: 901 seconds
# Epoch:   2/100, Batch:  100/2708, Training Loss Error:  7.033, Training Time on 100 Batches: 1681 seconds
# Epoch:   2/100, Batch:  200/2708, Training Loss Error:  1.579, Training Time on 100 Batches: 1568 seconds
# Epoch:   2/100, Batch:  300/2708, Training Loss Error:  1.377, Training Time on 100 Batches: 1344 seconds
# Epoch:   2/100, Batch:  400/2708, Training Loss Error:  1.306, Training Time on 100 Batches: 2173 seconds
# Epoch:   2/100, Batch:  500/2708, Training Loss Error:  1.301, Training Time on 100 Batches: 2262 seconds
# Epoch:   2/100, Batch:  600/2708, Training Loss Error:  1.284, Training Time on 100 Batches: 5250 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-41bbfdffeec7> in <module>()
#      22                                                                                                lr: learning_rate,
#      23                                                                                                sequence_length: padded_answers_in_batch.shape[1],
# ---> 24                                                                                                keep_prob: keep_probability})
#      25         total_training_loss_error += batch_training_loss_error
#      26         ending_time = time.time()
#
# /home/mb45296/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/mb45296/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/mb45296/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/mb45296/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/mb45296/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
########## PART 4 - TESTING THE SEQ2SEQ MODEL ##########
 
 
 
# Loading the weights and Running the session
checkpoint = "./chatbot_weights.ckpt"
session = tf.InteractiveSession()
session.run(tf.global_variables_initializer())
#saver = tf.train.Saver()
#saver.restore(session, checkpoint)
 
# Converting the questions from strings to lists of encoding integers
def convert_string2int(question, word2int):
    question = clean_text(question)
    return [word2int.get(word, word2int['<OUT>']) for word in question.split()]
 
# Setting up the chat
while(True):
    question = input("You: ")
    if question == 'Goodbye':
        break
    question = convert_string2int(question, questionswords2int)
    question = question + [questionswords2int['<PAD>']] * (25 - len(question))
    fake_batch = np.zeros((batch_size, 25))
    fake_batch[0] = question
    predicted_answer = session.run(test_predictions, {inputs: fake_batch, keep_prob: 0.5})[0]
    answer = ''
    for i in np.argmax(predicted_answer, 1):
        if answersints2word[i] == 'i':
            token = ' I'
        elif answersints2word[i] == '<EOS>':
            token = '.'
        elif answersints2word[i] == '<OUT>':
            token = 'out'
        else:
            token = ' ' + answersints2word[i]
        answer += token
        if token == '.':
            break
    print('ChatBot: ' + answer)
# Out:
# You: hi
# ChatBot:  borg borg borg quarrel prime prime geneva geneva egg egg egg egg shadow egg xray anymore! anymore! darlin' darlin' chat anymore! loud chat er spoiled
# You: what
# ChatBot:  sex sex mainland theresa bee bee bee practical bee bee bee alphabet meanwhile meanwhile meanwhile meanwhile anymore! o malfunction approximately approximately anymore! anymore! anymore! anymore!
# You: quit
# ChatBot:  shave sounds shave 75 iti dreamt anymore! atom luck luck luck luck winner palm luck malfunction malfunction anymore! o anymore! anymore! anymore! seen seen chairs
# You: goodbye
# ChatBot:  shave blanks split split spoken spoken luis luis atlanta egg egg egg egg bianca bianca fog fog fog fog er er er er loves loves
# You: Goodbye
